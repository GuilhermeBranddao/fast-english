# %%
len(palavras)
# Out:
# 665

# %% [markdown]
# Quero uma classe que crie novos cards de estudo e salve esses card seguindo um padrão
#
# Esse é um exemplo de um existente
#
# Eu tenho um arquivo json que contem informações sobre o card
#
# database\extract_data_video\data\extracted_data\phrases\data_organize\avião\bagagem\are_you_checking_any_baggage\text_v2.json
#
# {
#   "id": "61d8a5919c664927b39fb7121bdd98fe",
#   "pergunta_pt-br": "Está a reportar alguma bagagem?",
#   "uso_da_linguagem": "A Linguagem formal oo",
#   "tradução_en": "Are you checking any baggage?",
#   "fonetica": "Jar ja tfekin ‘eni ‘beegid3?/",
#   "difficulty_level": "beginner",
#   "part_of_speech": "question",
#   "category": "avião",
#   "subcategory": "bagagem",
#   "context": "",
#   "example_en": "",
#   "example_pt": "",
#   "created_at": "2025-04-11T11:17:38.000000Z",
#   "updated_at": "2025-05-19T06:15:19.872357Z",
#   "observations": "",
#   "status": "pending",
#   "author": "automation extracted from video lessons"
# }
#
#
# O caminho a ser criado pela classe será parecido, vai mudar só algumas coisas
#
# A pasta para onde as frase iram será "personalized"
# As pastas "subclass" e "class" serão escolhidas pelo usuario
# A pasta que vai conter o json se chama "sentense" ela recebe o nome da frase em ingles exemplo se a frase em ingles for "How are, you?" o nome da pasta deve ser "how_are_you"
#
# database\extract_data_video\data\extracted_data\personalized\data_organize\{class}\{subclass}\{sentense}\text_v2.json

# %%
import os

os.chdir("..")
os.chdir("..")
os.chdir("..")

# %load_ext autoreload
# %autoreload 2

# !dir
# Out:
#  O volume na unidade G � Armazenamento
#  O N�mero de S�rie do Volume � 2091-BE76
#
#  Pasta de g:\py_projects\fast-english
#
# 29/07/2025  18:47    <DIR>          .
# 27/07/2025  11:13    <DIR>          ..
# 26/07/2025  16:09                44 .gitattributes
# 03/07/2025  16:47    <DIR>          .github
# 26/07/2025  16:22             4.660 .gitignore
# 03/07/2025  16:47                 9 .python-version
# 03/07/2025  16:53    <DIR>          .venv
# 26/07/2025  16:22    <DIR>          add_new_data
# 29/07/2025  18:47    <DIR>          app
# 12/07/2025  20:33    <DIR>          database
# 03/07/2025  16:47    <DIR>          docs
# 03/07/2025  16:47           456.432 poetry.lock
# 03/07/2025  16:47             1.231 pyproject.toml
# 28/07/2025  11:21               208 README.md
# 28/07/2025  13:51               210 requirements.txt
# 26/07/2025  15:48            15.326 set_difference.txt
# 03/07/2025  16:47    <DIR>          tests
# 03/07/2025  16:47    <DIR>          trash
# ...

# %%
palavras = {
# better
"Eu me sinto muito melhor depois de uma boa noite de sono.": "I feel much better after a good night's sleep.",
"Você deveria encontrar uma maneira melhor de organizar seus arquivos.": "You should find a better way to organize your files.",
"A nova versão do software é melhor que a anterior.": "The new software version is better than the old one.",

# actually
"Eu pensei que o filme seria chato, mas na verdade foi muito bom.": "I thought the movie would be boring, but it was actually very good.",
"Ele parece jovem, mas na verdade tem mais de quarenta anos.": "He looks young, but he's actually over forty years old.",
"Você realmente terminou o projeto inteiro sozinho?": "Did you actually finish the entire project by yourself?",

# six-figure
"Ela conseguiu um emprego de seis dígitos logo após a faculdade.": "She landed a six-figure job right after college.",
"Construir um negócio com uma renda de seis dígitos requer muita dedicação.": "Building a business with a six-figure income requires a lot of dedication.",
"O processo resultou em um acordo de seis dígitos.": "The lawsuit resulted in a six-figure settlement.",

# tons
"Nós temos toneladas de trabalho para fazer antes do prazo final.": "We have tons of work to do before the deadline.",
"Obrigado pelas flores, elas custaram uma tonelada, tenho certeza!": "Thanks for the flowers, they must have cost tons!",
"Ela tem toneladas de amigos na cidade.": "She has tons of friends in the city.",

# haggle over
"Eu não gosto de pechinchar o preço de vegetais no mercado.": "I don't like to haggle over the price of vegetables at the market.",
"Eles passaram uma hora pechinchando cada item do contrato.": "They spent an hour haggling over every item in the contract.",
"Não vamos pechinchar por alguns reais, apenas pague o valor pedido.": "Let's not haggle over a few dollars, just pay the asking price.",

# paycheck
"Muitas pessoas vivem de salário em salário.": "Many people live from paycheck to paycheck.",
"Meu primeiro salário foi gasto inteiramente em livros.": "My first paycheck was spent entirely on books.",
"Estou ansiosamente esperando meu próximo salário para poder comprar o novo console.": "I'm eagerly waiting for my next paycheck so I can buy the new console.",

# laid off
"Ele foi demitido durante a reestruturação da empresa.": "He was laid off during the company's restructuring.",
"Ser demitido pode ser uma experiência muito estressante.": "Being laid off can be a very stressful experience.",
"Centenas de trabalhadores foram demitidos quando a fábrica fechou.": "Hundreds of workers were laid off when the factory closed.",

# partner
"Ele e seu sócio iniciaram o negócio do zero.": "He and his business partner started the company from scratch.",
"Eu vou à festa com meu/minha parceiro(a).": "I am going to the party with my partner.",
"O sucesso deste projeto depende de cada parceiro cumprir seu papel.": "The success of this project depends on each partner fulfilling their role.",

# praying
"Ela estava rezando por um resultado positivo.": "She was praying for a positive outcome.",
"Estou rezando para que você chegue em casa em segurança.": "I'm praying you get home safely.",
"Eles passaram a noite rezando por notícias de seu filho.": "They spent the night praying for news of their son.",

# elderly
"É nosso dever cuidar da população idosa.": "It is our duty to care for the elderly population.",
"O motorista idoso teve dificuldade em ler a placa de trânsito.": "The elderly driver had trouble reading the road sign.",
"A comunidade construiu um novo centro para cidadãos idosos.": "The community built a new center for elderly citizens.",

# stuck
"O carro ficou preso na lama depois da forte chuva.": "The car got stuck in the mud after the heavy rain.",
"Estou preso neste problema de matemática há horas.": "I've been stuck on this math problem for hours.",
"Nós ficamos presos no elevador por quase uma hora.": "We were stuck in the elevator for almost an hour.",

# handle
"Ela sabe como lidar com clientes difíceis.": "She knows how to handle difficult customers.",
"Você pode, por favor, me ajudar a manusear esta caixa pesada?": "Can you please help me handle this heavy box?",
"Eu acho que não consigo lidar com mais más notícias hoje.": "I don't think I can handle any more bad news today.",

# them
"Eu os vi no parque ontem.": "I saw them at the park yesterday.",
"Você pode dar esses livros a eles, por favor?": "Can you give these books to them, please?",
"A decisão não cabe a eles, mas sim à gerência.": "The decision is not up to them, but up to the management.",

# won't
"Eu não irei à festa esta noite.": "I won't go to the party tonight.",
"Este carro velho não pega de manhã.": "This old car won't start in the morning.",
"Ela prometeu que não contaria nosso segredo a ninguém.": "She promised she won't tell anyone our secret.",

# at least
"Pelo menos nós tentamos fazer o nosso melhor.": "At least we tried to do our best.",
"Você deveria beber pelo menos oito copos de água por dia.": "You should drink at least eight glasses of water a day.",
"O show estava lotado, mas pelo menos conseguimos bons lugares.": "The show was sold out, but at least we got good seats.",


# tap
"Apenas toque na tela para abrir o aplicativo.": "Just tap the screen to open the application.",
"Ele sentiu um toque em seu ombro.": "He felt a tap on his shoulder.",
"Precisamos explorar novos mercados para expandir o negócio.": "We need to tap into new markets to grow the business.",

# blank stares
"Minha explicação foi recebida com olhares vazios da plateia.": "My explanation was met with blank stares from the audience.",
"Ele me lançou um olhar vago quando perguntei sobre o projeto.": "He gave me a blank stare when I asked him about the project.",
"A teoria complexa resultou em uma sala cheia de olhares perplexos.": "The complex theory resulted in a room full of blank stares.",

# suddenly
"De repente, todas as luzes se apagaram.": "Suddenly, all the lights went out.",
"Ele decidiu de repente mudar sua trajetória de carreira.": "He suddenly decided to change his career path.",
"O humor na sala mudou subitamente quando ela entrou.": "The mood in the room changed suddenly when she entered.",

# entire
"Ele comeu a pizza inteira sozinho.": "He ate the entire pizza by himself.",
"A equipe inteira trabalhou no projeto.": "The entire team worked on the project.",
"Levei o dia inteiro para limpar a casa.": "It took me the entire day to clean the house.",

# almost
"Nós estamos quase lá, não desista agora.": "We are almost there, don't give up now.",
"Eu quase perdi meu voo esta manhã.": "I almost missed my flight this morning.",
"O copo está quase cheio.": "The glass is almost full.",

# their crossover point
"Eles alcançaram seu ponto de virada financeiro no ano passado.": "They reached their crossover point last year.",
"O objetivo de muitas pessoas é atingir seu ponto de virada o mais cedo possível.": "Many people's goal is to hit their crossover point as early as possible.",
"Uma vez que você entenda seu ponto de virada, você pode planejar a independência financeira.": "Once you understand their crossover point, you can plan for financial independence.",

# More on that later
"Discutiremos a estratégia de marketing agora. A logística? Mais sobre isso depois.": "We'll discuss the marketing strategy now. The logistics? More on that later.",
"A causa do problema é complexa, e entrarei em mais detalhes sobre isso mais tarde.": "The cause of the issue is complex, and I'll go into more on that later.",
"Ele mencionou uma nova oportunidade, prometendo mais detalhes sobre isso mais tarde.": "He mentioned a new opportunity, promising more on that later.",

# behind
"A chave está atrás do vaso de plantas.": "The key is behind the flower pot.",
"Ele está ficando para trás em seus estudos.": "He is falling behind in his studies.",
"Qual é o significado por trás de suas palavras?": "What is the meaning behind his words?",

# be paid off
"Todo o trabalho duro deles será recompensado no final.": "All their hard work will be paid off in the end.",
"A hipoteca finalmente será quitada no próximo mês.": "The mortgage will finally be paid off next month.",
"Ela espera que seu investimento seja recompensado generosamente.": "She hopes her investment will be paid off handsomely.",

# might
"Pode chover mais tarde, então leve um guarda-chuva.": "It might rain later, so take an umbrella.",
"Eu talvez vá ao cinema esta noite, se terminar meu trabalho.": "I might go to the movies tonight if I finish my work.",
"Ele pode saber a resposta, pergunte a ele.": "He might know the answer, you should ask him.",

# against
"É ele contra o mundo.": "It's him against the world.",
"Estou me apoiando na parede.": "I am leaning against the wall.",
"Votar contra a proposta foi uma decisão difícil.": "Voting against the proposal was a difficult decision.",

# earn
"Ele trabalha duro para ganhar um salário decente.": "He works hard to earn a decent salary.",
"Você deve conquistar a confiança deles.": "You have to earn their trust.",
"Quanto você ganha por ano?": "How much do you earn per year?",

# take-home
"Seu salário líquido é o que sobra após os impostos.": "Your take-home pay is what's left after taxes.",
"O salário anunciado era alto, mas o valor líquido era decepcionante.": "The advertised salary was high, but the take-home amount was disappointing.",
"Ele calcula seu orçamento com base em seu salário líquido mensal.": "He calculates his budget based on his monthly take-home pay.",

# guilty
"Ele se sentiu culpado por ter comido o último pedaço de bolo.": "He felt guilty about eating the last piece of cake.",
"O júri considerou o réu culpado de todas as acusações.": "The jury found the defendant guilty of all charges.",
"Não há necessidade de se sentir culpado por tirar um dia de folga.": "There's no need to feel guilty for taking a day off.",


# more
"Eu poderia ter um pouco mais de água, por favor?": "Could I have some more water, please?",
"Isto é mais difícil do que eu esperava.": "This is more difficult than I expected.",
"Quanto mais você estuda, mais você aprende.": "The more you study, the more you learn.",

# overwhelmed
"Ela se sentiu sobrecarregada com todo o trabalho que tinha para fazer.": "She felt overwhelmed with all the work she had to do.",
"Pais de primeira viagem muitas vezes se sentem sobrecarregados por suas responsabilidades.": "New parents often feel overwhelmed by their responsibilities.",
"Não fique sobrecarregado com os detalhes; foque no objetivo principal.": "Don't get overwhelmed by the details; focus on the main goal.",

# pretty
"Esse é um vestido muito bonito.": "That is a very pretty dress.",
"Tenho quase certeza de que tranquei a porta.": "I'm pretty sure I locked the door.",
"O tempo está muito bom hoje.": "The weather is pretty good today.",

# moves
"Os passos de dança dele eram impressionantes.": "His dance moves were impressive.",
"Precisamos analisar os movimentos do nosso concorrente.": "We need to analyze our competitor's moves.",
"Fazer movimentos de carreira ousados pode levar a um grande sucesso.": "Making bold career moves can lead to great success.",

# wealth
"Ele acumulou grande riqueza através de investimentos inteligentes.": "He accumulated great wealth through smart investments.",
"Saúde é a maior riqueza.": "Health is the greatest wealth.",
"A gestão de patrimônio é crucial para os ricos.": "Wealth management is crucial for the affluent.",

# wondering
"Eu estava me perguntando se você poderia me ajudar com isso.": "I was wondering if you could help me with this.",
"Ela estava pensando no que fazer a seguir.": "She was wondering what to do next.",
"Ele ficou ali, imaginando por que ela tinha ido embora.": "He stood there, wondering why she had left.",

# burn rate
"A startup tem uma alta taxa de queima de caixa, gastando milhares a cada mês.": "The startup has a high burn rate, spending thousands each month.",
"Precisamos reduzir nossa taxa de queima de caixa para estender nossa viabilidade financeira.": "We need to lower our burn rate to extend our financial runway.",
"Investidores sempre perguntam sobre a taxa de queima de caixa da empresa.": "Investors always ask about the company's burn rate.",

# figure
"Não consigo descobrir como resolver este quebra-cabeça.": "I can't figure out how to solve this puzzle.",
"Os números de vendas para este trimestre são excelentes.": "The sales figures for this quarter are excellent.",
"Ele é uma figura importante na comunidade local.": "He is an important figure in the local community.",

# they
"Eles vêm para jantar hoje à noite.": "They are coming over for dinner tonight.",
"Se um aluno precisar de ajuda, ele deve perguntar ao professor.": "If a student needs help, they should ask the teacher.",
"Dizem que vai chover amanhã.": "They say it's going to rain tomorrow.",

# jokes aside
"Brincadeiras à parte, nós realmente precisamos terminar este projeto a tempo.": "Jokes aside, we really need to finish this project on time.",
"Eu sei que rimos sobre isso, mas brincadeiras à parte, este é um assunto sério.": "I know we laugh about it, but jokes aside, this is a serious matter.",
"Brincadeiras à parte, sua contribuição foi inestimável.": "Jokes aside, your contribution was invaluable.",

# pick
"Você pode escolher qualquer cor que você goste.": "You can pick any color you like.",
"Preciso buscar meus filhos na escola.": "I need to pick up my kids from school.",
"Vamos colher algumas flores do jardim.": "Let's pick some flowers from the garden.",

# chaos
"A cidade estava um caos depois do blecaute.": "The city was in chaos after the blackout.",
"Minha manhã é sempre um caos tentando arrumar as crianças para a escola.": "My morning is always chaos trying to get the kids ready for school.",
"Ele conseguiu encontrar ordem no caos de sua mesa.": "He managed to find order in the chaos of his desk.",

# lie
"Ele decidiu deitar-se no sofá por um tempo.": "He decided to lie on the couch for a while.",
"A vila fica em um belo vale.": "The village lies in a beautiful valley.",
"A raiz do problema reside na falta de comunicação.": "The root of the problem lies in the lack of communication.",

# statements
"Por favor, verifique seus extratos bancários em busca de erros.": "Please check your bank statements for any errors.",
"As testemunhas deram suas declarações à polícia.": "The witnesses gave their statements to the police.",
"As declarações de missão da empresa orientam suas decisões.": "The company's mission statements guide its decisions.",

# throws
"Ele arremessa a bola com grande precisão.": "He throws the ball with great accuracy.",
"Ela frequentemente dá grandes festas para seus amigos.": "She often throws big parties for her friends.",
"Este novo dado joga um balde de água fria em nossos planos.": "This new data throws a wrench in our plans.",


# oftentimes
"Muitas vezes, a solução mais simples é a melhor.": "Oftentimes, the simplest solution is the best one.",
"Ele frequentemente trabalha até tarde para terminar seus projetos.": "He oftentimes works late to finish his projects.",
"O que parece um fracasso muitas vezes leva a uma nova oportunidade.": "What seems like a failure oftentimes leads to a new opportunity.",

# Whatever
"Você pode fazer o que quiser.": "You can do whatever you want.",
"Seja qual for o motivo, ele não está aqui hoje.": "Whatever the reason, he is not here today.",
"Ela o apoiará, seja o que for que ele decida.": "She will support him, whatever he decides.",

# thought
"Eu pensei que você viria para a festa.": "I thought you were coming to the party.",
"Ela dedicou muito pensamento ao presente dela.": "She put a lot of thought into her gift.",
"O simples pensamento de falar em público o deixa nervoso.": "The mere thought of public speaking makes him nervous.",

# along
"Nós caminhamos ao longo da praia ao pôr do sol.": "We walked along the beach at sunset.",
"Traga seus amigos junto para o show.": "Bring your friends along to the concert.",
"Tudo está correndo conforme o planejado.": "Everything is going along as planned.",

# amount
"Por favor, pague o valor total até a data de vencimento.": "Please pay the full amount by the due date.",
"Uma quantidade surpreendente de pessoas compareceu ao evento.": "A surprising amount of people attended the event.",
"Nenhuma quantia de dinheiro pode comprar felicidade.": "No amount of money can buy happiness.",

# disaster
"O terremoto foi um desastre natural terrível.": "The earthquake was a terrible natural disaster.",
"A festa foi um desastre completo; tudo deu errado.": "The party was a complete disaster; everything went wrong.",
"Sua primeira tentativa de cozinhar foi um desastre.": "His first attempt at cooking was a disaster.",

# ride
"Você gostaria de dar uma volta de bicicleta?": "Would you like to go for a bike ride?",
"Você pode me dar uma carona para o aeroporto?": "Can you give me a ride to the airport?",
"O passeio na montanha-russa foi emocionante.": "The rollercoaster ride was thrilling.",

# curveball
"A vida lhe pregou uma peça quando ele perdeu o emprego.": "Life threw him a curveball when he lost his job.",
"O entrevistador me surpreendeu com uma pergunta que eu não esperava.": "The interviewer threw me a curveball with a question I didn't expect.",
"Quando achávamos que o projeto estava finalizado, um novo requisito foi uma verdadeira surpresa.": "Just when we thought the project was finished, a new requirement was a real curveball.",

# figure out
"Preciso descobrir como montar este móvel.": "I need to figure out how to assemble this furniture.",
"Nós finalmente encontramos a solução para o problema.": "We finally figured out the solution to the problem.",
"Ela não conseguia entender por que o computador não estava funcionando.": "She couldn't figure out why the computer wasn't working.",

# spreadsheets
"Ele usa planilhas para acompanhar suas despesas mensais.": "He uses spreadsheets to track his monthly expenses.",
"Analistas financeiros são especialistas em criar planilhas complexas.": "Financial analysts are experts at creating complex spreadsheets.",
"Os dados foram organizados em várias planilhas.": "The data was organized in several spreadsheets.",

# into
"Ele entrou na sala sem bater.": "He walked into the room without knocking.",
"Ela recentemente começou a se interessar por ioga.": "She has recently gotten into yoga.",
"Você pode traduzir este texto para o português?": "Can you translate this text into Portuguese?",

# budgeting
"Um orçamento eficaz é a chave para a estabilidade financeira.": "Effective budgeting is key to financial stability.",
"Ela está ensinando seu filho sobre orçamento e como poupar dinheiro.": "She is teaching her son about budgeting and saving money.",
"O processo de orçamento da empresa começa no quarto trimestre.": "The company's budgeting process begins in the fourth quarter.",

# spent
"Nós passamos o dia inteiro na praia.": "We spent the whole day at the beach.",
"Ela gastou muito dinheiro em roupas no mês passado.": "She spent too much money on clothes last month.",
"Toda a sua energia foi gasta para terminar a maratona.": "All his energy was spent on finishing the marathon.",

# sprinklers
"Os irrigadores automáticos ligam todas as manhãs às 6h.": "The automatic sprinklers turn on every morning at 6 AM.",
"As crianças adoram correr pelos irrigadores em dias quentes.": "The children love running through the sprinklers on hot days.",
"O incêndio foi contido pelo sistema de sprinklers do prédio.": "The fire was contained by the building's sprinkler system.",

# own
"Ele quer abrir seu próprio negócio um dia.": "He wants to start his own business one day.",
"Você precisa assumir seus próprios erros.": "You need to take ownership of your own mistakes.",
"Eles possuem uma bela casa à beira do lago.": "They own a beautiful house by the lake.",


# higher
"As temperaturas estão mais altas hoje do que ontem.": "The temperatures are higher today than yesterday.",
"Ele almeja uma posição mais alta na empresa.": "He is aiming for a higher position in the company.",
"A educação superior pode levar a melhores oportunidades de emprego.": "Higher education can lead to better job opportunities.",

# substandard
"O trabalho que ele entregou estava abaixo do padrão e teve que ser refeito.": "The work he submitted was substandard and had to be redone.",
"Não vamos tolerar produtos de qualidade inferior de nossos fornecedores.": "We will not tolerate substandard products from our suppliers.",
"As condições de vida naquele prédio foram consideradas insatisfatórias.": "The living conditions in that building were deemed substandard.",

# guess anymore
"Com esses dados, não precisamos mais adivinhar.": "With this data, we don't have to guess anymore.",
"Eu não consigo mais adivinhar o que ela está pensando.": "I can't guess anymore what she is thinking.",
"Depois de estudar o guia, você não terá mais que adivinhar as respostas.": "After studying the guide, you won't have to guess anymore on the answers.",

# until
"Por favor, espere aqui até eu voltar.": "Please wait here until I get back.",
"Ele trabalhou até tarde da noite para terminar o relatório.": "He worked until late at night to finish the report.",
"A loja fica aberta até as 21h.": "The store is open until 9 PM.",

# even
"Até uma criança consegue resolver este problema.": "Even a child can solve this problem.",
"Ele não disse nem uma palavra durante a reunião.": "He didn't say even a single word during the meeting.",
"Os números 2, 4 e 6 são números pares.": "The numbers 2, 4, and 6 are even numbers.",

# debt free
"Seu objetivo é estar livre de dívidas em cinco anos.": "Her goal is to be debt free in five years.",
"Viver sem dívidas proporciona uma grande sensação de liberdade.": "Living debt free provides a great sense of freedom.",
"Ele celebrou o dia em que finalmente se tornou livre de dívidas.": "He celebrated the day he finally became debt free.",

# owe
"Eu te devo um pedido de desculpas pelo meu comportamento.": "I owe you an apology for my behavior.",
"Quanto eu te devo pelo jantar?": "How much do I owe you for dinner?",
"Ela deve seu sucesso ao trabalho árduo e à perseverança.": "She owes her success to hard work and perseverance.",

# paying
"Você está prestando atenção no que estou dizendo?": "Are you paying attention to what I'm saying?",
"Pagar as contas em dia é importante para o seu score de crédito.": "Paying your bills on time is important for your credit score.",
"Ele está pagando por seus erros agora.": "He is paying for his mistakes now.",

# godforsaken Kohl's
"Eu não acredito que tenho que ir àquela maldita Kohl's de novo.": "I can't believe I have to go to that godforsaken Kohl's again.",
"Ele perdeu a carteira em algum lugar naquela maldita Kohl's.": "He lost his wallet somewhere in that godforsaken Kohl's.",
"Ela jurou nunca mais pisar naquela maldita Kohl's depois do péssimo atendimento.": "She swore never to set foot in that godforsaken Kohl's again after the terrible service.",

# whatever
"Faça o que for preciso para terminar o trabalho.": "Do whatever it takes to get the job done.",
"O que quer que você decida, eu te apoiarei.": "Whatever you decide, I will support you.",
"Ela come o que quer e nunca engorda.": "She eats whatever she wants and never gains weight.",

# avoiding
"Ele tem evitado minhas ligações a semana toda.": "He has been avoiding my calls all week.",
"Evitar o problema não o fará desaparecer.": "Avoiding the problem won't make it go away.",
"Ela está evitando açúcar para melhorar sua saúde.": "She is avoiding sugar to improve her health.",

# gotta
"Eu tenho que ir agora ou vou me atrasar.": "I gotta go now or I'll be late.",
"Você tem que ver este filme, é incrível.": "You gotta see this movie, it's amazing.",
"Nós temos que terminar isso hoje.": "We gotta get this done today.",

# vague
"As instruções dele eram muito vagas, então eu não sabia o que fazer.": "His instructions were very vague, so I didn't know what to do.",
"Tenho uma vaga lembrança de tê-lo conhecido antes.": "I have a vague memory of meeting him before.",
"Tente não ser vago ao descrever o que aconteceu.": "Try not to be vague when describing what happened.",

# either
"Você pode escolher ou o bolo de chocolate ou o de baunilha.": "You can have either the chocolate cake or the vanilla one.",
"Eu não gosto de brócolis, e meu irmão também não.": "I don't like broccoli, and my brother doesn't either.",
"De qualquer forma, a decisão precisa ser tomada até amanhã.": "Either way, the decision needs to be made by tomorrow.",

# those
"Aqueles sapatos são exatamente o que eu estava procurando.": "Those shoes are exactly what I was looking for.",
"Você se lembra daqueles dias que passamos na praia?": "Do you remember those days we spent at the beach?",
"Quem são aquelas pessoas ali?": "Who are those people over there?",


# Putting aside
"Deixando de lado nossas diferenças, precisamos trabalhar juntos.": "Putting aside our differences, we need to work together.",
"Ela está guardando um pouco de dinheiro todo mês para um carro novo.": "She is putting aside a little money each month for a new car.",
"Deixando o custo de lado, qual opção você prefere?": "Putting aside the cost, which option do you prefer?",

# horseradish sauce
"Rosbife é frequentemente servido com molho de raiz-forte.": "Roast beef is often served with horseradish sauce.",
"Cuidado, o molho de raiz-forte é muito picante.": "Be careful, the horseradish sauce is very strong.",
"Eu gostaria de um pouco de molho de raiz-forte extra no meu sanduíche.": "I'd like a little extra horseradish sauce on my sandwich.",

# shave
"Ele precisa se barbear antes de ir para a entrevista de emprego.": "He needs to shave before going to the job interview.",
"Conseguimos reduzir alguns segundos do nosso tempo recorde.": "We managed to shave a few seconds off our record time.",
"Ela decidiu raspar a cabeça por caridade.": "She decided to shave her head for charity.",

# every
"Todo aluno recebeu um certificado.": "Every student received a certificate.",
"Ela vai correr todo santo dia.": "She goes for a run every single day.",
"Verifiquei todos os cômodos e não consigo encontrar minhas chaves.": "I've checked every room, and I can't find my keys.",

# tightrope
"O acrobata atravessou a corda bamba com um equilíbrio incrível.": "The acrobat walked across the tightrope with amazing balance.",
"Gerenciar um orçamento às vezes pode parecer como andar na corda bamba.": "Managing a budget can sometimes feel like walking a tightrope.",
"Ele está em uma corda bamba política, tentando agradar a ambos os partidos.": "He is on a political tightrope, trying to please both parties.",

# interest
"O banco oferece uma alta taxa de juros em contas poupança.": "The bank offers a high interest rate on savings accounts.",
"Ela tem um grande interesse em arte moderna.": "She has a keen interest in modern art.",
"O que ele disse não foi de meu interesse.": "What he said was of no interest to me.",

# valence
"Em psicologia, valência se refere ao valor emocional de um evento.": "In psychology, valence refers to the emotional value of an event.",
"A valência de um átomo é determinada pelo número de elétrons que ele pode compartilhar.": "The valence of an atom is determined by the number of electrons it can share.",
"Os pesquisadores estão estudando a base neural da valência emocional.": "Researchers are studying the neural basis of emotional valence.",

# weird
"Eu tive um sonho muito estranho na noite passada.": "I had a really weird dream last night.",
"É estranho que ela não tenha ligado para dizer que se atrasaria.": "It's weird that she didn't call to say she would be late.",
"Ele tem um senso de humor peculiar, mas é um cara legal.": "He has a weird sense of humor, but he's a nice guy.",

# awful
"O tempo esteve horrível durante todo o fim de semana.": "The weather was awful all weekend.",
"Sinto-me péssimo pelo que lhe disse.": "I feel awful for what I said to you.",
"Havia um cheiro terrível vindo da cozinha.": "There was an awful smell coming from the kitchen.",

# assign
"O professor vai passar a lição de casa no final da aula.": "The teacher will assign the homework at the end of the class.",
"Eles decidiram me designar a tarefa de organizar o evento.": "They decided to assign me the task of organizing the event.",
"Você pode atribuir um toque específico a um contato.": "You can assign a specific ringtone to a contact.",

# palate
"O chef cria pratos para agradar a todos os paladares.": "The chef creates dishes to please every palate.",
"Este vinho tem um paladar complexo com notas de frutas e carvalho.": "This wine has a complex palate with notes of berries and oak.",
"O paladar dela não está acostumado com comida apimentada.": "Her palate is not used to spicy food.",

# less
"Eu tenho menos tempo do que pensava.": "I have less time than I thought.",
"Você deveria comer menos 'junk food'.": "You should eat less junk food.",
"Quanto mais você se preocupa, menos você realiza.": "The more you worry, the less you accomplish.",

# takeout
"Estou cansado demais para cozinhar; vamos pedir comida para viagem.": "I'm too tired to cook; let's get some takeout.",
"Pedimos comida chinesa para viagem para o jantar.": "We ordered Chinese takeout for dinner.",
"É para comer aqui ou para levar?": "Is this for here or takeout?",

# becomes
"Quando o gelo derrete, torna-se água.": "When ice melts, it becomes water.",
"Ele fica muito quieto quando está chateado.": "He becomes very quiet when he is upset.",
"O que antes era uma pequena vila, agora se tornou uma cidade grande.": "What was once a small village has now become a large city.",

# single month
"Ele conseguiu ler dez livros em um único mês.": "He managed to read ten books in a single month.",
"O lucro da empresa dobrou em um único mês.": "The company's profit doubled in a single month.",
"Você realmente consegue aprender um idioma em um único mês?": "Can you really learn a language in a single month?",


# guardrails
"As defensas metálicas na rodovia impediram que o carro saísse da pista.": "The guardrails on the highway prevented the car from going off the road.",
"Barreiras de proteção financeiras, como um orçamento, ajudam você a se manter no caminho certo.": "Financial guardrails, like a budget, help you stay on track.",
"Sem barreiras de proteção éticas, uma empresa pode facilmente tomar decisões ruins.": "Without ethical guardrails, a company can easily make poor decisions.",

# got
"Eu consegui um novo emprego na semana passada.": "I got a new job last week.",
"Ele se cansou de esperar e foi embora.": "He got tired of waiting and left.",
"Você entendeu a piada?": "Have you got the joke?",

# harder
"Você precisa se esforçar mais se quiser ter sucesso.": "You need to work harder if you want to succeed.",
"Este quebra-cabeça é muito mais difícil do que parece.": "This puzzle is much harder than it looks.",
"Quanto mais você espera, mais difícil se torna.": "The longer you wait, the harder it becomes.",

# chill
"Vamos apenas relaxar em casa hoje à noite e assistir a um filme.": "Let's just chill at home tonight and watch a movie.",
"Havia um frio no ar esta manhã.": "There was a chill in the air this morning.",
"Você precisa gelar o vinho antes de servi-lo.": "You need to chill the wine before serving it.",

# sweater
"Ela usava um suéter de lã aconchegante para se manter aquecida.": "She wore a cozy wool sweater to keep warm.",
"Acho que deixei meu suéter na sua casa.": "I think I left my sweater at your house.",
"Este suéter encolheu na lavagem.": "This sweater shrank in the wash.",

# guess
"Acho que deveríamos sair agora.": "I guess we should leave now.",
"Você consegue adivinhar quantas moedas há no pote?": "Can you guess how many coins are in the jar?",
"Meu melhor palpite é que o projeto será concluído na próxima semana.": "My best guess is that the project will be finished next week.",

# Wealthy
"Ele vem de uma família muito rica.": "He comes from a very wealthy family.",
"Indivíduos ricos frequentemente contratam consultores financeiros.": "Wealthy individuals often hire financial advisors.",
"A nação é rica em recursos naturais.": "The nation is wealthy in natural resources.",

# ratio
"A relação dívida/renda é uma métrica chave para os credores.": "The debt-to-income ratio is a key metric for lenders.",
"A proporção de alunos para professores na escola é de 15 para 1.": "The ratio of students to teachers in the school is 15 to 1.",
"Para fazer o concreto perfeito, você precisa da proporção correta de ingredientes.": "To make the perfect concrete, you need the correct ratio of ingredients.",

# screaming
"As crianças gritavam de empolgação na montanha-russa.": "The children were screaming with excitement on the rollercoaster.",
"Ele acordou gritando de um pesadelo.": "He woke up screaming from a nightmare.",
"Os pneus cantavam enquanto o carro acelerava bruscamente.": "The tires were screaming as the car sped away.",

# sweating
"Ele suava profusamente após a corrida matinal.": "He was sweating profusely after his morning run.",
"Ela suava de nervosismo antes de sua apresentação.": "She was sweating with nervousness before her presentation.",
"Pare de se preocupar com os detalhes; não é importante.": "Stop sweating the small stuff; it's not important.",

# poorly fitting suit
"O candidato ao emprego causou uma má impressão com seu terno mal ajustado.": "The job candidate made a poor impression in his poorly fitting suit.",
"Ele se sentia desconfortável e autoconsciente no terno mal ajustado.": "He felt uncomfortable and self-conscious in the poorly fitting suit.",
"Um alfaiate pode consertar um terno mal ajustado para que pareça muito melhor.": "A tailor can fix a poorly fitting suit to make it look much better.",

# through
"Nós dirigimos através de um longo túnel.": "We drove through a long tunnel.",
"Ela conseguiu o emprego por meio de trabalho duro e determinação.": "She got the job through hard work and determination.",
"Eu ainda não terminei; estou apenas na metade do livro.": "I'm not finished yet; I'm only halfway through the book.",

# investors
"A startup está buscando novos investidores para financiar sua expansão.": "The startup is seeking new investors to fund its expansion.",
"O bom desempenho da empresa agradou os investidores.": "The company's good performance pleased the investors.",
"Investidores-anjo fornecem capital para empresas em estágio inicial.": "Angel investors provide capital for early-stage businesses.",

# sit still
"A criança energética achou difícil ficar quieta na aula.": "The energetic child found it hard to sit still in class.",
"Eu não consigo ficar parado quando estou nervoso.": "I can't sit still when I'm nervous.",
"Apenas fique quieto por um momento para que eu possa tirar a foto.": "Just sit still for a moment so I can take the picture.",

# sitting around picking stocks
"Ele acha que investir é apenas ficar à toa escolhendo ações, mas é muito mais complexo.": "He thinks investing is just about sitting around picking stocks, but it's much more complex.",
"Em vez de ficar à toa escolhendo ações, você deveria ter uma estratégia diversificada.": "Instead of sitting around picking stocks, you should have a diversified strategy.",
"Você não ficará rico apenas ficando à toa escolhendo ações com base em manchetes.": "You won't get wealthy by just sitting around picking stocks based on news headlines.",


# guardrails
"As defensas metálicas na rodovia impediram que o carro saísse da pista.": "The guardrails on the highway prevented the car from going off the road.",
"Barreiras de proteção financeiras, como um orçamento, ajudam você a se manter no caminho certo.": "Financial guardrails, like a budget, help you stay on track.",
"Sem barreiras de proteção éticas, uma empresa pode facilmente tomar decisões ruins.": "Without ethical guardrails, a company can easily make poor decisions.",

# got
"Eu consegui um novo emprego na semana passada.": "I got a new job last week.",
"Ele se cansou de esperar e foi embora.": "He got tired of waiting and left.",
"Você entendeu a piada?": "Have you got the joke?",

# harder
"Você precisa se esforçar mais se quiser ter sucesso.": "You need to work harder if you want to succeed.",
"Este quebra-cabeça é muito mais difícil do que parece.": "This puzzle is much harder than it looks.",
"Quanto mais você espera, mais difícil se torna.": "The longer you wait, the harder it becomes.",

# chill
"Vamos apenas relaxar em casa hoje à noite e assistir a um filme.": "Let's just chill at home tonight and watch a movie.",
"Havia um frio no ar esta manhã.": "There was a chill in the air this morning.",
"Você precisa gelar o vinho antes de servi-lo.": "You need to chill the wine before serving it.",

# sweater
"Ela usava um suéter de lã aconchegante para se manter aquecida.": "She wore a cozy wool sweater to keep warm.",
"Acho que deixei meu suéter na sua casa.": "I think I left my sweater at your house.",
"Este suéter encolheu na lavagem.": "This sweater shrank in the wash.",

# guess
"Acho que deveríamos sair agora.": "I guess we should leave now.",
"Você consegue adivinhar quantas moedas há no pote?": "Can you guess how many coins are in the jar?",
"Meu melhor palpite é que o projeto será concluído na próxima semana.": "My best guess is that the project will be finished next week.",

# Wealthy
"Ele vem de uma família muito rica.": "He comes from a very wealthy family.",
"Indivíduos ricos frequentemente contratam consultores financeiros.": "Wealthy individuals often hire financial advisors.",
"A nação é rica em recursos naturais.": "The nation is wealthy in natural resources.",

# ratio
"A relação dívida/renda é uma métrica chave para os credores.": "The debt-to-income ratio is a key metric for lenders.",
"A proporção de alunos para professores na escola é de 15 para 1.": "The ratio of students to teachers in the school is 15 to 1.",
"Para fazer o concreto perfeito, você precisa da proporção correta de ingredientes.": "To make the perfect concrete, you need the correct ratio of ingredients.",

# screaming
"As crianças gritavam de empolgação na montanha-russa.": "The children were screaming with excitement on the rollercoaster.",
"Ele acordou gritando de um pesadelo.": "He woke up screaming from a nightmare.",
"Os pneus cantavam enquanto o carro acelerava bruscamente.": "The tires were screaming as the car sped away.",

# sweating
"Ele suava profusamente após a corrida matinal.": "He was sweating profusely after his morning run.",
"Ela suava de nervosismo antes de sua apresentação.": "She was sweating with nervousness before her presentation.",
"Pare de se preocupar com os detalhes; não é importante.": "Stop sweating the small stuff; it's not important.",

# poorly fitting suit
"O candidato ao emprego causou uma má impressão com seu terno mal ajustado.": "The job candidate made a poor impression in his poorly fitting suit.",
"Ele se sentia desconfortável e autoconsciente no terno mal ajustado.": "He felt uncomfortable and self-conscious in the poorly fitting suit.",
"Um alfaiate pode consertar um terno mal ajustado para que pareça muito melhor.": "A tailor can fix a poorly fitting suit to make it look much better.",

# through
"Nós dirigimos através de um longo túnel.": "We drove through a long tunnel.",
"Ela conseguiu o emprego por meio de trabalho duro e determinação.": "She got the job through hard work and determination.",
"Eu ainda não terminei; estou apenas na metade do livro.": "I'm not finished yet; I'm only halfway through the book.",

# investors
"A startup está buscando novos investidores para financiar sua expansão.": "The startup is seeking new investors to fund its expansion.",
"O bom desempenho da empresa agradou os investidores.": "The company's good performance pleased the investors.",
"Investidores-anjo fornecem capital para empresas em estágio inicial.": "Angel investors provide capital for early-stage businesses.",

# sit still
"A criança energética achou difícil ficar quieta na aula.": "The energetic child found it hard to sit still in class.",
"Eu não consigo ficar parado quando estou nervoso.": "I can't sit still when I'm nervous.",
"Apenas fique quieto por um momento para que eu possa tirar a foto.": "Just sit still for a moment so I can take the picture.",

# sitting around picking stocks
"Ele acha que investir é apenas ficar à toa escolhendo ações, mas é muito mais complexo.": "He thinks investing is just about sitting around picking stocks, but it's much more complex.",
"Em vez de ficar à toa escolhendo ações, você deveria ter uma estratégia diversificada.": "Instead of sitting around picking stocks, you should have a diversified strategy.",
"Você não ficará rico apenas ficando à toa escolhendo ações com base em manchetes.": "You won't get wealthy by just sitting around picking stocks based on news headlines.",


# glued
"As crianças ficaram grudadas na televisão a tarde toda.": "The kids were glued to the television all afternoon.",
"Ele permaneceu grudado na tela do computador, terminando o relatório.": "He remained glued to his computer screen, finishing the report.",
"Os olhos dela estavam grudados na última página do romance de mistério.": "Her eyes were glued to the last page of the mystery novel.",

# early
"Eu tenho que acordar cedo para uma reunião amanhã.": "I have to wake up early for a meeting tomorrow.",
"É melhor chegar cedo para conseguir um bom lugar.": "It's best to arrive early to get a good seat.",
"É muito cedo para tomar uma decisão final.": "It's too early to make a final decision.",

# stay
"Acho que vou ficar em casa hoje à noite.": "I think I will stay home tonight.",
"Por quanto tempo você vai ficar no Brasil?": "How long will you stay in Brazil?",
"Por favor, permaneça na linha; sua chamada é importante para nós.": "Please stay on the line; your call is important to us.",

# boring
"O filme foi tão chato que eu adormeci.": "The movie was so boring that I fell asleep.",
"Ele tem um trabalho muito entediante, preenchendo formulários o dia todo.": "He has a very boring job, filling out forms all day.",
"A palestra foi longa e incrivelmente entediante.": "The lecture was long and incredibly boring.",

# heavy lifting
"Deixe as máquinas fazerem o trabalho pesado.": "Let the machines do the heavy lifting.",
"Em nossa equipe, os desenvolvedores seniores fazem o trabalho pesado em projetos complexos.": "In our team, the senior developers do the heavy lifting on complex projects.",
"O software de automação faz a maior parte do trabalho pesado para nós agora.": "The automation software does most of the heavy lifting for us now.",

# aim
"Nosso principal objetivo é aumentar a satisfação do cliente.": "Our main aim is to increase customer satisfaction.",
"Mire no alvo e então atire.": "Aim for the target and then shoot.",
"Nosso objetivo é fornecer o melhor serviço possível.": "We aim to provide the best service possible.",

# yet
"Eu ainda não terminei minha lição de casa.": "I haven't finished my homework yet.",
"Já é hora de ir?": "Is it time to go yet?",
"Ele é jovem, no entanto é muito sábio.": "He is young, yet he is very wise.",

# stressed
"Ela tem estado muito estressada com os exames.": "She's been very stressed about her exams.",
"Não se estresse; nós temos bastante tempo.": "Don't get stressed; we have plenty of time.",
"Ele sempre fica estressado quando tem que falar em público.": "He always gets stressed when he has to speak in public.",

# over
"O pássaro voou por cima da casa.": "The bird flew over the house.",
"O jogo acabou, nós perdemos.": "The game is over; we lost.",
"Vamos discutir isso durante o jantar.": "Let's discuss this over dinner.",

# mortgage
"Eles contrataram uma hipoteca de 30 anos para comprar a casa.": "They took out a 30-year mortgage to buy their house.",
"Pagar a prestação mensal da hipoteca é a maior despesa deles.": "Making the monthly mortgage payment is their biggest expense.",
"Ela espera quitar sua hipoteca antecipadamente.": "She hopes to pay off her mortgage early.",

# advisor
"Você deveria consultar um consultor financeiro antes de fazer grandes investimentos.": "You should consult a financial advisor before making large investments.",
"Meu orientador acadêmico me ajudou a escolher minhas matérias.": "My academic advisor helped me choose my courses.",
"Ele trabalha como consultor político sênior para o governo.": "He works as a senior policy advisor to the government.",

# hiring
"Nossa empresa está contratando novos desenvolvedores de software.": "Our company is hiring new software developers.",
"O processo de contratação pode levar várias semanas.": "The hiring process can take several weeks.",
"Ela é responsável pela contratação e treinamento de novos funcionários.": "She is responsible for hiring and training new staff.",

# guidance
"Estou procurando por alguma orientação sobre minha carreira.": "I'm looking for some guidance on my career path.",
"Sob sua orientação, a equipe concluiu o projeto com sucesso.": "Under his guidance, the team completed the project successfully.",
"A orientação dos pais é recomendada para este filme.": "Parental guidance is recommended for this movie.",

# I cut over here
"Para economizar tempo, vou pular direto para esta parte e mostrar os resultados finais.": "To save time, I'll cut over here and show you the final results.",
"A apresentação estava longa, então eu disse: 'deixe-me apenas pular aqui para o ponto principal'.": "The presentation was getting long, so I said, 'let me just cut over here to the main point'.",
"Estávamos discutindo o orçamento, e ele interrompeu: 'se eu puder cortar para cá', e mudou o assunto.": "We were on the budget, and he interjected, 'if I can cut over here,' and changed the subject.",

# huge
"Eles moram em uma casa enorme com dez quartos.": "They live in a huge house with ten bedrooms.",
"Esta é uma oportunidade imensa para nossa empresa.": "This is a huge opportunity for our company.",
"Havia uma multidão enorme no show.": "There was a huge crowd at the concert.",


# opposite
"O banco fica no lado oposto da rua.": "The bank is on the opposite side of the street.",
"Meu irmão e eu temos personalidades opostas.": "My brother and I have opposite personalities.",
"Ela fez exatamente o oposto do que eu lhe disse para fazer.": "She did the exact opposite of what I told her to do.",

# utilities
"O aluguel não inclui o custo dos serviços básicos como água e eletricidade.": "The rent does not include the cost of utilities like water and electricity.",
"Você precisa pagar a conta de luz e água até o final do mês.": "You need to pay the utilities bill by the end of the month.",
"A cidade está investindo na modernização de seus serviços públicos.": "The city is investing in upgrading its public utilities.",

# fees
"O banco cobra taxas altas para transferências internacionais.": "The bank charges high fees for international transfers.",
"As mensalidades da universidade aumentaram este ano.": "University tuition fees have increased this year.",
"Sempre leia o contrato para verificar se há taxas ocultas.": "Always read the contract to check for hidden fees.",

# straight
"Siga reto por duas quadras e depois vire à esquerda.": "Go straight ahead for two blocks and then turn left.",
"Ela me olhou diretamente nos olhos e disse a verdade.": "She looked me straight in the eye and told the truth.",
"Trabalhei por oito horas seguidas sem intervalo.": "I worked for eight hours straight without a break.",

# anymore
"Eu não moro mais lá.": "I don't live there anymore.",
"Ela não quer mais falar sobre isso.": "She doesn't want to talk about it anymore.",
"Ele não aguenta mais a pressão.": "He can't handle the pressure anymore.",

# concept
"O conceito de infinito é difícil de compreender.": "The concept of infinity is difficult to grasp.",
"Ela apresentou um novo conceito de design para o projeto.": "She presented a new design concept for the project.",
"É um conceito simples, mas muito eficaz.": "It's a simple concept, but very effective.",

# brings
"A nova estação traz um clima mais quente.": "The new season brings warmer weather.",
"Ele sempre traz uma atitude positiva para a equipe.": "He always brings a positive attitude to the team.",
"O que te traz a São Paulo?": "What brings you to São Paulo?",

# reach
"Mantenha o remédio fora do alcance das crianças.": "Keep the medicine out of the reach of children.",
"Esperamos alcançar nossa meta de vendas até o final do trimestre.": "We hope to reach our sales goal by the end of the quarter.",
"Não consigo alcançar a prateleira de cima.": "I can't reach the top shelf.",

# alone puts
"Apenas economizar 10% da sua renda já o coloca à frente da maioria.": "Saving 10% of your income alone puts you ahead of most people.",
"Sua experiência na indústria, por si só, o coloca em uma posição forte para o trabalho.": "His experience in the industry alone puts him in a strong position for the job.",
"O fato de você ter aparecido, por si só, já o coloca em minha boa graça.": "The fact that you showed up alone puts you in my good graces.",

# free yet
"Ele quitou suas dívidas, mas ainda não se sente livre.": "He has paid off his debts, but he doesn't feel free yet.",
"O software ainda não é gratuito, mas há uma versão de teste.": "The software is not free yet, but there is a trial version.",
"Você já está desocupado? Preciso falar com você.": "Are you free yet? I need to talk to you.",

# expenses
"Precisamos acompanhar nossas despesas mensais com mais cuidado.": "We need to track our monthly expenses more carefully.",
"A empresa irá reembolsá-lo por suas despesas de viagem.": "The company will reimburse you for your travel expenses.",
"Morar em uma cidade grande acarreta despesas elevadas.": "Living in a big city comes with high expenses.",

# unapologetically
"Ela vive sua vida sem pedir desculpas e inspira outros a fazerem o mesmo.": "She lives her life unapologetically and inspires others to do the same.",
"O novo carro é assumidamente luxuoso e potente.": "The new car is unapologetically luxurious and powerful.",
"Ele é ambicioso sem rodeios.": "He is unapologetically ambitious.",

# ton
"Eu tenho uma tonelada de trabalho para fazer neste fim de semana.": "I have a ton of work to do this weekend.",
"Esta caixa pesa uma tonelada!": "This box weighs a ton!",
"Muito obrigado pela sua ajuda!": "Thanks a ton for your help!",

# throw
"Não atire pedras na janela.": "Don't throw stones at the window.",
"Vamos dar uma festa de aniversário para ela.": "Let's throw a party for her birthday.",
"Você deveria jogar fora esses sapatos velhos.": "You should throw away those old shoes.",

# worth
"Este vaso antigo vale muito dinheiro.": "This antique vase is worth a lot of money.",
"A vista do topo da montanha vale a subida.": "The view from the top of the mountain is worth the climb.",
"Não vale a pena discutir sobre isso.": "It's not worth arguing about.",


# retirement
"Ele está ansioso pela sua aposentadoria no próximo ano.": "He is looking forward to his retirement next year.",
"Poupar para a aposentadoria é importante para o seu futuro financeiro.": "Saving for retirement is important for your financial future.",
"Eles se mudaram para uma casa menor após a aposentadoria.": "They moved to a smaller house after their retirement.",

# renting
"Estamos alugando um apartamento no centro da cidade.": "We are renting an apartment in the city center.",
"Alugar pode ser mais flexível do que comprar uma casa.": "Renting can be more flexible than buying a house.",
"Ela está alugando um carro para sua viagem de fim de semana.": "She is renting a car for her weekend trip.",

# stare
"É falta de educação encarar as pessoas.": "It's rude to stare at people.",
"Ela só conseguia encarar, incrédula, a cena diante dela.": "She could only stare in disbelief at the scene before her.",
"Ele frequentemente ficava a encarar a janela, perdido em pensamentos.": "He would often stare out the window, lost in thought.",

# keeps them trapped
"O medo do fracasso os mantém presos em suas zonas de conforto.": "The fear of failure keeps them trapped in their comfort zones.",
"A dívida com juros altos é um ciclo que os mantém presos financeiramente.": "High-interest debt is a cycle that keeps them trapped financially.",
"A incapacidade dela de tomar uma decisão os mantém presos num estado de incerteza.": "Her inability to make a decision keeps them trapped in a state of uncertainty.",

# leaky roof
"Precisamos consertar o telhado com goteira antes da próxima chuva.": "We need to fix the leaky roof before the next rainstorm.",
"Um telhado com goteira pode causar danos significativos a uma casa.": "A leaky roof can cause significant damage to a house.",
"O proprietário prometeu consertar o telhado com goteira semanas atrás.": "The landlord promised to repair the leaky roof weeks ago.",

# lever
"Puxe esta alavanca para ligar a máquina.": "Pull this lever to start the machine.",
"Usar dívida pode ser uma alavanca financeira poderosa, mas é arriscado.": "Using debt can be a powerful financial lever, but it's risky.",
"Ele usou um pé de cabra como alavanca para abrir o caixote.": "He used a crowbar as a lever to open the crate.",

# care
"Você deveria cuidar melhor de si mesmo.": "You should take better care of yourself.",
"Ela escolheu suas palavras com muito cuidado.": "She chose her words with great care.",
"Eu não me importo com o que as outras pessoas pensam.": "I don't care what other people think.",

# therapist
"Conversar com um terapeuta a ajudou a lidar com sua ansiedade.": "Talking to a therapist helped her deal with her anxiety.",
"Ele decidiu procurar um terapeuta para melhorar sua saúde mental.": "He decided to see a therapist to improve his mental health.",
"Um fisioterapeuta pode ajudá-lo a se recuperar de uma lesão.": "A physical therapist can help you recover from an injury.",

# might mean
"Uma queda repentina nas vendas pode significar que precisamos mudar nossa estratégia.": "A sudden drop in sales might mean we need to change our strategy.",
"Não tenho certeza do que esta mensagem de erro pode significar.": "I'm not sure what this error message might mean.",
"O silêncio dele pode significar que ele discorda.": "His silence might mean he disagrees.",

# hire
"Precisamos contratar um novo assistente para o departamento.": "We need to hire a new assistant for the department.",
"Você alugou um carro para sua viagem?": "Did you hire a car for your trip?",
"Muitas vezes é melhor contratar um especialista do que fazer você mesmo.": "It's often better to hire an expert than to do it yourself.",

# holding back
"O medo do fracasso a está impedindo de abrir o próprio negócio.": "Fear of failure is holding her back from starting her own business.",
"Ele estava segurando as lágrimas durante o discurso emocionante.": "He was holding back tears during the emotional speech.",
"Não se contenha; diga-me o que você realmente pensa.": "Don't hold back; tell me what you really think.",

# attend
"Você vai participar da conferência na próxima semana?": "Are you going to attend the conference next week?",
"Todos os funcionários são obrigados a participar do treinamento de segurança.": "All employees are required to attend the safety training.",
"Ela estava doente demais para frequentar a escola.": "She was too sick to attend school.",

# crossover
"O sucesso 'crossover' da banda foi popular entre os fãs de rock e pop.": "The band's crossover hit was popular with both rock and pop fans.",
"O ponto de virada financeiro é quando a renda dos seus investimentos cobre suas despesas.": "The financial crossover point is when your investment income covers your expenses.",
"Este veículo 'crossover' combina o espaço de um SUV com o conforto de um sedã.": "This crossover vehicle combines the space of an SUV with the comfort of a sedan.",

# splurge
"Ela decidiu esbanjar em uma bolsa de grife após receber uma promoção.": "She decided to splurge on a designer handbag after getting a promotion.",
"Tudo bem esbanjar de vez em quando, contanto que você se planeje para isso.": "It's okay to splurge once in a while, as long as you budget for it.",
"Eles esbanjaram em um jantar chique no aniversário de casamento.": "They splurged on a fancy dinner for their anniversary.",

# changes
"O novo gerente fez muitas mudanças no departamento.": "The new manager made a lot of changes to the department.",
"A vida é cheia de mudanças inesperadas.": "Life is full of unexpected changes.",
"Ele muda de ideia o tempo todo.": "He changes his mind all the time.",


# left behind
"Ele se preocupava em ser deixado para trás por seus colegas de classe.": "He worried about being left behind by his classmates.",
"Não fique para trás; acompanhe as últimas tecnologias.": "Don't get left behind; keep up with the latest technology.",
"Ela percebeu que havia deixado sua carteira para trás no restaurante.": "She realized she had left her wallet behind at the restaurant.",

# constraint
"A maior restrição do projeto é o orçamento limitado.": "The biggest constraint on the project is the limited budget.",
"Temos que trabalhar dentro das limitações da lei.": "We have to work within the constraints of the law.",
"O tempo é uma grande restrição para a maioria das pessoas.": "Time is a major constraint for most people.",

# hitting
"A empresa está atingindo todas as suas metas de vendas este ano.": "The company is hitting all its sales targets this year.",
"Atingir a independência financeira é um objetivo para muitos.": "Hitting financial independence is a goal for many.",
"A tempestade deve atingir a costa amanhã de manhã.": "The storm is expected to be hitting the coast tomorrow morning.",

# milestone
"Formar-se na faculdade foi um marco importante em sua vida.": "Graduating from college was a major milestone in her life.",
"Alcançar 1 milhão de usuários é um marco significativo para nosso aplicativo.": "Reaching 1 million users is a significant milestone for our app.",
"O projeto tem vários marcos que precisamos cumprir.": "The project has several milestones that we need to meet.",

# pace
"Ela caminhava em um ritmo lento por causa da perna machucada.": "She walked at a slow pace because of her injured leg.",
"O ritmo da mudança tecnológica está se acelerando.": "The pace of technological change is accelerating.",
"Você deve trabalhar no seu próprio ritmo.": "You should work at your own pace.",

# conservative
"Ele fez uma estimativa conservadora do custo do projeto.": "He made a conservative estimate of the project's cost.",
"Uma estratégia de investimento conservadora foca na preservação de capital.": "A conservative investment strategy focuses on preserving capital.",
"O cálculo deles para o cronograma foi bastante conservador.": "Their calculation for the timeline was quite conservative.",

# enough income
"Eles não têm renda suficiente para se qualificar para uma hipoteca.": "They don't have enough income to qualify for a mortgage.",
"Sua atividade paralela está gerando renda suficiente para valer a pena?": "Is your side hustle generating enough income to be worth the time?",
"O objetivo é gerar renda passiva suficiente para cobrir os custos de vida.": "The goal is to generate enough passive income to cover living costs.",

# timeline
"Qual é o cronograma para a conclusão deste projeto?": "What is the timeline for completing this project?",
"A linha do tempo histórica mostrava os eventos-chave da guerra.": "The historical timeline showed the key events of the war.",
"Precisamos nos ater ao cronograma se quisermos lançar na data prevista.": "We need to stick to the timeline if we want to launch on schedule.",

# crossover number
"Uma vez que você sabe seu número de virada, pode criar um plano para alcançá-lo.": "Once you know your crossover number, you can create a plan to reach it.",
"Calcular seu número de virada é o primeiro passo para a independência financeira.": "Calculating your crossover number is the first step toward financial independence.",
"O número de virada dele era menor do que ele esperava.": "His crossover number was lower than he expected.",

# plug
"Você poderia ligar o abajur na tomada para mim?": "Could you plug in the lamp for me?",
"Use este tampão para impedir que a água escorra.": "Use this plug to stop the water from draining.",
"O autor aproveitou a oportunidade para promover seu novo livro.": "The author took the opportunity to plug his new book.",

# below
"A temperatura caiu abaixo de zero na noite passada.": "The temperature dropped below freezing last night.",
"Por favor, veja o gráfico abaixo para mais detalhes.": "Please see the chart below for more details.",
"O desempenho dele foi bem abaixo da média.": "His performance was well below average.",

# break down
"Meu carro decidiu quebrar no meio da rodovia.": "My car decided to break down in the middle of the highway.",
"Vamos decompor o problema em partes menores e gerenciáveis.": "Let's break down the problem into smaller, manageable parts.",
"Ela pode desabar e chorar se você lhe contar as más notícias.": "She might break down and cry if you tell her the bad news.",

# fully cover
"Seu salário cobrirá totalmente todas as suas despesas mensais?": "Will your salary fully cover all your monthly expenses?",
"A apólice de seguro não cobre totalmente os procedimentos odontológicos.": "The insurance policy does not fully cover dental procedures.",
"Certifique-se de que a tinta consiga cobrir totalmente a cor antiga.": "Make sure the paint can fully cover the old color.",

# sabbatical
"O professor está de licença sabática por um ano para escrever um livro.": "The professor is on sabbatical for a year to write a book.",
"Tirar um período sabático pode ser uma ótima maneira de recarregar as energias.": "Taking a sabbatical can be a great way to recharge.",
"A empresa dela oferece um período sabático remunerado após dez anos de serviço.": "Her company offers a paid sabbatical after ten years of service.",

# brunch
"Vamos sair para um brunch no domingo com alguns amigos.": "We're going out for brunch on Sunday with some friends.",
"O hotel serve um delicioso buffet de brunch até as 14h.": "The hotel serves a delicious brunch buffet until 2 PM.",
"Qual é a sua comida favorita para o brunch?": "What's your favorite food to have for brunch?",


# Crossover Point
"O 'Crossover Point' é quando sua renda passiva excede suas despesas.": "The Crossover Point is when your passive income exceeds your expenses.",
"Muitos no movimento FIRE se esforçam para alcançar seu 'Crossover Point'.": "Many in the FIRE movement strive to reach their Crossover Point.",
"Atingir o 'Crossover Point' não significa que você tem que se aposentar, mas que pode.": "Reaching the Crossover Point doesn't mean you have to retire, but that you can.",

# themselves
"Eles mesmos construíram a casa, sem nenhuma ajuda.": "They built the house themselves, without any help.",
"As crianças já conseguem se vestir sozinhas.": "The children can dress themselves now.",
"Pessoas que se exercitam regularmente muitas vezes sentem-se melhor consigo mesmas.": "People who exercise regularly often feel better about themselves.",

# oat
"Eu gostaria de um café com leite de aveia, por favor.": "I'd like an oat milk latte, please.",
"O farelo de aveia é uma boa fonte de fibra.": "Oat bran is a good source of fiber.",
"Ela começa todo dia com uma tigela de mingau de aveia.": "She starts every day with a bowl of oat porridge.",

# feel guilty
"Você não deveria se sentir culpado por tirar um dia para descansar.": "You shouldn't feel guilty for taking a day off to rest.",
"Eu sempre me sinto culpado quando como muito chocolate.": "I always feel guilty when I eat too much chocolate.",
"Não há razão para se sentir culpado por uma decisão que você teve que tomar.": "There's no reason to feel guilty about a decision you had to make.",

# lettuce
"Eu quero uma salada com alface e tomate extras.": "I'll have a salad with extra lettuce and tomatoes.",
"Não se esqueça de lavar a alface antes de fazer a salada.": "Don't forget to wash the lettuce before making the salad.",
"Ele colocou uma fatia de peru e um pouco de alface em seu sanduíche.": "He put a slice of turkey and some lettuce in his sandwich.",

# hard-earned
"Ele decidiu investir seu dinheiro suado no mercado de ações.": "He decided to invest his hard-earned money in the stock market.",
"Ela se presenteou com umas férias com suas economias suadas.": "She treated herself to a vacation with her hard-earned savings.",
"Não desperdice sua reputação arduamente conquistada com um erro bobo.": "Don't waste your hard-earned reputation on a foolish mistake.",

# however
"Eu entendo seu ponto; no entanto, eu não concordo.": "I understand your point; however, I don't agree.",
"Ele é um ótimo atleta. Contudo, ele tem um histórico de lesões.": "He is a great athlete. However, he has a history of injuries.",
"Você pode organizar os móveis como quiser.": "You can arrange the furniture however you like.",

# track
"É importante acompanhar suas despesas para gerenciar seu orçamento.": "It's important to track your expenses to manage your budget.",
"A encomenda está a caminho para ser entregue amanhã.": "The package is on track to be delivered tomorrow.",
"O trem corre sobre um trilho de metal.": "The train runs on a metal track.",

# outlined
"O CEO delineou o plano da empresa para os próximos cinco anos.": "The CEO outlined the company's plan for the next five years.",
"As regras estão claramente descritas no manual do funcionário.": "The rules are clearly outlined in the employee handbook.",
"Ela esboçou os principais argumentos de sua redação na introdução.": "She outlined the main arguments of her essay in the introduction.",

# roughly
"O projeto levará aproximadamente três meses para ser concluído.": "The project will take roughly three months to complete.",
"Havia cerca de 200 pessoas no evento.": "There were roughly 200 people at the event.",
"Ele me tratou com aspereza quando fiz a pergunta.": "He treated me roughly when I asked the question.",

# guilt-free
"Esta deliciosa sobremesa é totalmente livre de culpa, feita com adoçantes naturais.": "This delicious dessert is completely guilt-free, made with natural sweeteners.",
"Automatizar suas economias permite gastos sem culpa em outras coisas.": "Automating your savings allows for guilt-free spending on other things.",
"Ela queria desfrutar de umas férias sem culpa, então terminou todo o trabalho com antecedência.": "She wanted to enjoy a guilt-free vacation, so she finished all her work beforehand.",

# whatever's left
"Depois de pagar as contas, você pode gastar o que sobrar com diversão.": "After paying the bills, you can spend whatever's left on fun.",
"Vou apenas comer o que sobrou na geladeira para o jantar.": "I'll just have whatever's left in the fridge for dinner.",
"Ele investe uma quantia fixa e economiza o que sobra.": "He invests a fixed amount and saves whatever's left.",

# carrying
"Ela estava carregando uma sacola de compras pesada.": "She was carrying a heavy bag of groceries.",
"A loja agora vende uma nova linha de produtos orgânicos.": "The store is now carrying a new line of organic products.",
"Manter um saldo devedor no cartão de crédito pode ser muito caro.": "Carrying a balance on your credit card can be very expensive.",

# incurring
"Ao pagar com atraso, você está incorrendo em taxas adicionais.": "By paying late, you are incurring additional fees.",
"A empresa evitou contrair dívidas ao financiar o projeto com seu próprio caixa.": "The company avoided incurring debt by funding the project with its own cash.",
"Ele viajou de forma barata, incorrendo em despesas mínimas.": "He traveled cheaply, incurring minimal expenses.",

# upcoming
"Ela está muito animada com suas próximas férias.": "She is very excited about her upcoming vacation.",
"A empresa anunciou seus resultados para o próximo trimestre.": "The company announced its results for the upcoming quarter.",
"Você está preparado para a prova que está por vir?": "Are you prepared for the upcoming exam?",


# high-yield
"Ela investiu em uma conta poupança de alto rendimento para ganhar mais juros.": "She invested in a high-yield savings account to earn more interest.",
"Títulos de alto rendimento oferecem retornos maiores, mas também vêm com maior risco.": "High-yield bonds offer higher returns but also come with greater risk.",
"Encontrar um investimento seguro e de alto rendimento é o objetivo de muitos poupadores.": "Finding a safe, high-yield investment is the goal for many savers.",

# tax-free
"Títulos municipais frequentemente fornecem renda isenta de impostos.": "Municipal bonds often provide tax-free income.",
"O prêmio que ela ganhou na loteria era totalmente livre de impostos.": "The prize she won in the lottery was completely tax-free.",
"Ele está procurando maneiras isentas de impostos para poupar para a educação de seu filho.": "He is looking for tax-free ways to save for his child's education.",

# Depot
"Preciso ir à Home Depot para comprar tinta e ferramentas.": "I need to go to Home Depot to buy some paint and tools.",
"O terminal de ônibus está localizado na periferia da cidade.": "The bus depot is located on the outskirts of the city.",
"O principal depósito de suprimentos do exército era fortemente vigiado.": "The army's main supply depot was heavily guarded.",

# flexible
"Yoga pode ajudá-lo a se tornar mais flexível.": "Yoga can help you become more flexible.",
"Meu horário de trabalho é flexível, então posso começar meu dia mais cedo ou mais tarde.": "My work schedule is flexible, so I can start my day earlier or later.",
"Precisamos de um plano flexível que possa se adaptar a circunstâncias mutáveis.": "We need a flexible plan that can adapt to changing circumstances.",

# portion
"Ela comeu uma pequena porção do bolo.": "She ate a small portion of the cake.",
"Uma parte significativa do nosso orçamento é alocada para marketing.": "A significant portion of our budget is allocated to marketing.",
"Ele decidiu doar uma parte de seus ganhos para a caridade.": "He decided to donate a portion of his winnings to charity.",

# paid
"Ela foi bem paga por seu trabalho como consultora.": "She was well paid for her work as a consultant.",
"Eu já paguei a conta de eletricidade.": "I have already paid the electricity bill.",
"A empresa oferece 20 dias de férias remuneradas por ano.": "The company offers 20 days of paid vacation per year.",

# switched
"Eu mudei meu curso de engenharia para economia.": "I switched my major from engineering to economics.",
"Ela mudou o canal da TV para assistir ao noticiário.": "She switched the TV channel to watch the news.",
"Ele mudou para um provedor de internet diferente para ter uma conexão melhor.": "He switched to a different internet provider for a better connection.",

# truthfully
"Você pode dizer, com sinceridade, que fez o seu melhor?": "Can you truthfully say that you did your best?",
"Ele respondeu a todas as perguntas com veracidade.": "He answered all the questions truthfully.",
"Sinceramente, não sou um grande fã de comida apimentada.": "Truthfully, I'm not a big fan of spicy food.",

# sponsor
"Um grande banco é o patrocinador oficial do evento.": "A major bank is the official sponsor of the event.",
"Você estaria disposto a me patrocinar para a maratona beneficente?": "Would you be willing to sponsor me for the charity marathon?",
"A empresa irá patrocinar seu pedido de visto.": "The company will sponsor his visa application.",

# money left
"Sobrou algum dinheiro no orçamento para novos equipamentos?": "Is there any money left in the budget for new equipment?",
"Depois de pagar todas as suas dívidas, sobrou-lhe muito pouco dinheiro.": "After paying all his debts, he had very little money left.",
"Deveríamos usar o dinheiro que sobrou para fazer uma pequena viagem.": "We should use the money left over to go on a small trip.",

# freaking day
"Eu estive trabalhando neste relatório o maldito dia inteiro.": "I've been working on this report the whole freaking day.",
"Ela me liga todo santo dia com um novo problema.": "She calls me every freaking day with a new problem.",
"Não acredito que perdi minhas chaves de novo neste dia desgraçado.": "I can't believe I lost my keys again on this freaking day.",

# whole
"Ele comeu a pizza inteira sozinho.": "He ate the whole pizza by himself.",
"A família inteira foi de férias junta.": "The whole family went on vacation together.",
"Essa é uma história completamente diferente.": "That's a whole other story.",

# retire
"Meus pais planejam se aposentar no próximo ano e viajar pelo mundo.": "My parents plan to retire next year and travel the world.",
"Com que idade a maioria das pessoas se aposenta no seu país?": "At what age do most people retire in your country?",
"Estou cansado, então acho que vou me recolher para a cama mais cedo esta noite.": "I'm tired, so I think I'll retire to bed early tonight.",

# stacking
"Ele estava empilhando caixas no armazém.": "He was stacking boxes in the warehouse.",
"Acumular bons hábitos ao longo do tempo leva a ótimos resultados.": "Stacking good habits over time leads to great results.",
"As probabilidades estão se acumulando contra nós, mas não vamos desistir.": "The odds are stacking against us, but we won't give up.",

# Head over
"Acesse nosso site para ver a nova coleção.": "Head over to our website to see the new collection.",
"Por que você не dá um pulo na minha casa depois do trabalho?": "Why don't you head over to my place after work?",
"Vou dar uma passada na loja para pegar um pouco de leite.": "I'm going to head over to the store to pick up some milk.",


# Facet
"Cada faceta do problema requer uma consideração cuidadosa.": "Each facet of the problem requires careful consideration.",
"As facetas do diamante brilhavam à luz.": "The diamond's facets sparkled in the light.",
"A personalidade dela tem muitas facetas diferentes.": "Her personality has many different facets.",

# provides
"A escola fornece almoço para todos os seus alunos.": "The school provides lunch for all its students.",
"Este relatório fornece uma análise detalhada do mercado.": "This report provides a detailed analysis of the market.",
"A nova lei oferece melhor proteção aos consumidores.": "The new law provides better protection for consumers.",

# providing guidance across retirement
"A empresa é especializada em fornecer orientação através das fases da aposentadoria.": "The firm specializes in providing guidance across retirement stages.",
"Fornecer orientação durante a aposentadoria é um serviço chave para consultores financeiros.": "Providing guidance across retirement is a key service for financial advisors.",
"O site deles é um ótimo recurso para fornecer orientação ao longo da aposentadoria.": "Their website is a great resource for providing guidance across retirement.",

# launchpad
"A cidade espera que o novo polo tecnológico seja uma plataforma de lançamento para startups inovadoras.": "The city hopes the new tech hub will be a launchpad for innovative startups.",
"O foguete está pronto na plataforma de lançamento.": "The rocket is ready on the launchpad.",
"Este estágio pode ser uma plataforma de lançamento para uma carreira de sucesso.": "This internship can be a launchpad for a successful career.",

# tens
"Havia dezenas de milhares de pessoas no festival.": "There were tens of thousands of people at the festival.",
"Ele leu dezenas de livros sobre o assunto.": "He has read tens of books on the subject.",
"O projeto custará dezenas de milhões de dólares.": "The project will cost tens of millions of dollars.",

# common
"É comum sentir-se nervoso antes de uma apresentação.": "It's common to feel nervous before a presentation.",
"Partilhamos um interesse comum em música clássica.": "We share a common interest in classical music.",
"Estes pássaros são muito comuns nesta região.": "These birds are very common in this region.",

# affordable flat membership fee
"A academia atrai muitos clientes com sua taxa de adesão fixa e acessível.": "The gym attracts many clients with its affordable flat membership fee.",
"Eles oferecem consultoria financeira por uma taxa de adesão fixa e acessível.": "They offer financial advice for an affordable flat membership fee.",
"Este serviço cobra uma taxa de adesão fixa e acessível, sem custos ocultos.": "This service charges an affordable flat membership fee with no hidden costs.",

# devouring
"O leão faminto estava devorando sua presa.": "The hungry lion was devouring its prey.",
"Ela estava devorando o livro, incapaz de largá-lo.": "She was devouring the book, unable to put it down.",
"O fogo estava devorando o antigo prédio de madeira.": "The fire was devouring the old wooden building.",

# advice
"Posso te dar um conselho?": "Can I give you a piece of advice?",
"Ele seguiu o conselho de seu advogado e aceitou o acordo.": "He followed his lawyer's advice and accepted the settlement.",
"Meu conselho é que você poupe pelo menos 10% da sua renda.": "My advice is to save at least 10% of your income.",

# bricks
"A casa foi construída com tijolos vermelhos.": "The house was built with red bricks.",
"Você precisa construir uma base sólida, tijolo por tijolo.": "You need to lay a solid foundation, brick by brick.",
"Ele sentiu como se tivesse batido numa parede de tijolos com sua pesquisa.": "He felt like he had hit a brick wall with his research.",

# estate planning
"Um bom planejamento sucessório garante que seus bens sejam distribuídos conforme seus desejos.": "Good estate planning ensures your assets are distributed according to your wishes.",
"O planejamento sucessório envolve criar um testamento e estabelecer fundos fiduciários.": "Estate planning involves creating a will and setting up trusts.",
"Eles contrataram um advogado para ajudá-los com o planejamento sucessório.": "They hired a lawyer to help them with their estate planning.",

# clarity
"Ele explicou o tópico complexo com grande clareza.": "He explained the complex topic with great clarity.",
"Os óculos novos deram a ela uma clareza de visão muito melhor.": "The new glasses gave her much better clarity of vision.",
"Precisamos de mais clareza sobre os objetivos do projeto antes de prosseguir.": "We need more clarity on the project's goals before we proceed.",

# alone
"Ela gosta de morar sozinha.": "She enjoys living alone.",
"Ele se sentiu completamente sozinho na nova cidade.": "He felt all alone in the new city.",
"Deixe-me em paz, preciso me concentrar.": "Leave me alone; I need to concentrate.",

# wrote
"Ela escreveu uma carta para sua avó.": "She wrote a letter to her grandmother.",
"Ele anotou o número de telefone em um pedaço de papel.": "He wrote down the phone number on a piece of paper.",
"Quem escreveu esta canção incrível?": "Who wrote this amazing song?",

# income
"Sua renda mensal não é suficiente para cobrir todas as suas despesas.": "His monthly income is not enough to cover all his expenses.",
"Ela tem uma segunda fonte de renda de seu imóvel alugado.": "She has a second source of income from her rental property.",
"O governo planeja aumentar os impostos sobre os assalariados de alta renda.": "The government plans to raise taxes on high-income earners.",


# already
"Eu já terminei minha lição de casa.": "I have already finished my homework.",
"Quando cheguei, a festa já tinha começado.": "When I arrived, the party had already started.",
"Já são 10 da noite? O tempo voa.": "Is it 10 PM already? Time flies.",

# slightly cheaper
"A marca genérica é um pouco mais barata que a marca famosa.": "The generic brand is slightly cheaper than the name brand.",
"Encontramos um voo que era ligeiramente mais barato em um site diferente.": "We found a flight that was slightly cheaper on a different website.",
"Se você comprar a granel, geralmente sai um pouco mais barato.": "If you buy in bulk, it's often slightly cheaper.",

# downsize
"Depois que os filhos saíram de casa, eles decidiram se mudar para um apartamento menor.": "After their children left home, they decided to downsize to a smaller apartment.",
"A empresa teve que reduzir seu quadro de funcionários para cortar custos.": "The company had to downsize its workforce to cut costs.",
"Reduzir seus pertences pode ser uma experiência muito libertadora.": "Downsizing your possessions can be a very liberating experience.",

# household
"A família inteira ajuda nas tarefas domésticas.": "The entire household helps with the chores.",
"Qual é a renda familiar total de vocês?": "What is your total household income?",
"Produtos de limpeza são uma despesa doméstica comum.": "Cleaning supplies are a common household expense.",

# on energy
"Estamos tentando economizar dinheiro em energia usando lâmpadas de LED.": "We are trying to save money on energy by using LED bulbs.",
"O governo está oferecendo descontos para residências que economizam no consumo de energia.": "The government is offering rebates for homes that save on energy consumption.",
"Grande parte do orçamento da fábrica é gasta com energia.": "A large portion of the factory's budget is spent on energy.",

# gross
"O lucro bruto da empresa aumentou 15% no ano passado.": "The company's gross profit increased by 15% last year.",
"Sua renda anual bruta é superior a 100.000 dólares.": "His gross annual income is over $100,000.",
"A diferença entre o salário bruto e o líquido é significativa.": "The difference between gross and net pay is significant.",

# nitpick
"Meu chefe tende a criticar cada pormenor do meu trabalho.": "My boss tends to nitpick every detail of my work.",
"Não vamos procurar pelo em ovo sobre detalhes menores e vamos focar na questão principal.": "Let's not nitpick over minor details and focus on the main issue.",
"Ele é um bom editor, mas às vezes pode ser um pouco implicante.": "He's a good editor, but he can nitpick a bit too much.",

# avoid
"Você deve evitar comer muito açúcar.": "You should avoid eating too much sugar.",
"Ele pegou uma rota diferente para evitar o trânsito.": "He took a different route to avoid the traffic.",
"Ela tem evitado minhas ligações o dia todo.": "She has been avoiding my calls all day.",

# spending more
"Precisamos parar de gastar mais do que ganhamos.": "We need to stop spending more than we earn.",
"Eles estão passando mais tempo juntos como uma família.": "They are spending more time together as a family.",
"A empresa está gastando mais em marketing este ano.": "The company is spending more on marketing this year.",

# snarky
"Ela é conhecida por seus comentários sarcásticos e senso de humor espirituoso.": "She is known for her snarky comments and witty sense of humor.",
"Não precisa ser sarcástico; eu estava apenas fazendo uma pergunta.": "There's no need to be snarky; I was just asking a question.",
"Ele postou uma resposta irônica nas redes sociais.": "He posted a snarky reply on social media.",

# also
"Eu gosto de pizza, e também gosto de massa.": "I like pizza, and I also like pasta.",
"Ela é uma cantora talentosa e também uma ótima atriz.": "She is a talented singer and also a great actress.",
"Ele não só terminou a corrida, mas também estabeleceu um novo recorde.": "He not only finished the race but also set a new record.",

# grocery
"Preciso ir ao supermercado para comprar leite e ovos.": "I need to go to the grocery store to buy milk and eggs.",
"Nossa conta de supermercado semanal está ficando mais cara.": "Our weekly grocery bill is getting more expensive.",
"Ele fez uma lista de compras antes de ir às compras.": "He made a grocery list before going shopping.",

# bread
"Você gostaria de uma fatia de pão com sua sopa?": "Would you like a slice of bread with your soup?",
"Ela assa o próprio pão todo fim de semana.": "She bakes her own bread every weekend.",
"Ele é o principal provedor da família.": "He is the main breadwinner of the family."
}

# %%
# Out:
# Eu me sinto muito melhor depois de uma boa noite de sono. I feel much better after a good night's sleep.

# %%
from app.toolkit.utils.generate_card import CardCreator

# 1. Crie uma instância do CardCreator com a categoria e subcategoria desejadas
#    (o usuário escolheria estas opções)
card_creator_finance = CardCreator(category="youtube_videos", subcategory="finance")

# 2. Itere sobre seu dicionário e use o método create_card
for pt_phrase, en_phrase in palavras.items():
    try:
        # Você pode passar dados extras como kwargs, se necessário
        card_creator_finance.create_card(
            pergunta_pt=pt_phrase,
            traducao_en=en_phrase,
            uso_da_linguagem="Frase extraída de vídeo sobre finanças.",
            status="ok"
        )
    except ValueError as e:
        print(f"Erro ao criar card para '{en_phrase}': {e}")
    except Exception as e:
        print(f"Ocorreu um erro inesperado: {e}")
# Out:
# Card criado com sucesso em: database\extract_data_video\data\extracted_data\personalized\data_organize\youtube_videos\finance\i_feel_much_better_after_a_good_nights_sleep\text_v2.json
# Card criado com sucesso em: database\extract_data_video\data\extracted_data\personalized\data_organize\youtube_videos\finance\you_should_find_a_better_way_to_organize_your_files\text_v2.json
# Card criado com sucesso em: database\extract_data_video\data\extracted_data\personalized\data_organize\youtube_videos\finance\the_new_software_version_is_better_than_the_old_one\text_v2.json
# Card criado com sucesso em: database\extract_data_video\data\extracted_data\personalized\data_organize\youtube_videos\finance\i_thought_the_movie_would_be_boring_but_it_was_actually_very_good\text_v2.json
# Card criado com sucesso em: database\extract_data_video\data\extracted_data\personalized\data_organize\youtube_videos\finance\he_looks_young_but_hes_actually_over_forty_years_old\text_v2.json
# ...
