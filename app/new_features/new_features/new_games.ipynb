# %% [markdown]
# 🎮 1. Jogo de Associação (Match Game)
# - Mostra uma imagem + áudio.
# - O jogador escolhe entre várias traduções (em português ou inglês).
# - Pode ser com cronômetro para aumentar a dificuldade.
#
# ---
#
#
#
# ---
#
# 🗣️ 3. Jogo de Pronúncia
# - O jogo toca o áudio da palavra em inglês.
# - O jogador deve repetir e o sistema reconhece a pronúncia com bibliotecas como speech_recognition.
# - Dá feedback de acerto ou erro.
#
# ---
#
# ✏️ 4. Complete a Palavra
# - Mostra a imagem e/ou o áudio.
# - O jogador escreve a palavra em inglês (ou português).
# - Feedback visual com letras corretas e incorretas (estilo Wordle).
#
# ---
#
# 🧩 5. Quebra-Cabeça de Imagens
# - A imagem da palavra é cortada em partes.
# - Cada parte só é revelada ao acertar perguntas sobre aquela palavra (tradução, uso em frase, etc.).
#
# ---
#
# 🔊 6. Jogo do Ditado
# - Toca o áudio da palavra em inglês.
# - O jogador digita o que ouviu.
# - Ajuda na escuta e ortografia.
#
# ---
#
# 🖼️ 7. Arraste e Solte (Drag and Drop)
# - Palavras e imagens separadas.
# - O jogador arrasta a palavra para a imagem correta (ou vice-versa).
#
# ---
#
# 🎯 8. Jogo de Memória (Memory Game)
# - Cartas viradas: imagens e traduções (ou imagens e áudios).
# - O jogador tem que combinar pares corretos.
#
# ---
#
# 📖 9. Histórias Interativas
# - Pequenas histórias com lacunas.
# - O jogador escolhe as palavras corretas (baseadas no seu vocabulário salvo) para completar.
#
# ---
#
# 📦 10. Categorias Rápidas
# - Mostra uma palavra e o jogador deve escolher rapidamente a qual categoria ela pertence (útil se você tem subcategorias como “compras online”, “culinária”, etc.).
#
#
#
# 🧠 13. Jogo de Verdadeiro ou Falso
# - Mostra uma palavra em português e a correspondente em inglês.
# - O jogador responde se a tradução está correta.
# - Pode usar imagem ou áudio como suporte.
#
# ---
#
# 🧳 14. Jogo de Viagem (Adventure)
# - Um mapa com lugares ou situações (ex: mercado, aeroporto, hotel).
# - O jogador interage com objetos/personagens que dizem palavras.
# - Deve responder corretamente para “prosseguir”.
#
# ---
#
# 🔤 15. Spelling Bee
# - Ouve o áudio e deve digitar a palavra corretamente.
# - Pode ter dicas visuais como a imagem ou categoria.
#
# ---
#
# 🎲 16. Jogo de Categorias
# - Mostra várias palavras e o jogador deve arrastar cada uma para sua categoria (ex: roupas, compras, animais).
# - Pode usar cor ou som para feedback imediato.
#
# ---
#
# 📸 17. O que Está na Imagem?
# - Mostra uma imagem.
# - O jogador responde digitando a palavra em inglês.
# - Pode usar reconhecimento de imagem no futuro como bônus.
#
# ---
#
# ⏱️ 18. Desafio Relâmpago
# - Tem 60 segundos para traduzir o máximo de palavras possível.
# - Mostra texto, áudio ou imagem aleatoriamente.
#
# ---
#
# 📦 19. Montar a Frase
# - Dadas várias palavras em inglês, o jogador deve formar frases corretas.
# - Usa vocabulário aprendido.
#
# ---
#
# 📚 20. Use em uma Frase
# - Mostra a imagem/áudio.
# - O jogador deve criar uma frase com aquela palavra.
# - Pode usar GPT localmente para corrigir/avaliar a frase futuramente.
#
# ---
#
# 🧭 21. Caminho das Palavras
# - Tipo Candy Crush, onde o jogador liga palavras que pertencem à mesma categoria ou que estão corretas com base em imagens/áudio.
#
# ---
#
# 🎯 22. Tiro ao Alvo (Vocabulary Shooter)
# - Mostra palavras em inglês descendo a tela.
# - O jogador atira apenas nas que são a tradução correta de uma palavra em português (ou vice-versa).
#
# ---
#
# 🎧 23. Ditado Interativo
# - Toca o áudio em inglês.
# - O jogador deve escrever a palavra que ouviu.
# - Feedback visual e auditivo sobre acertos ou erros.
#
# ---
#
# 🗣️ 24. Repita Comigo (Pronúncia)
# - O jogo toca o áudio.
# - O jogador repete e o sistema avalia (pode começar só como exercício livre).
# - Posteriormente pode usar bibliotecas de reconhecimento de voz.
#
# ---
#
# 👁️‍🗨️ 25. Memória Auditiva
# - Mostra cartas viradas. Ao clicar, ouve um áudio.
# - Deve encontrar os pares com o mesmo significado (ex: "account" e "a conta").
#
# ---
#
# 📦 26. Classifique a Imagem
# - Mostra uma imagem e várias palavras.
# - Jogador escolhe a que representa corretamente a imagem.
#
# ---
#
# 🔁 27. Inverter Traduções
# - Mostra a palavra em inglês, o jogador deve escolher entre várias imagens a correta.
# - Alternar entre tradução PT→EN e EN→PT.
#
# ---
#
# 🕹️ 28. Role e Responda (Estilo RPG)
# - Personagem caminha por um cenário.
# - Encontra desafios que só são superados com vocabulário certo (tradução, escrita ou escolha da imagem correta).
#
# ---
#
# 🎲 29. Roleta de Palavras
# - Uma roleta gira e para em uma categoria.
# - Jogador responde uma pergunta sobre aquela categoria (imagem, tradução ou áudio).
#
# ---
#
# 🧮 30. Quantas Palavras Você Lembra?
# - Dado um tema, o jogador digita o máximo de palavras que lembra em inglês dentro de um tempo.
#
# ---
#
# 🧊 31. Quebra-Gelo Diário
# - Um minijogo diferente por dia, com 1 palavra nova e 3 desafios rápidos (tradução, imagem, escrita).
#
# ---
#
# 🗂️ 32. Organize as Palavras
# - Recebe uma lista de palavras embaralhadas (ex: por categoria errada).
# - Arrasta cada uma para sua categoria correta.
#
# ---
#
# 🔓 33. Desbloqueie o Cofre
# - Um "cofre" só abre se o jogador acertar as 3 traduções certas seguidas (com imagens e áudios como dicas).
#
# ---
#
# 💡 34. Quem Sou Eu? (Descritivo)
# - Mostra uma definição ou dica em inglês.
# - O jogador escolhe a palavra certa com base na imagem/áudio.
#
# ---
#
# 📆 35. Calendário do Vocabulário
# - Todo dia, um novo desafio com palavras novas ou revisão de palavras anteriores.
# - Pode incluir pontuação para manter engajamento.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
os.chdir("..")
os.chdir("..")
# os.chdir("..")

# !dir
# Out:
#  O volume na unidade C � OS
#  O N�mero de S�rie do Volume � A2FB-FA56
#
#  Pasta de c:\pyprojects\fast-english
#
# 05/05/2025  08:24    <DIR>          .
# 05/05/2025  15:26    <DIR>          ..
# 23/04/2025  08:12    <DIR>          .github
# 05/05/2025  08:24             4.368 .gitignore
# 23/04/2025  08:36    <DIR>          .venv
# 23/04/2025  08:12             8.923 anki_cards.txt
# 05/05/2025  08:24    <DIR>          app
# 05/05/2025  08:24    <DIR>          database
# 23/04/2025  08:12    <DIR>          docs
# 23/04/2025  17:13             2.172 extarct_words.ipynb
# 05/05/2025  08:24    <DIR>          extract_data_video
# 24/04/2025  13:55            14.146 feets_tkinter.ipynb
# 05/05/2025  08:24               776 game_data_.csv
# 05/05/2025  08:24               994 game_data_teste_1.csv
# 24/04/2025  11:43    <DIR>          gui
# 23/04/2025  08:12                20 mkdocs.yml
# 23/04/2025  08:12            42.816 output.mp3
# 28/04/2025  08:06           403.736 poetry.lock
# ...

# %%
import os
import json
from pathlib import Path

from app.utils.data_loader import DataLoader

# %%
DATA_PATH = Path("database/vocabulary/words/data_organize")
SUBCATEGORY_NAME = "compras_online"


data_loader = DataLoader(base_path=DATA_PATH)
list_data_words = data_loader.get_all_words(subcategory_name=SUBCATEGORY_NAME)

# list_data_words

# %% [markdown]
# ---
#
# 🧩 12. Palavras Embaralhadas (Word Scramble)
# - Mostra a imagem ou o áudio.
# - A palavra em inglês aparece com letras embaralhadas.
# - O jogador organiza as letras na ordem correta.
#
# ---

# %%
import tkinter as tk
from tkinter import messagebox
from PIL import Image, ImageTk
import random
import os

class WordScrambleGame:
    def __init__(self, master, list_data_words):
        self.master = master
        self.master.title("Word Scramble - Palavras Embaralhadas")
        self.words_data = list_data_words
        self.current_word_data = None

        # Widgets
        self.image_label = tk.Label(master)
        self.image_label.pack(pady=10)

        self.scrambled_label = tk.Label(master, text="", font=("Helvetica", 24))
        self.scrambled_label.pack(pady=10)

        self.entry = tk.Entry(master, font=("Helvetica", 18))
        self.entry.pack(pady=5)

        self.submit_button = tk.Button(master, text="Verificar", command=self.check_answer)
        self.submit_button.pack(pady=10)

        self.feedback_label = tk.Label(master, text="", font=("Helvetica", 14))
        self.feedback_label.pack(pady=5)

        self.next_button = tk.Button(master, text="Próxima Palavra", command=self.load_new_word)
        self.next_button.pack(pady=10)

        self.load_new_word()

    def load_new_word(self):
        self.entry.delete(0, tk.END)
        self.feedback_label.config(text="")

        self.current_word_data = random.choice(self.words_data)
        word = self.current_word_data["text_eng"]

        scrambled = list(word)
        while True:
            random.shuffle(scrambled)
            if "".join(scrambled).lower() != word.lower():
                break

        self.scrambled_label.config(text=" ".join(scrambled))

        # Carrega imagem
        img_path = self.current_word_data["image_figure"]
        if os.path.exists(img_path):
            img = Image.open(img_path).resize((200, 200))
            self.photo = ImageTk.PhotoImage(img)
            self.image_label.config(image=self.photo)
        else:
            self.image_label.config(image="", text="Imagem não encontrada")

    def check_answer(self):
        user_input = self.entry.get().strip().lower()
        correct = self.current_word_data["text_eng"].lower()
        if user_input == correct:
            self.feedback_label.config(text="✅ Correto!", fg="green")
        else:
            self.feedback_label.config(text=f"❌ Errado. Resposta certa: {correct}", fg="red")

if __name__ == "__main__":
    from pathlib import Path

    DATA_PATH = Path("database/vocabulary/words/data_organize")
    SUBCATEGORY_NAME = "compras_online"

    loader = DataLoader(base_path=DATA_PATH)
    words = loader.get_all_words(subcategory_name=SUBCATEGORY_NAME)

    if len(words) < 4:
        print("Base de dados insuficiente!")
    else:
        root = tk.Tk()
        app = WordScrambleGame(root, words)
        root.mainloop()
        root.destroy()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# Cell In[8], line 82
#      80 app = WordScrambleGame(root, words)
#      81 root.mainloop()
# ---> 82 root.destroy()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\Lib\tkinter\__init__.py:2390, in Tk.destroy(self)
#    2387 """Destroy this and all descendants widgets. This will
#    2388 end the application of this Tcl interpreter."""
#    2389 for c in list(self.children.values()): c.destroy()
# -> 2390 self.tk.call('destroy', self._w)
#    2391 Misc.destroy(self)
#    2392 global _default_root
#
# TclError: can't invoke "destroy" command: application has been destroyed

# %% [markdown]
# 🧠 2. Quiz de Múltipla Escolha
# - Exibe uma palavra em inglês.
# - Mostra 4 imagens, o jogador deve escolher a que representa corretamente a palavra.
# - Pode ter pontuação e progresso.

# %%
import tkinter as tk
from tkinter import messagebox
from PIL import Image, ImageTk
import os
import random
import json
from pathlib import Path


class QuizGame:
    def __init__(self, master, data):
        self.master = master
        self.master.title("Quiz de Vocabulário")
        self.data = data
        self.score = 0
        self.current_question = {}
        
        self.label = tk.Label(master, text="", font=("Arial", 20))
        self.label.pack(pady=20)

        self.image_buttons = []
        self.frame = tk.Frame(master)
        self.frame.pack()

        for i in range(4):
            btn = tk.Button(self.frame, command=lambda idx=i: self.check_answer(idx))
            btn.grid(row=i//2, column=i%2, padx=10, pady=10)
            self.image_buttons.append(btn)

        self.next_question()

    def next_question(self):
        self.current_choices = random.sample(self.data, 4)
        self.current_question = random.choice(self.current_choices)

        self.label.config(text=self.current_question["text_eng"].capitalize())

        for idx, item in enumerate(self.current_choices):
            image = Image.open(item["image_figure"]).resize((150, 150))
            photo = ImageTk.PhotoImage(image)
            self.image_buttons[idx].config(image=photo)
            self.image_buttons[idx].image = photo  # evitar que seja coletado pelo garbage collector

    def check_answer(self, index):
        selected = self.current_choices[index]
        if selected["text_eng"] == self.current_question["text_eng"]:
            messagebox.showinfo("Correto!", "Você acertou!")
            self.score += 1
        else:
            messagebox.showerror("Errado!", f"Resposta correta: {self.current_question['text_pt_br']}")

        self.next_question()

# ------------ Execução ------------
if __name__ == "__main__":
    from pathlib import Path

    DATA_PATH = Path("database/vocabulary/words/data_organize")
    SUBCATEGORY_NAME = "compras_online"

    loader = DataLoader(base_path=DATA_PATH)
    words = loader.get_all_words(subcategory_name=SUBCATEGORY_NAME)

    if len(words) < 4:
        print("Base de dados insuficiente!")
    else:
        root = tk.Tk()
        app = QuizGame(root, words)
        root.mainloop()
        root.destroy()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# Cell In[6], line 70
#      68 app = QuizGame(root, words)
#      69 root.mainloop()
# ---> 70 root.destroy()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\Lib\tkinter\__init__.py:2390, in Tk.destroy(self)
#    2387 """Destroy this and all descendants widgets. This will
#    2388 end the application of this Tcl interpreter."""
#    2389 for c in list(self.children.values()): c.destroy()
# -> 2390 self.tk.call('destroy', self._w)
#    2391 Misc.destroy(self)
#    2392 global _default_root
#
# TclError: can't invoke "destroy" command: application has been destroyed
