# %%
import os

os.chdir("..")
os.chdir("..")
os.chdir("..")

# %%
import tkinter as tk
from pathlib import Path
from app.utils.data_loader import DataLoader
import re
from tkinter import simpledialog
import json
from tqdm import tqdm

class TextReaderApp(tk.Frame):
    def __init__(self, parent=None, **kwargs):
        super().__init__(parent, **kwargs)
        self.known_words = self.prep_data_match_word()

        scrollbar = tk.Scrollbar(self)
        scrollbar.pack(side="right", fill="y")

        self.text_widget = tk.Text(self, wrap="word", font=("Arial", 14), yscrollcommand=scrollbar.set)
        self.text_widget.pack(expand=True, fill="both")

        scrollbar.config(command=self.text_widget.yview)

        self.send_button = tk.Button(self, text="Enviar", command=self._process_text)
        self.send_button.pack(pady=(0, 5))

        self.send_button = tk.Button(self, text="Criar banco de dados com palavras", command=self._save_data_words)
        self.send_button.pack(pady=(0, 5))

        self.btn_listar_conhecidas = tk.Button(self, text="Listar Palavras Conhecidas no Texto", command=self._listar_palavras_conhecidas)
        self.btn_listar_conhecidas.pack(pady=(0, 5))


        self.btn_remover_conhecidas = tk.Button(self, text="Remover Palavras Conhecidas do Texto", command=self._remover_palavras_conhecidas_do_texto)
        self.btn_remover_conhecidas.pack(pady=(0, 5))

        self.btn_remover_desconhecidas = tk.Button(self, text="Remover Palavras Desconhecidas do Texto", command=self._remover_palavras_desconhecidas_do_texto)
        self.btn_remover_desconhecidas.pack(pady=(0, 5))

        self.btn_palavras_unicas = tk.Button(self, text="Manter Apenas Palavras Únicas", command=self._manter_palavras_unicas)
        self.btn_palavras_unicas.pack(pady=(0, 5))


        # Coluna do stats_label
        # self.stats_label = tk.Label(self, justify="left", font=("Arial", 12), anchor="nw")
        # self.stats_label.grid(row=0, column=1, padx=10, sticky="nw")  # Alinha no topo à esquerda

        self.stats_label = tk.Label(self, justify="left", font=("Arial", 12), anchor="nw")
        self.stats_label.pack(side="left", padx=10, anchor="n")

        self.list_data_words_in_text = []
        self._configure_tags()

    def prep_data_match_word(self):
        """
        Função otimizada que prepara os dados para a busca de palavras.
        """
        data_loader_words = DataLoader(base_path="database/extract_data_video/data/extracted_data/words/data_organize")
        data_loader_phrases = DataLoader(base_path="database/extract_data_video/data/extracted_data/phrases/data_organize")

        # Junta as listas diretamente
        lista_total = data_loader_words.get_all_words() + data_loader_phrases.get_all_words()

        # Cria os pares (palavra, caminho) com list comprehension
        set_data_words = [
            {"word": word, "path": Path(info["path"])}
            for info in tqdm(lista_total, desc="Processando palavras")
            for word in Path(info["path"]).stem.replace("_", " ").lower().split()
        ]

        return set_data_words

    def find_match_word(self, word, set_deta_words):
        """
        Função que procura por palavras que possuem a tag "tag" no nome.
        """
        word = word.lower()
        
        list_match_word = []
        for data_word in set_deta_words:
            word_name = data_word.get("word", "")

            if word == word_name:
                list_match_word.append(data_word)
        
        return list_match_word
        

    def _save_data_words(self):
        file_name = simpledialog.askstring("Salvar palavras", "Digite o nome do arquivo (sem extensão):")
        
        if not file_name:
            return  # Usuário cancelou

        MAX_POR_PALAVRA = 2
        contador_por_palavra = {}
        save_words = []

        for dict_match_word in self.list_data_words_in_text:
            palavra = dict_match_word["word"].lower()
            caminho = str(dict_match_word["path"])

            if contador_por_palavra.get(palavra, 0) < MAX_POR_PALAVRA:
                save_words.append(caminho)
                contador_por_palavra[palavra] = contador_por_palavra.get(palavra, 0) + 1

        save_path = Path("database/vocabulary/save_words") / f"{file_name}.json"
        save_path.parent.mkdir(parents=True, exist_ok=True)

        with open(save_path, 'w', encoding="utf-8") as json_file:
            json.dump(save_words, json_file, ensure_ascii=False, indent=4)

        print(f"Palavras salvas em: {save_path}")

    def _listar_palavras_conhecidas(self):
        # Cria janela popup
        popup = tk.Toplevel(self)
        popup.title("Palavras Conhecidas no Texto")

        listbox = tk.Listbox(popup, selectmode=tk.SINGLE, width=50, height=20)
        listbox.pack(padx=10, pady=10)

        # Usar set para evitar repetições
        self.palavras_conhecidas_unicas = sorted(set(
            data['word'] for data in self.list_data_words_in_text
        ))

        for word in self.palavras_conhecidas_unicas:
            listbox.insert(tk.END, word)

        btn_remover = tk.Button(popup, text="Remover Palavra Selecionada", command=lambda: self._remover_palavra_base(listbox))
        btn_remover.pack(pady=(0, 10))

    def _remover_palavra_base(self, listbox):
        selection = listbox.curselection()
        if not selection:
            return

        index = selection[0]
        palavra = self.palavras_conhecidas_unicas[index]

        # Remove todas as ocorrências dessa palavra na base
        self.known_words = [w for w in self.known_words if w["word"] != palavra]

        # Atualiza a listbox
        listbox.delete(index)

        print(f"Palavra removida da base: {palavra}")

    def _manter_palavras_unicas(self):
        text = self.text_widget.get("1.0", tk.END)
        seen = set()
        result = []

        for match in re.finditer(r"[a-zA-Z]+", text):
            word = match.group()
            key = word.lower()

            if key not in seen:
                seen.add(key)
                result.append(word)

        texto_resultante = " ".join(result)
        self.text_widget.delete("1.0", tk.END)
        self.text_widget.insert("1.0", texto_resultante)

    def _remover_palavras_conhecidas_do_texto(self):
        texto = self.text_widget.get("1.0", tk.END)
        palavras_para_remover = []

        for match in re.finditer(r"[a-zA-Z]+", texto):
            palavra = match.group()
            if self.find_match_word(palavra, self.known_words):
                palavras_para_remover.append(palavra)

        for palavra in set(palavras_para_remover):
            # Remove apenas a palavra completa
            texto = re.sub(rf'\b{re.escape(palavra)}\b', '', texto)

        # Limpa espaços extras e finaliza
        texto = re.sub(r'\s+', ' ', texto).strip()

        self.text_widget.delete("1.0", tk.END)
        self.text_widget.insert("1.0", texto)
        self._process_text()


    def _remover_palavras_desconhecidas_do_texto(self):
        texto = self.text_widget.get("1.0", tk.END)
        palavras_para_remover = []

        for match in re.finditer(r"[a-zA-Z]+", texto):
            palavra = match.group()
            if not self.find_match_word(palavra, self.known_words):
                palavras_para_remover.append(palavra)

        for palavra in set(palavras_para_remover):
            # Remove somente a palavra isolada (com limites de palavra)
            texto = re.sub(rf'\b{re.escape(palavra)}\b', '', texto)

        # Remove espaços duplos e linhas em branco
        texto = re.sub(r'\s+', ' ', texto).strip()

        self.text_widget.delete("1.0", tk.END)
        self.text_widget.insert("1.0", texto)
        self._process_text()

    def _configure_tags(self):
        self.text_widget.tag_config("green", foreground="green")
        self.text_widget.tag_config("gray", foreground="gray")

    def _process_text(self):
        self._clear_tags()
        text = self.text_widget.get("1.0", tk.END)
        self.total_words = self.known_words_count = 0
        self.list_data_words_in_text = []

        for match in re.finditer(r"[a-zA-Z]+", text):
            word = match.group()
            start, end = match.start(), match.end()
            self.total_words += 1

            match_data = self.find_match_word(word, self.known_words)
            if match_data:
                self.known_words_count += 1
                self.list_data_words_in_text.extend(match_data)
                tag = "green"
            else:
                tag = "gray"

            self.text_widget.tag_add(tag, f"1.0+{start}c", f"1.0+{end}c")

        self._show_statistics()

    def _clear_tags(self):
        self.text_widget.tag_remove("green", "1.0", tk.END)
        self.text_widget.tag_remove("gray", "1.0", tk.END)

    def _show_statistics(self):
        total = self.total_words
        known = self.known_words_count
        unknown = total - known
        percent = (known / total * 100) if total else 0

        stats_text = (
            f"Total de palavras: {total}\n"
            f"Conhecidas: {known}\n"
            f"Desconhecidas: {unknown}\n"
            f"Compreensão: {percent:.1f}%"
        )
        self.stats_label.config(text=stats_text)


if __name__ == "__main__":
    try:
        root = tk.Tk()
        root.title("Leitura de Texto")
        app = TextReaderApp(root)
        app.pack(expand=True, fill="both")

        # Texto inicial (opcional)
        example_text = """How many-teste pieces you retrieve from your RAG system affects the result."""
        app.text_widget.insert("1.0", example_text)
        root.mainloop()
    except Exception as e:
        print(f"Erro: {e}")
    finally:
        root.destroy()
# Out:
# Processando palavras: 100%|██████████| 10829/10829 [00:00<00:00, 65952.24it/s]
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# Cell In[18], line 265
#     263     print(f"Erro: {e}")
#     264 finally:
# --> 265     root.destroy()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\Lib\tkinter\__init__.py:2390, in Tk.destroy(self)
#    2387 """Destroy this and all descendants widgets. This will
#    2388 end the application of this Tcl interpreter."""
#    2389 for c in list(self.children.values()): c.destroy()
# -> 2390 self.tk.call('destroy', self._w)
#    2391 Misc.destroy(self)
#    2392 global _default_root
#
# TclError: can't invoke "destroy" command: application has been destroyed

# %%
from pathlib import Path
from tqdm import tqdm  # se quiser ver progresso
import time


def prep_data_match_word():
    """
    Função otimizada que prepara os dados para a busca de palavras.
    """
    data_loader_words = DataLoader(base_path="database/extract_data_video/data/extracted_data/words/data_organize")
    data_loader_phrases = DataLoader(base_path="database/extract_data_video/data/extracted_data/phrases/data_organize")

    # Junta as listas diretamente
    lista_total = data_loader_words.get_all_words() + data_loader_phrases.get_all_words()

    # Cria os pares (palavra, caminho) com list comprehension
    set_data_words = [
        {"word": word, "path": Path(info["path"])}
        for info in tqdm(lista_total, desc="Processando palavras")
        for word in Path(info["path"]).stem.replace("_", " ").lower().split()
    ]

    return set_data_words


set_data_words = prep_data_match_word()
# Out:
# Processando palavras: 100%|██████████| 10829/10829 [00:00<00:00, 39182.47it/s]

# %%
match_word
# Out:
# [{'word': 'aberrant',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/aberrant')},
#  {'word': 'admirable',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/admirable')},
#  {'word': 'amazing',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/amazing')},
#  {'word': 'antique',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/antique')},
#  {'word': 'artistic',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/artistic')},
#  {'word': 'brief',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/brief')},
#  {'word': 'classical',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/classical')},
#  {'word': 'comic',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/comic')},
#  {'word': 'complex',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/complex')},
#  {'word': 'confusing',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/confusing')},
#  {'word': 'constructive',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/constructive')},
#  {'word': 'convincing',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/convincing')},
#  {'word': 'cultural',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/cultural')},
#  {'word': 'distinguished',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/distinguished')},
#  {'word': 'diverse',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/diverse')},
#  {'word': 'dubious',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/dubious')},
#  {'word': 'eccentric',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/eccentric')},
#  {'word': 'exceptional',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/exceptional')},
#  {'word': 'expressive',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/expressive')},
#  {'word': 'extraordinary',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/extraordinary')},
#  {'word': 'futuristic',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/futuristic')},
#  {'word': 'historic',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/historic')},
#  {'word': 'illogical',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/illogical')},
#  {'word': 'impressive',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/impressive')},
#  {'word': 'intuitive',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/intuitive')},
#  {'word': 'logical',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/logical')},
#  {'word': 'meaningless',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/meaningless')},
#  {'word': 'notable',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/notable')},
#  {'word': 'nplic',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/nplic')},
#  {'word': 'original',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/original')},
#  {'word': 'overrated',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/overrated')},
#  {'word': 'paradoxical',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/paradoxical')},
#  {'word': 'progressive',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/progressive')},
#  {'word': 'promising',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/promising')},
#  {'word': 'provocative',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/provocative')},
#  {'word': 'realistic',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/realistic')},
#  {'word': 'recent',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/recent')},
#  {'word': 'satirical',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/satirical')},
#  {'word': 'shocking',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/shocking')},
#  {'word': 'splendid',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/splendid')},
#  {'word': 'symbolic',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/symbolic')},
#  {'word': 'tragic',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/tragic')},
#  {'word': 'trivial',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/trivial')},
#  {'word': 'underrated',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/underrated')},
#  {'word': 'unforgettable',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/unforgettable')},
#  {'word': 'vague',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/vague')},
#  {'word': 'authentic',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/authentic')},
#  {'word': 'automatic',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/automatic')},
#  {'word': 'broken',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/broken')},
#  {'word': 'cheap',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/cheap')},
#  {'word': 'closed',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/closed')},
#  {'word': 'durable',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/durable')},
#  {'word': 'elastic',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/elastic')},
#  {'word': 'electric',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/electric')},
#  {'word': 'electronic',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/electronic')},
#  {'word': 'empty',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/empty')},
#  {'word': 'expensive',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/expensive')},
#  {'word': 'fast',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/fast')},
#  {'word': 'fireproof',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/fireproof')},
#  {'word': 'flexible',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/flexible')},
#  {'word': 'fluffy',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/fluffy')},
#  {'word': 'fragile',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/fragile')},
#  {'word': 'full',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/full')},
#  {'word': 'furry',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/furry')},
#  {'word': 'glossy',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/glossy')},
#  {'word': 'golden',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/golden')},
#  {'word': 'hard',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/hard')},
#  {'word': 'heavy',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/heavy')},
#  {'word': 'ideal',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/ideal')},
#  {'word': 'inflexible',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/inflexible')},
#  {'word': 'innovative',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/innovative')},
#  {'word': 'light',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/light')},
#  {'word': 'metallic',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/metallic')},
#  {'word': 'moist',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/moist')},
#  {'word': 'new',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/new')},
#  {'word': 'old',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/old')},
#  {'word': 'open',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/open')},
#  {'word': 'portable',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/portable')},
#  {'word': 'precious',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/precious')},
#  {'word': 'priceless',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/priceless')},
#  {'word': 'qualitative',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/qualitative')},
#  {'word': 'recyclable',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/recyclable')},
#  {'word': 'rusty',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/rusty')},
#  {'word': 'shiny',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/shiny')},
#  {'word': 'silver',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/silver')},
#  {'word': 'slow',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/slow')},
#  {'word': 'soft',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/soft')},
#  {'word': 'sophisticated',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/sophisticated')},
#  {'word': 'sparkling',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/sparkling')},
#  {'word': 'standard',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/standard')},
#  {'word': 'sticky',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/sticky')},
#  {'word': 'translucent',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/translucent')},
#  {'word': 'transparent',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/transparent')},
#  {'word': 'valuable',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/valuable')},
#  {'word': 'waterproof',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/waterproof')},
#  {'word': 'wet',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/wet')},
#  {'word': 'wooden',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/wooden')},
#  {'word': 'additional',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/additional')},
#  {'word': 'analogous',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/analogous')},
#  {'word': 'compact',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/compact')},
#  {'word': 'dense',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/dense')},
#  {'word': 'disproportionate',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/disproportionate')},
#  {'word': 'distant',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/distant')},
#  {'word': 'double',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/double')},
#  {'word': 'dynamic',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/dynamic')},
#  {'word': 'ethnic',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/ethnic')},
#  {'word': 'external',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/external')},
#  {'word': 'extra',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/extra')},
#  {'word': 'extreme',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/extreme')},
#  {'word': 'fixed',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/fixed')},
#  {'word': 'foreign',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/foreign')},
#  {'word': 'immediate',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/immediate')},
#  {'word': 'individual',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/individual')},
#  {'word': 'infinite',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/infinite')},
#  {'word': 'intense',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/intense')},
#  {'word': 'known',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/known')},
#  {'word': 'local',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/local')},
#  {'word': 'luminous',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/luminous')},
#  {'word': 'magnetic',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/magnetic')},
#  {'word': 'main',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/main')},
#  {'word': 'majo',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/majo')},
#  {'word': 'middle',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/middle')},
#  {'word': 'mino',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/mino')},
#  {'word': 'mixed',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/mixed')},
#  {'word': 'multicultural',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/multicultural')},
#  {'word': 'only',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/only')},
#  {'word': 'other',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/other')},
#  {'word': 'powerful',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/powerful')},
#  {'word': 'proportionate',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/proportionate')},
#  {'word': 'regional',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/regional')},
#  {'word': 'relative',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/relative')},
#  {'word': 'special',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/special')},
#  {'word': 'static',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/static')},
#  {'word': 'technical',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/technical')},
#  {'word': 'total',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/total')},
#  {'word': 'traditional',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/traditional')},
#  {'word': 'triple',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/triple')},
#  {'word': 'various',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/various')},
#  {'word': 'abundant',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/abundant')},
#  {'word': 'alternative',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/alternative')},
#  {'word': 'available',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/available')},
#  {'word': 'central',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/central')},
#  {'word': 'commercial',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/commercial')},
#  {'word': 'confidential',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/confidential')},
#  {'word': 'constant',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/constant')},
#  {'word': 'crowded',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/crowded')},
#  {'word': 'destructive',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/destructive')},
#  {'word': 'eastern',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/eastern')},
#  {'word': 'efficient',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/efficient')},
#  {'word': 'endless',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/endless')},
#  {'word': 'equal',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/equal')},
#  {'word': 'excessive',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/excessive')},
#  {'word': 'extraterrestrial',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/extraterrestrial')},
#  {'word': 'final',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/final')},
#  {'word': 'global',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/global')},
#  {'word': 'imaginary',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/imaginary')},
#  {'word': 'insufficient',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/insufficient')},
#  {'word': 'loud',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/loud')},
#  {'word': 'northern',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/northern')},
#  {'word': 'nuclear',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/nuclear')},
#  {'word': 'numerous',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/numerous')},
#  {'word': 'obvious',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/obvious')},
#  {'word': 'partial',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/partial')},
#  {'word': 'public',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/public')},
#  {'word': 'random',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/random')},
#  {'word': 'ready',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/ready')},
#  {'word': 'secret',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/secret')},
#  {'word': 'social',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/social')},
#  {'word': 'southern',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/southern')},
#  {'word': 'strategic',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/strategic')},
#  {'word': 'sufficient',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/sufficient')},
#  {'word': 'technological',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/technological')},
#  {'word': 'typical',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/typical')},
#  {'word': 'unavailable',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/unavailable')},
#  {'word': 'urgent',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/urgent')},
#  {'word': 'western',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/western')},
#  {'word': 'worldwide',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/worldwide')},
#  {'word': 'adjacent',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_3/adjacent')},
#  {'word': 'arbitrary',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_3/arbitrary')},
#  {'word': 'comparative',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_3/comparative')},
#  {'word': 'consecutive',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_3/consecutive')},
#  {'word': 'contradictory',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_3/contradictory')},
#  {'word': 'depressing',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_3/depressing')},
#  {'word': 'detailed',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_3/detailed')},
#  {'word': 'essential',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_3/essential')},
#  {'word': 'existent',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_3/existent')},
#  {'word': 'forgivable',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_3/forgivable')},
#  {'word': 'forgotten',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_3/forgotten')},
#  {'word': 'hidden',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_3/hidden')},
#  {'word': 'home-made',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_3/home-made')},
#  {'word': 'hypothetical',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_3/hypothetical')},
#  {'word': 'inexistent',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_3/inexistent')},
#  {'word': 'integrated',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_3/integrated')},
#  {'word': 'irreversible',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_3/irreversible')},
#  {'word': 'moderate',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_3/moderate')},
#  {'word': 'opposite',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_3/opposite')},
#  {'word': 'optimal',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_3/optimal')},
#  {'word': 'prestigious',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_3/prestigious')},
#  {'word': 'repeated',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_3/repeated')},
#  {'word': 'reversible',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_3/reversible')},
#  {'word': 'routine',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_3/routine')},
#  {'word': 'subordinate',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_3/subordinate')},
#  {'word': 'threatening',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_3/threatening')},
#  {'word': 'tidy',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_3/tidy')},
#  {'word': 'tiring',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_3/tiring')},
#  {'word': 'troublesome',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_3/troublesome')},
#  {'word': 'unforgivable',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_3/unforgivable')},
#  {'word': 'universal',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_3/universal')},
#  {'word': 'vast',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_3/vast')},
#  {'word': 'vital',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_3/vital')},
#  {'word': 'voluntary',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_3/voluntary')},
#  {'word': 'worthy',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_3/worthy')},
#  {'word': 'absent',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/absent')},
#  {'word': 'artificial',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/artificial')},
#  {'word': 'back',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/back')},
#  {'word': 'clear',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/clear')},
#  {'word': 'close',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/close')},
#  {'word': 'dangerous',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/dangerous')},
#  {'word': 'deep',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/deep')},
#  {'word': 'different',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/different')},
#  {'word': 'direct',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/direct')},
#  {'word': 'effective',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/effective')},
#  {'word': 'fair',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/fair')},
#  {'word': 'false',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/false')},
#  {'word': 'far',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/far')},
#  {'word': 'front',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/front')},
#  {'word': 'identical',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/identical')},
#  {'word': 'impossible',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/impossible')},
#  {'word': 'indirect',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/indirect')},
#  {'word': 'ineffective',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/ineffective')},
#  {'word': 'invisible',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/invisible')},
#  {'word': 'lucky',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/lucky')},
#  {'word': 'maximal',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/maximal')},
#  {'word': 'minimal',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/minimal')},
#  {'word': 'modern',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/modern')},
#  {'word': 'natural',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/natural')},
#  {'word': 'old-fashioned',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/old-fashioned')},
#  {'word': 'possible',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/possible')},
#  {'word': 'prepared',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/prepared')},
#  {'word': 'present',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/present')},
#  {'word': 'real',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/real')},
#  {'word': 'safe',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/safe')},
#  {'word': 'shallow',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/shallow')},
#  {'word': 'true',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/true')},
#  {'word': 'unclear',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/unclear')},
#  {'word': 'unfair',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/unfair')},
#  {'word': 'unlucky',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/unlucky')},
#  {'word': 'unprepared',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/unprepared')},
#  {'word': 'unreal',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/unreal')},
#  {'word': 'unused',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/unused')},
#  {'word': 'unusual',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/unusual')},
#  {'word': 'used',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/used')},
#  {'word': 'usual',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/usual')},
#  {'word': 'visible',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/visible')},
#  {'word': 'accessible',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/accessible')},
#  {'word': 'blunt',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/blunt')},
#  {'word': 'complete',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/complete')},
#  {'word': 'dependent',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/dependent')},
#  {'word': 'exact',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/exact')},
#  {'word': 'formal',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/formal')},
#  {'word': 'general',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/general')},
#  {'word': 'harmful',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/harmful')},
#  {'word': 'harmless',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/harmless')},
#  {'word': 'human',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/human')},
#  {'word': 'improbable',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/improbable')},
#  {'word': 'inaccessible',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/inaccessible')},
#  {'word': 'incomplete',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/incomplete')},
#  {'word': 'independent',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/independent')},
#  {'word': 'inexact',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/inexact')},
#  {'word': 'inferior',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/inferior')},
#  {'word': 'informal',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/informal')},
#  {'word': 'international',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/international')},
#  {'word': 'invalid',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/invalid')},
#  {'word': 'liquid',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/liquid')},
#  {'word': 'mental',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/mental')},
#  {'word': 'national',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/national')},
#  {'word': 'non-human',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/non-human')},
#  {'word': 'occupied',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/occupied')},
#  {'word': 'physical',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/physical')},
#  {'word': 'probable',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/probable')},
#  {'word': 'separate',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/separate')},
#  {'word': 'sharp',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/sharp')},
#  {'word': 'solid',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/solid')},
#  {'word': 'specific',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/specific')},
#  {'word': 'stable',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/stable')},
#  {'word': 'superior',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/superior')},
#  {'word': 'united',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/united')},
#  {'word': 'unstable',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/unstable')},
#  {'word': 'unwanted',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/unwanted')},
#  {'word': 'useful',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/useful')},
#  {'word': 'useless',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/useless')},
#  {'word': 'vacant',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/vacant')},
#  {'word': 'valid',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/valid')},
#  {'word': 'wanted',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/wanted')},
#  {'word': 'able',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/sobre_as_pessoas/able')},
#  {'word': 'alive',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/sobre_as_pessoas/alive')},
#  {'word': 'anonymous',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/sobre_as_pessoas/anonymous')},
#  {'word': 'blind',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/sobre_as_pessoas/blind')},
#  {'word': 'crazy',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/sobre_as_pessoas/crazy')},
#  {'word': 'dead',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/sobre_as_pessoas/dead')},
#  {'word': 'deaf',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/sobre_as_pessoas/deaf')},
#  {'word': 'deaf-mute',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/sobre_as_pessoas/deaf-mute')},
#  {'word': 'famous',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/sobre_as_pessoas/famous')},
#  {'word': 'free',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/sobre_as_pessoas/free')},
#  {'word': 'illiterate',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/sobre_as_pessoas/illiterate')},
#  {'word': 'intellectual',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/sobre_as_pessoas/intellectual')},
#  {'word': 'ironic',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/sobre_as_pessoas/ironic')},
#  {'word': 'irrational',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/sobre_as_pessoas/irrational')},
#  {'word': 'lame',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/sobre_as_pessoas/lame')},
#  {'word': 'literate',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/sobre_as_pessoas/literate')},
#  {'word': 'mute',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/sobre_as_pessoas/mute')},
#  {'word': 'myopic',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/sobre_as_pessoas/myopic')},
#  {'word': 'naked',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/sobre_as_pessoas/naked')},
#  {'word': 'objective',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/sobre_as_pessoas/objective')},
#  {'word': 'popular',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/sobre_as_pessoas/popular')},
#  {'word': 'pregnant',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/sobre_as_pessoas/pregnant')},
#  {'word': 'qualified',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/sobre_as_pessoas/qualified')},
#  {'word': 'rational',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/sobre_as_pessoas/rational')},
#  {'word': 'rich',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/sobre_as_pessoas/rich')},
#  {'word': 'spontaneous',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/sobre_as_pessoas/spontaneous')},
#  {'word': 'strong',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/sobre_as_pessoas/strong')},
#  {'word': 'subjective',
# ...
#  {'word': 'of',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/grupos_de_animais/herd_of_horses')},
#  {'word': 'horses',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/grupos_de_animais/herd_of_horses')},
#  {'word': 'nest',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/grupos_de_animais/nest')},
#  {'word': 'pack',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/grupos_de_animais/pack_of_wolves')},
#  {'word': 'of',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/grupos_de_animais/pack_of_wolves')},
#  {'word': 'wolves',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/grupos_de_animais/pack_of_wolves')},
#  {'word': 'pen',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/grupos_de_animais/pen')},
#  {'word': 'pigpen',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/grupos_de_animais/pigpen')},
#  {'word': 'pride',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/grupos_de_animais/pride')},
#  {'word': 'school',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/grupos_de_animais/school')},
#  {'word': 'sheepfold',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/grupos_de_animais/sheepfold')},
#  {'word': 'stable',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/grupos_de_animais/stable')},
#  {'word': 'stall',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/grupos_de_animais/stall')},
#  {'word': 'swarm',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/grupos_de_animais/swarm')},
#  {'word': 'to',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/grupos_de_animais/to_pasture')},
#  {'word': 'pasture',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/grupos_de_animais/to_pasture')},
#  {'word': 'zoo',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/grupos_de_animais/zoo')},
#  {'word': 'ant',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/ant')},
#  {'word': 'arachnid',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/arachnid')},
#  {'word': 'bee',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/bee')},
#  {'word': 'black',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/black_widow')},
#  {'word': 'widow',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/black_widow')},
#  {'word': 'bug',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/bug')},
#  {'word': 'butterfly',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/butterfly')},
#  {'word': 'centipede',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/centipede')},
#  {'word': 'cockroach',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/cockroach')},
#  {'word': 'dragonfly',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/dragonfly')},
#  {'word': 'drone',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/drone')},
#  {'word': 'earwig',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/earwig')},
#  {'word': 'flea',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/flea')},
#  {'word': 'fly',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/fly')},
#  {'word': 'grasshopper',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/grasshopper')},
#  {'word': 'horsefly',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/horsefly')},
#  {'word': 'insect',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/insect')},
#  {'word': 'insecticide',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/insecticide')},
#  {'word': 'ladybug',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/ladybug')},
#  {'word': 'locust',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/locust')},
#  {'word': 'louse',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/louse')},
#  {'word': 'mantis',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/mantis')},
#  {'word': 'midge',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/midge')},
#  {'word': 'mosquito',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/mosquito')},
#  {'word': 'moth',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/moth')},
#  {'word': 'potato',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/potato_beetle')},
#  {'word': 'beetle',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/potato_beetle')},
#  {'word': 'scarab',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/scarab')},
#  {'word': 'scorpion',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/scorpion')},
#  {'word': 'spider',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/spider')},
#  {'word': 'spiderweb',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/spiderweb')},
#  {'word': 'tarantula',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/tarantula')},
#  {'word': 'tsetse',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/tsetse')},
#  {'word': 'wasp',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/wasp')},
#  {'word': 'weevil',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/weevil')},
#  {'word': 'wolf',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/wolf_spider')},
#  {'word': 'spider',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/wolf_spider')},
#  {'word': 'beak',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/membros_dos_animais/beak')},
#  {'word': 'claw',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/membros_dos_animais/claw')},
#  {'word': 'cocoon',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/membros_dos_animais/cocoon')},
#  {'word': 'dorsal',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/membros_dos_animais/dorsal_fin')},
#  {'word': 'fin',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/membros_dos_animais/dorsal_fin')},
#  {'word': 'fangs',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/membros_dos_animais/fangs')},
#  {'word': 'feather',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/membros_dos_animais/feather')},
#  {'word': 'fin',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/membros_dos_animais/fin')},
#  {'word': 'fishbone',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/membros_dos_animais/fishbone')},
#  {'word': 'foreleg',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/membros_dos_animais/foreleg')},
#  {'word': 'fur',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/membros_dos_animais/fur')},
#  {'word': 'gill',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/membros_dos_animais/gill')},
#  {'word': 'hind',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/membros_dos_animais/hind_leg')},
#  {'word': 'leg',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/membros_dos_animais/hind_leg')},
#  {'word': 'hoof',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/membros_dos_animais/hoof')},
#  {'word': 'horns',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/membros_dos_animais/horns')},
#  {'word': 'horseshoe',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/membros_dos_animais/horseshoe')},
#  {'word': 'mane',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/membros_dos_animais/mane')},
#  {'word': 'muzzle',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/membros_dos_animais/muzzle')},
#  {'word': 'paw',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/membros_dos_animais/paw')},
#  {'word': 'pectoral',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/membros_dos_animais/pectoral_fin')},
#  {'word': 'fin',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/membros_dos_animais/pectoral_fin')},
#  {'word': 'rump',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/membros_dos_animais/rump')},
#  {'word': 'scale',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/membros_dos_animais/scale')},
#  {'word': 'snout',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/membros_dos_animais/snout')},
#  {'word': 'tail',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/membros_dos_animais/tail')},
#  {'word': 'trunk',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/membros_dos_animais/trunk')},
#  {'word': 'tusks',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/membros_dos_animais/tusks')},
#  {'word': 'whiskers',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/membros_dos_animais/whiskers')},
#  {'word': 'wing',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/membros_dos_animais/wing')},
#  {'word': 'argentine',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/peixes/argentine')},
#  {'word': 'barracuda',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/peixes/barracuda')},
#  {'word': 'beluga',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/peixes/beluga')},
#  {'word': 'flounder',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/peixes/flounder')},
#  {'word': 'goldfish',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/peixes/goldfish')},
#  {'word': 'koi',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/peixes/koi_carp')},
#  {'word': 'carp',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/peixes/koi_carp')},
#  {'word': 'minnow',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/peixes/minnow')},
#  {'word': 'perch',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/peixes/perch')},
#  {'word': 'piranha',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/peixes/piranha')},
#  {'word': 'roach',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/peixes/roach')},
#  {'word': 'sea',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/peixes/sea_horse')},
#  {'word': 'horse',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/peixes/sea_horse')},
#  {'word': 'shark',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/peixes/shark')},
#  {'word': 'skate',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/peixes/skate')},
#  {'word': 'sturgeon',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/peixes/sturgeon')},
#  {'word': 'sunfish',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/peixes/sunfish')},
#  {'word': 'bird',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/pássaros_domésticos/bird')},
#  {'word': 'canary',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/pássaros_domésticos/canary')},
#  {'word': 'cockatoo',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/pássaros_domésticos/cockatoo')},
#  {'word': 'duck',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/pássaros_domésticos/duck')},
#  {'word': 'goose',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/pássaros_domésticos/goose')},
#  {'word': 'hen',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/pássaros_domésticos/hen')},
#  ...]

# %%
set_data_words
# Out:
# [{'word': 'aberrant',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/aberrant')},
#  {'word': 'admirable',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/admirable')},
#  {'word': 'amazing',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/amazing')},
#  {'word': 'antique',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/antique')},
#  {'word': 'artistic',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/artistic')},
#  {'word': 'brief',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/brief')},
#  {'word': 'classical',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/classical')},
#  {'word': 'comic',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/comic')},
#  {'word': 'complex',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/complex')},
#  {'word': 'confusing',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/confusing')},
#  {'word': 'constructive',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/constructive')},
#  {'word': 'convincing',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/convincing')},
#  {'word': 'cultural',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/cultural')},
#  {'word': 'distinguished',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/distinguished')},
#  {'word': 'diverse',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/diverse')},
#  {'word': 'dubious',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/dubious')},
#  {'word': 'eccentric',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/eccentric')},
#  {'word': 'exceptional',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/exceptional')},
#  {'word': 'expressive',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/expressive')},
#  {'word': 'extraordinary',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/extraordinary')},
#  {'word': 'futuristic',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/futuristic')},
#  {'word': 'historic',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/historic')},
#  {'word': 'illogical',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/illogical')},
#  {'word': 'impressive',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/impressive')},
#  {'word': 'intuitive',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/intuitive')},
#  {'word': 'logical',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/logical')},
#  {'word': 'meaningless',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/meaningless')},
#  {'word': 'notable',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/notable')},
#  {'word': 'nplic',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/nplic')},
#  {'word': 'original',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/original')},
#  {'word': 'overrated',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/overrated')},
#  {'word': 'paradoxical',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/paradoxical')},
#  {'word': 'progressive',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/progressive')},
#  {'word': 'promising',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/promising')},
#  {'word': 'provocative',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/provocative')},
#  {'word': 'realistic',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/realistic')},
#  {'word': 'recent',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/recent')},
#  {'word': 'satirical',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/satirical')},
#  {'word': 'shocking',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/shocking')},
#  {'word': 'splendid',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/splendid')},
#  {'word': 'symbolic',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/symbolic')},
#  {'word': 'tragic',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/tragic')},
#  {'word': 'trivial',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/trivial')},
#  {'word': 'underrated',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/underrated')},
#  {'word': 'unforgettable',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/unforgettable')},
#  {'word': 'vague',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descição_de_arte/vague')},
#  {'word': 'authentic',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/authentic')},
#  {'word': 'automatic',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/automatic')},
#  {'word': 'broken',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/broken')},
#  {'word': 'cheap',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/cheap')},
#  {'word': 'closed',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/closed')},
#  {'word': 'durable',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/durable')},
#  {'word': 'elastic',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/elastic')},
#  {'word': 'electric',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/electric')},
#  {'word': 'electronic',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/electronic')},
#  {'word': 'empty',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/empty')},
#  {'word': 'expensive',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/expensive')},
#  {'word': 'fast',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/fast')},
#  {'word': 'fireproof',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/fireproof')},
#  {'word': 'flexible',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/flexible')},
#  {'word': 'fluffy',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/fluffy')},
#  {'word': 'fragile',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/fragile')},
#  {'word': 'full',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/full')},
#  {'word': 'furry',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/furry')},
#  {'word': 'glossy',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/glossy')},
#  {'word': 'golden',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/golden')},
#  {'word': 'hard',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/hard')},
#  {'word': 'heavy',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/heavy')},
#  {'word': 'ideal',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/ideal')},
#  {'word': 'inflexible',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/inflexible')},
#  {'word': 'innovative',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/innovative')},
#  {'word': 'light',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/light')},
#  {'word': 'metallic',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/metallic')},
#  {'word': 'moist',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/moist')},
#  {'word': 'new',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/new')},
#  {'word': 'old',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/old')},
#  {'word': 'open',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/open')},
#  {'word': 'portable',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/portable')},
#  {'word': 'precious',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/precious')},
#  {'word': 'priceless',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/priceless')},
#  {'word': 'qualitative',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/qualitative')},
#  {'word': 'recyclable',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/recyclable')},
#  {'word': 'rusty',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/rusty')},
#  {'word': 'shiny',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/shiny')},
#  {'word': 'silver',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/silver')},
#  {'word': 'slow',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/slow')},
#  {'word': 'soft',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/soft')},
#  {'word': 'sophisticated',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/sophisticated')},
#  {'word': 'sparkling',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/sparkling')},
#  {'word': 'standard',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/standard')},
#  {'word': 'sticky',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/sticky')},
#  {'word': 'translucent',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/translucent')},
#  {'word': 'transparent',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/transparent')},
#  {'word': 'valuable',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/valuable')},
#  {'word': 'waterproof',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/waterproof')},
#  {'word': 'wet',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/wet')},
#  {'word': 'wooden',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrição_de_objetos/wooden')},
#  {'word': 'additional',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/additional')},
#  {'word': 'analogous',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/analogous')},
#  {'word': 'compact',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/compact')},
#  {'word': 'dense',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/dense')},
#  {'word': 'disproportionate',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/disproportionate')},
#  {'word': 'distant',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/distant')},
#  {'word': 'double',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/double')},
#  {'word': 'dynamic',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/dynamic')},
#  {'word': 'ethnic',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/ethnic')},
#  {'word': 'external',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/external')},
#  {'word': 'extra',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/extra')},
#  {'word': 'extreme',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/extreme')},
#  {'word': 'fixed',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/fixed')},
#  {'word': 'foreign',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/foreign')},
#  {'word': 'immediate',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/immediate')},
#  {'word': 'individual',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/individual')},
#  {'word': 'infinite',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/infinite')},
#  {'word': 'intense',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/intense')},
#  {'word': 'known',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/known')},
#  {'word': 'local',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/local')},
#  {'word': 'luminous',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/luminous')},
#  {'word': 'magnetic',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/magnetic')},
#  {'word': 'main',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/main')},
#  {'word': 'majo',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/majo')},
#  {'word': 'middle',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/middle')},
#  {'word': 'mino',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/mino')},
#  {'word': 'mixed',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/mixed')},
#  {'word': 'multicultural',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/multicultural')},
#  {'word': 'only',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/only')},
#  {'word': 'other',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/other')},
#  {'word': 'powerful',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/powerful')},
#  {'word': 'proportionate',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/proportionate')},
#  {'word': 'regional',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/regional')},
#  {'word': 'relative',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/relative')},
#  {'word': 'special',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/special')},
#  {'word': 'static',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/static')},
#  {'word': 'technical',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/technical')},
#  {'word': 'total',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/total')},
#  {'word': 'traditional',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/traditional')},
#  {'word': 'triple',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/triple')},
#  {'word': 'various',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_1/various')},
#  {'word': 'abundant',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/abundant')},
#  {'word': 'alternative',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/alternative')},
#  {'word': 'available',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/available')},
#  {'word': 'central',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/central')},
#  {'word': 'commercial',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/commercial')},
#  {'word': 'confidential',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/confidential')},
#  {'word': 'constant',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/constant')},
#  {'word': 'crowded',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/crowded')},
#  {'word': 'destructive',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/destructive')},
#  {'word': 'eastern',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/eastern')},
#  {'word': 'efficient',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/efficient')},
#  {'word': 'endless',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/endless')},
#  {'word': 'equal',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/equal')},
#  {'word': 'excessive',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/excessive')},
#  {'word': 'extraterrestrial',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/extraterrestrial')},
#  {'word': 'final',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/final')},
#  {'word': 'global',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/global')},
#  {'word': 'imaginary',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/imaginary')},
#  {'word': 'insufficient',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/insufficient')},
#  {'word': 'loud',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/loud')},
#  {'word': 'northern',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/northern')},
#  {'word': 'nuclear',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/nuclear')},
#  {'word': 'numerous',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/numerous')},
#  {'word': 'obvious',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/obvious')},
#  {'word': 'partial',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/partial')},
#  {'word': 'public',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/public')},
#  {'word': 'random',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/random')},
#  {'word': 'ready',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/ready')},
#  {'word': 'secret',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/secret')},
#  {'word': 'social',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/social')},
#  {'word': 'southern',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/southern')},
#  {'word': 'strategic',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/strategic')},
#  {'word': 'sufficient',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/sufficient')},
#  {'word': 'technological',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/technological')},
#  {'word': 'typical',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/typical')},
#  {'word': 'unavailable',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/unavailable')},
#  {'word': 'urgent',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/urgent')},
#  {'word': 'western',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/western')},
#  {'word': 'worldwide',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_2/worldwide')},
#  {'word': 'adjacent',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_3/adjacent')},
#  {'word': 'arbitrary',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_3/arbitrary')},
#  {'word': 'comparative',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_3/comparative')},
#  {'word': 'consecutive',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_3/consecutive')},
#  {'word': 'contradictory',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_3/contradictory')},
#  {'word': 'depressing',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_3/depressing')},
#  {'word': 'detailed',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_3/detailed')},
#  {'word': 'essential',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_3/essential')},
#  {'word': 'existent',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_3/existent')},
#  {'word': 'forgivable',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_3/forgivable')},
#  {'word': 'forgotten',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_3/forgotten')},
#  {'word': 'hidden',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_3/hidden')},
#  {'word': 'home-made',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_3/home-made')},
#  {'word': 'hypothetical',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_3/hypothetical')},
#  {'word': 'inexistent',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_3/inexistent')},
#  {'word': 'integrated',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_3/integrated')},
#  {'word': 'irreversible',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_3/irreversible')},
#  {'word': 'moderate',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_3/moderate')},
#  {'word': 'opposite',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_3/opposite')},
#  {'word': 'optimal',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_3/optimal')},
#  {'word': 'prestigious',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_3/prestigious')},
#  {'word': 'repeated',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_3/repeated')},
#  {'word': 'reversible',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_3/reversible')},
#  {'word': 'routine',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_3/routine')},
#  {'word': 'subordinate',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_3/subordinate')},
#  {'word': 'threatening',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_3/threatening')},
#  {'word': 'tidy',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_3/tidy')},
#  {'word': 'tiring',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_3/tiring')},
#  {'word': 'troublesome',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_3/troublesome')},
#  {'word': 'unforgivable',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_3/unforgivable')},
#  {'word': 'universal',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_3/universal')},
#  {'word': 'vast',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_3/vast')},
#  {'word': 'vital',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_3/vital')},
#  {'word': 'voluntary',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_3/voluntary')},
#  {'word': 'worthy',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/descrições_3/worthy')},
#  {'word': 'absent',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/absent')},
#  {'word': 'artificial',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/artificial')},
#  {'word': 'back',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/back')},
#  {'word': 'clear',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/clear')},
#  {'word': 'close',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/close')},
#  {'word': 'dangerous',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/dangerous')},
#  {'word': 'deep',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/deep')},
#  {'word': 'different',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/different')},
#  {'word': 'direct',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/direct')},
#  {'word': 'effective',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/effective')},
#  {'word': 'fair',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/fair')},
#  {'word': 'false',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/false')},
#  {'word': 'far',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/far')},
#  {'word': 'front',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/front')},
#  {'word': 'identical',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/identical')},
#  {'word': 'impossible',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/impossible')},
#  {'word': 'indirect',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/indirect')},
#  {'word': 'ineffective',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/ineffective')},
#  {'word': 'invisible',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/invisible')},
#  {'word': 'lucky',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/lucky')},
#  {'word': 'maximal',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/maximal')},
#  {'word': 'minimal',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/minimal')},
#  {'word': 'modern',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/modern')},
#  {'word': 'natural',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/natural')},
#  {'word': 'old-fashioned',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/old-fashioned')},
#  {'word': 'possible',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/possible')},
#  {'word': 'prepared',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/prepared')},
#  {'word': 'present',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/present')},
#  {'word': 'real',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/real')},
#  {'word': 'safe',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/safe')},
#  {'word': 'shallow',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/shallow')},
#  {'word': 'true',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/true')},
#  {'word': 'unclear',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/unclear')},
#  {'word': 'unfair',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/unfair')},
#  {'word': 'unlucky',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/unlucky')},
#  {'word': 'unprepared',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/unprepared')},
#  {'word': 'unreal',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/unreal')},
#  {'word': 'unused',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/unused')},
#  {'word': 'unusual',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/unusual')},
#  {'word': 'used',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/used')},
#  {'word': 'usual',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/usual')},
#  {'word': 'visible',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_1/visible')},
#  {'word': 'accessible',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/accessible')},
#  {'word': 'blunt',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/blunt')},
#  {'word': 'complete',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/complete')},
#  {'word': 'dependent',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/dependent')},
#  {'word': 'exact',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/exact')},
#  {'word': 'formal',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/formal')},
#  {'word': 'general',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/general')},
#  {'word': 'harmful',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/harmful')},
#  {'word': 'harmless',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/harmless')},
#  {'word': 'human',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/human')},
#  {'word': 'improbable',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/improbable')},
#  {'word': 'inaccessible',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/inaccessible')},
#  {'word': 'incomplete',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/incomplete')},
#  {'word': 'independent',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/independent')},
#  {'word': 'inexact',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/inexact')},
#  {'word': 'inferior',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/inferior')},
#  {'word': 'informal',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/informal')},
#  {'word': 'international',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/international')},
#  {'word': 'invalid',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/invalid')},
#  {'word': 'liquid',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/liquid')},
#  {'word': 'mental',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/mental')},
#  {'word': 'national',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/national')},
#  {'word': 'non-human',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/non-human')},
#  {'word': 'occupied',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/occupied')},
#  {'word': 'physical',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/physical')},
#  {'word': 'probable',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/probable')},
#  {'word': 'separate',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/separate')},
#  {'word': 'sharp',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/sharp')},
#  {'word': 'solid',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/solid')},
#  {'word': 'specific',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/specific')},
#  {'word': 'stable',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/stable')},
#  {'word': 'superior',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/superior')},
#  {'word': 'united',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/united')},
#  {'word': 'unstable',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/unstable')},
#  {'word': 'unwanted',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/unwanted')},
#  {'word': 'useful',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/useful')},
#  {'word': 'useless',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/useless')},
#  {'word': 'vacant',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/vacant')},
#  {'word': 'valid',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/valid')},
#  {'word': 'wanted',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/pares_2/wanted')},
#  {'word': 'able',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/sobre_as_pessoas/able')},
#  {'word': 'alive',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/sobre_as_pessoas/alive')},
#  {'word': 'anonymous',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/sobre_as_pessoas/anonymous')},
#  {'word': 'blind',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/sobre_as_pessoas/blind')},
#  {'word': 'crazy',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/sobre_as_pessoas/crazy')},
#  {'word': 'dead',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/sobre_as_pessoas/dead')},
#  {'word': 'deaf',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/sobre_as_pessoas/deaf')},
#  {'word': 'deaf-mute',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/sobre_as_pessoas/deaf-mute')},
#  {'word': 'famous',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/sobre_as_pessoas/famous')},
#  {'word': 'free',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/sobre_as_pessoas/free')},
#  {'word': 'illiterate',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/sobre_as_pessoas/illiterate')},
#  {'word': 'intellectual',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/sobre_as_pessoas/intellectual')},
#  {'word': 'ironic',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/sobre_as_pessoas/ironic')},
#  {'word': 'irrational',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/sobre_as_pessoas/irrational')},
#  {'word': 'lame',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/sobre_as_pessoas/lame')},
#  {'word': 'literate',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/sobre_as_pessoas/literate')},
#  {'word': 'mute',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/sobre_as_pessoas/mute')},
#  {'word': 'myopic',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/sobre_as_pessoas/myopic')},
#  {'word': 'naked',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/sobre_as_pessoas/naked')},
#  {'word': 'objective',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/sobre_as_pessoas/objective')},
#  {'word': 'popular',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/sobre_as_pessoas/popular')},
#  {'word': 'pregnant',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/sobre_as_pessoas/pregnant')},
#  {'word': 'qualified',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/sobre_as_pessoas/qualified')},
#  {'word': 'rational',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/sobre_as_pessoas/rational')},
#  {'word': 'rich',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/sobre_as_pessoas/rich')},
#  {'word': 'spontaneous',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/sobre_as_pessoas/spontaneous')},
#  {'word': 'strong',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/adjetivos/sobre_as_pessoas/strong')},
#  {'word': 'subjective',
# ...
#  {'word': 'of',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/grupos_de_animais/herd_of_horses')},
#  {'word': 'horses',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/grupos_de_animais/herd_of_horses')},
#  {'word': 'nest',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/grupos_de_animais/nest')},
#  {'word': 'pack',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/grupos_de_animais/pack_of_wolves')},
#  {'word': 'of',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/grupos_de_animais/pack_of_wolves')},
#  {'word': 'wolves',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/grupos_de_animais/pack_of_wolves')},
#  {'word': 'pen',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/grupos_de_animais/pen')},
#  {'word': 'pigpen',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/grupos_de_animais/pigpen')},
#  {'word': 'pride',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/grupos_de_animais/pride')},
#  {'word': 'school',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/grupos_de_animais/school')},
#  {'word': 'sheepfold',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/grupos_de_animais/sheepfold')},
#  {'word': 'stable',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/grupos_de_animais/stable')},
#  {'word': 'stall',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/grupos_de_animais/stall')},
#  {'word': 'swarm',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/grupos_de_animais/swarm')},
#  {'word': 'to',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/grupos_de_animais/to_pasture')},
#  {'word': 'pasture',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/grupos_de_animais/to_pasture')},
#  {'word': 'zoo',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/grupos_de_animais/zoo')},
#  {'word': 'ant',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/ant')},
#  {'word': 'arachnid',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/arachnid')},
#  {'word': 'bee',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/bee')},
#  {'word': 'black',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/black_widow')},
#  {'word': 'widow',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/black_widow')},
#  {'word': 'bug',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/bug')},
#  {'word': 'butterfly',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/butterfly')},
#  {'word': 'centipede',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/centipede')},
#  {'word': 'cockroach',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/cockroach')},
#  {'word': 'dragonfly',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/dragonfly')},
#  {'word': 'drone',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/drone')},
#  {'word': 'earwig',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/earwig')},
#  {'word': 'flea',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/flea')},
#  {'word': 'fly',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/fly')},
#  {'word': 'grasshopper',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/grasshopper')},
#  {'word': 'horsefly',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/horsefly')},
#  {'word': 'insect',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/insect')},
#  {'word': 'insecticide',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/insecticide')},
#  {'word': 'ladybug',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/ladybug')},
#  {'word': 'locust',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/locust')},
#  {'word': 'louse',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/louse')},
#  {'word': 'mantis',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/mantis')},
#  {'word': 'midge',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/midge')},
#  {'word': 'mosquito',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/mosquito')},
#  {'word': 'moth',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/moth')},
#  {'word': 'potato',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/potato_beetle')},
#  {'word': 'beetle',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/potato_beetle')},
#  {'word': 'scarab',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/scarab')},
#  {'word': 'scorpion',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/scorpion')},
#  {'word': 'spider',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/spider')},
#  {'word': 'spiderweb',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/spiderweb')},
#  {'word': 'tarantula',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/tarantula')},
#  {'word': 'tsetse',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/tsetse')},
#  {'word': 'wasp',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/wasp')},
#  {'word': 'weevil',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/weevil')},
#  {'word': 'wolf',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/wolf_spider')},
#  {'word': 'spider',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/insetos_e_aracnídeos/wolf_spider')},
#  {'word': 'beak',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/membros_dos_animais/beak')},
#  {'word': 'claw',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/membros_dos_animais/claw')},
#  {'word': 'cocoon',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/membros_dos_animais/cocoon')},
#  {'word': 'dorsal',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/membros_dos_animais/dorsal_fin')},
#  {'word': 'fin',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/membros_dos_animais/dorsal_fin')},
#  {'word': 'fangs',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/membros_dos_animais/fangs')},
#  {'word': 'feather',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/membros_dos_animais/feather')},
#  {'word': 'fin',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/membros_dos_animais/fin')},
#  {'word': 'fishbone',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/membros_dos_animais/fishbone')},
#  {'word': 'foreleg',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/membros_dos_animais/foreleg')},
#  {'word': 'fur',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/membros_dos_animais/fur')},
#  {'word': 'gill',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/membros_dos_animais/gill')},
#  {'word': 'hind',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/membros_dos_animais/hind_leg')},
#  {'word': 'leg',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/membros_dos_animais/hind_leg')},
#  {'word': 'hoof',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/membros_dos_animais/hoof')},
#  {'word': 'horns',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/membros_dos_animais/horns')},
#  {'word': 'horseshoe',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/membros_dos_animais/horseshoe')},
#  {'word': 'mane',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/membros_dos_animais/mane')},
#  {'word': 'muzzle',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/membros_dos_animais/muzzle')},
#  {'word': 'paw',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/membros_dos_animais/paw')},
#  {'word': 'pectoral',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/membros_dos_animais/pectoral_fin')},
#  {'word': 'fin',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/membros_dos_animais/pectoral_fin')},
#  {'word': 'rump',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/membros_dos_animais/rump')},
#  {'word': 'scale',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/membros_dos_animais/scale')},
#  {'word': 'snout',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/membros_dos_animais/snout')},
#  {'word': 'tail',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/membros_dos_animais/tail')},
#  {'word': 'trunk',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/membros_dos_animais/trunk')},
#  {'word': 'tusks',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/membros_dos_animais/tusks')},
#  {'word': 'whiskers',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/membros_dos_animais/whiskers')},
#  {'word': 'wing',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/membros_dos_animais/wing')},
#  {'word': 'argentine',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/peixes/argentine')},
#  {'word': 'barracuda',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/peixes/barracuda')},
#  {'word': 'beluga',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/peixes/beluga')},
#  {'word': 'flounder',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/peixes/flounder')},
#  {'word': 'goldfish',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/peixes/goldfish')},
#  {'word': 'koi',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/peixes/koi_carp')},
#  {'word': 'carp',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/peixes/koi_carp')},
#  {'word': 'minnow',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/peixes/minnow')},
#  {'word': 'perch',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/peixes/perch')},
#  {'word': 'piranha',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/peixes/piranha')},
#  {'word': 'roach',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/peixes/roach')},
#  {'word': 'sea',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/peixes/sea_horse')},
#  {'word': 'horse',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/peixes/sea_horse')},
#  {'word': 'shark',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/peixes/shark')},
#  {'word': 'skate',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/peixes/skate')},
#  {'word': 'sturgeon',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/peixes/sturgeon')},
#  {'word': 'sunfish',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/peixes/sunfish')},
#  {'word': 'bird',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/pássaros_domésticos/bird')},
#  {'word': 'canary',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/pássaros_domésticos/canary')},
#  {'word': 'cockatoo',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/pássaros_domésticos/cockatoo')},
#  {'word': 'duck',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/pássaros_domésticos/duck')},
#  {'word': 'goose',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/pássaros_domésticos/goose')},
#  {'word': 'hen',
#   'path': WindowsPath('database/extract_data_video/data/extracted_data/words/data_organize/animais/pássaros_domésticos/hen')},
#  ...]
