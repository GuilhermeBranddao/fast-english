# %%
# !pip install pymupdf opencv-python

# %%
import cv2
import os
import numpy as np

# Caminhos
path_images = "data/raw_selected"
output_folder = "data/recortes"
os.makedirs(output_folder, exist_ok=True)

# Lista de imagens
imagens_paths = sorted([
    os.path.join(path_images, f)
    for f in os.listdir(path_images)
    if f.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp'))
])

# Histórico por imagem
historico = {}
i = 0

while i < len(imagens_paths):
    path = imagens_paths[i]
    img = cv2.imread(path)

    if img is None:
        print(f"⚠️ Erro ao carregar {path}. Pulando...")
        i += 1
        continue

    nome_base = os.path.splitext(os.path.basename(path))[0]
    historico[nome_base] = []

    print(f"\n🖼️ Imagem {i + 1}/{len(imagens_paths)}: {path}")

    while True:
        display = img.copy()
        cv2.putText(display, f"{nome_base}", (10, 25),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 255, 255), 2)

        img = cv2.resize(img, (640, 700))
        cv2.imshow("Imagem", img)
        key = cv2.waitKey(0)

        if key == ord('r'):
            r = cv2.selectROI("Imagem", img, fromCenter=False, showCrosshair=True)
            if r != (0, 0, 0, 0):
                x, y, w, h = r
                recorte = img[y:y+h, x:x+w]
                nome_arquivo = f"{nome_base}_crop_{x}_{y}.png"
                caminho_salvar = os.path.join(output_folder, nome_arquivo)
                cv2.imwrite(caminho_salvar, recorte)
                print(f"✅ Recorte salvo: {nome_arquivo}")
                historico[nome_base].append(caminho_salvar)

        elif key == ord('n'):
            i += 1
            break

        elif key == ord('p') and historico[nome_base]:
            ultimo = historico[nome_base].pop()
            if os.path.exists(ultimo):
                os.remove(ultimo)
                print(f"↩️ Recorte desfeito: {os.path.basename(ultimo)}")
            else:
                print("❌ Não foi possível desfazer o recorte.")

        elif key == ord('q'):
            print("🛑 Encerrando...")
            imagens_paths = 0
            cv2.destroyAllWindows()
            exit()

cv2.destroyAllWindows()
# Out:
# 🖼️ Imagem 1/21: data/raw_selected\page20_img1.png
# ✅ Recorte salvo: page20_img1_crop_65_116.png
# ✅ Recorte salvo: page20_img1_crop_175_121.png
# ✅ Recorte salvo: page20_img1_crop_287_114.png
# ✅ Recorte salvo: page20_img1_crop_398_120.png
# ✅ Recorte salvo: page20_img1_crop_505_118.png
# ✅ Recorte salvo: page20_img1_crop_74_225.png
# ✅ Recorte salvo: page20_img1_crop_213_225.png
# ✅ Recorte salvo: page20_img1_crop_353_226.png
# ✅ Recorte salvo: page20_img1_crop_492_226.png
# ✅ Recorte salvo: page20_img1_crop_54_339.png
# ✅ Recorte salvo: page20_img1_crop_130_339.png
# ✅ Recorte salvo: page20_img1_crop_208_341.png
# ✅ Recorte salvo: page20_img1_crop_286_339.png
# ✅ Recorte salvo: page20_img1_crop_365_336.png
# ✅ Recorte salvo: page20_img1_crop_446_337.png
# ✅ Recorte salvo: page20_img1_crop_524_340.png
# ✅ Recorte salvo: page20_img1_crop_59_445.png
# ✅ Recorte salvo: page20_img1_crop_151_445.png
# ✅ Recorte salvo: page20_img1_crop_244_445.png
# ✅ Recorte salvo: page20_img1_crop_333_444.png
# ✅ Recorte salvo: page20_img1_crop_424_444.png
# ✅ Recorte salvo: page20_img1_crop_514_445.png
# ✅ Recorte salvo: page20_img1_crop_60_547.png
# ✅ Recorte salvo: page20_img1_crop_149_547.png
# ✅ Recorte salvo: page20_img1_crop_241_548.png
# ✅ Recorte salvo: page20_img1_crop_334_546.png
# ✅ Recorte salvo: page20_img1_crop_425_547.png
# ✅ Recorte salvo: page20_img1_crop_517_547.png
#
# 🖼️ Imagem 2/21: data/raw_selected\page21_img1.png
#
# 🖼️ Imagem 3/21: data/raw_selected\page21_img2.png
# ✅ Recorte salvo: page21_img2_crop_48_77.png
# ✅ Recorte salvo: page21_img2_crop_160_77.png
# ✅ Recorte salvo: page21_img2_crop_269_78.png
# ✅ Recorte salvo: page21_img2_crop_380_77.png
# ✅ Recorte salvo: page21_img2_crop_490_77.png
# ✅ Recorte salvo: page21_img2_crop_64_192.png
# ✅ Recorte salvo: page21_img2_crop_175_192.png
# ✅ Recorte salvo: page21_img2_crop_292_191.png
# ✅ Recorte salvo: page21_img2_crop_397_190.png
# ✅ Recorte salvo: page21_img2_crop_500_191.png
# ✅ Recorte salvo: page21_img2_crop_63_298.png
# ✅ Recorte salvo: page21_img2_crop_169_293.png
# ✅ Recorte salvo: page21_img2_crop_282_296.png
# ✅ Recorte salvo: page21_img2_crop_399_295.png
# ✅ Recorte salvo: page21_img2_crop_503_296.png
# ✅ Recorte salvo: page21_img2_crop_53_405.png
# ✅ Recorte salvo: page21_img2_crop_161_408.png
# ✅ Recorte salvo: page21_img2_crop_277_407.png
# ✅ Recorte salvo: page21_img2_crop_384_405.png
# ✅ Recorte salvo: page21_img2_crop_493_404.png
# ✅ Recorte salvo: page21_img2_crop_63_534.png
# ✅ Recorte salvo: page21_img2_crop_169_531.png
# ✅ Recorte salvo: page21_img2_crop_278_532.png
# ✅ Recorte salvo: page21_img2_crop_384_532.png
# ✅ Recorte salvo: page21_img2_crop_502_532.png
