# %%
list_testos = ["frases_básicas__dizer_olá_e_adeus",
"frases_básicas__melhores_votos",
"frases_básicas__agradecimentos",
"frases_básicas__desculpas",
"frases_básicas__instruções",
"frases_básicas__perguntas_e_respostas_curtas",
"frases_básicas__felicitações",
"conversa__geral_idiomas",
"conversa__geral_fazer_se_compreender",
"conversa__geral_concordar_e_discordar",
"conversa__geral_pedir_por_e_fornecer_informação",
"conversa__geral_expressar_sentimentos",
"conversa__geral_ajuda_e_conselhos",
"conversa__geral_opiniões",
"emergências__situações_de_emergência",
"emergências__acidentes",
"emergências__primeiros_socorros",
"emergências__na_esquadra_da_polícia",
"fazer_amigos__apresentações",
"fazer_amigos__local_de_residência",
"fazer_amigos__idade_nacionalidade_e_religião",
"fazer_amigos__família_e_relacionamentos",
"fazer_amigos__descrever_pessoas",
"fazer_amigos__coisas_que_gosta_e_não_gosta",
"fazer_amigos__organizar_um_encontro",
"fazer_amigos__aceitar_e_recusar",
"encontros__perguntar_a_alguém_se_quer_sair",
"encontros__num_encontro",
"encontros__elogios",
"encontros__casamento",
"educação__na_escola",
"educação__na_universidade",
"educação__vida_de_estudante",
"educação__números_e_cores",
"empregos__ocupação",
"empregos__estatuto_de_emprego",
"empregos__no_local_de_trabalho",
"empregos__negócio",
"empregos__na_entrevista",
"empregos__carta_de_recomendação",
"viagem__pedir_indicações",
"viagem__dar_indicações",
"viagem__no_posto_de_turismo",
"viagem__excursões",
"avião__reservar_um_voo",
"avião__fazer_o_check_in",
"avião__bagagem",
"avião__controlo_de_passaporte_e_alfândega",
"avião__no_avião",
"avião__sinais_do_aeroporto",
"carro__aluguer_de_carro",
"carro__conduzir_e_estacionar",
"carro__na_bomba_de_gasolina",
"carro__problemas_mecânicos",
"carro__sinais_de_estrada",
"outro_transporte__no_terminal_de_camionetas",
"outro_transporte__na_estação_de_comboios",
"outro_transporte__na_camioneta_ou_comboio",
"outro_transporte__táxi",
"outro_transporte__navio",
"hotel__perguntar_sobre_instalações",
"hotel__reservar_um_quarto",
"hotel__fazer_o_check_in",
"hotel__durante_a_sua_estadia",
"hotel__fazer_o_check_out",
"hotel__reclamações",
"hotel__alugar_um_apartamento",
"restaurante_e_bar__reservar_uma_mesa",
"restaurante_e_bar__pedir_bebidas",
"restaurante_e_bar__pedir_comida",
"restaurante_e_bar__durante_a_refeição",
"restaurante_e_bar__pagar_a_conta",
"restaurante_e_bar__reclamações",
"restaurante_e_bar__no_bar",
"comida__carne_e_peixe",
"comida__fruta",
"comida__vegetais",
"comida__alimentos_básicos_e_especiarias",
"comida__comida_para_o_pequeno_almoço",
"compras__no_loja_de_departamentos",
"compras__roupas",
"compras__sapatos",
"compras__acessórios",
"compras__cuidados_pessoais",
"compras__dispositivos_eletrónicos",
"compras__outros_produtos",
"compras__no_supermercado",
"compras__na_livraria_e_florista",
"compras__pagamento_&_devoluções",
"tempo_de_lazer__no_cinema",
"tempo_de_lazer__no_teatro",
"tempo_de_lazer__no_museu",
"tempo_de_lazer__na_discoteca",
"tempo_de_lazer__na_praia",
"tempo_de_lazer__desporto",
"tempo_de_lazer__música",
"tempo_de_lazer__ir_acampar",
"tempo_de_lazer__tempo_com_a_família",
"tempo_de_lazer__jardinagem",
"tempo_de_lazer__receber_convidados",
"serviços__no_banco",
"serviços__na_agência_imobiliária",
"serviços__no_salão_de_beleza",
"serviços__no_alfaiate",
"serviços__reparações",
"saúde__no_médico",
"saúde__doenças",
"saúde__tratamento",
"saúde__no_dentista",
"saúde__no_oculista",
"saúde__na_farmácia",
"meios_de_comunicação__telefone",
"meios_de_comunicação__chamadas_telefónicas_no_trabalho",
"meios_de_comunicação__meios_de_comunicação_em_massa",
"meios_de_comunicação__nos_correios",
"meios_de_comunicação__carta",
"tempo_e_clima__dizendo_a_hora",
"tempo_e_clima__calendário",
"tempo_e_clima__expressões_de_tempo",
"tempo_e_clima__tempo",
]

# %%
import os
from pathlib import Path

# Caminho para os vídeos
videos_path = Path("/media/guilherme/ssd_m2_data/py_new_projects/fast_english/extract_data_video/data/video/sentences")


# Obter os arquivos de vídeo (pode ajustar o padrão se quiser)
videos = sorted(videos_path.glob("*.mp4"))

# Verifica se as quantidades batem
if len(videos) != len(list_testos):
    print("Erro: Quantidade de vídeos e nomes não corresponde.")
else:
    for video, novo_nome in zip(videos, list_testos):
        novo_caminho = videos_path / f"{novo_nome}.mp4"
        os.rename(video, novo_caminho)
        print(f"Renomeado: {video.name} -> {novo_caminho.name}")
# Out:
# Renomeado: Screen_Recording_20250501_114145_FunEasyLearn.mp4 -> frases_básicas__dizer_olá_e_adeus.mp4
# Renomeado: Screen_Recording_20250501_114401_FunEasyLearn.mp4 -> frases_básicas__melhores_votos.mp4
# Renomeado: Screen_Recording_20250501_115152_FunEasyLearn.mp4 -> frases_básicas__agradecimentos.mp4
# Renomeado: Screen_Recording_20250501_115446_FunEasyLearn.mp4 -> frases_básicas__desculpas.mp4
# Renomeado: Screen_Recording_20250501_115742_FunEasyLearn.mp4 -> frases_básicas__instruções.mp4
# Renomeado: Screen_Recording_20250501_120254_FunEasyLearn.mp4 -> frases_básicas__perguntas_e_respostas_curtas.mp4
# Renomeado: Screen_Recording_20250501_120543_FunEasyLearn.mp4 -> frases_básicas__felicitações.mp4
# Renomeado: Screen_Recording_20250501_120836_FunEasyLearn.mp4 -> conversa__geral_idiomas.mp4
# Renomeado: Screen_Recording_20250501_121145_FunEasyLearn.mp4 -> conversa__geral_fazer_se_compreender.mp4
# ...

# %%
videos
# Out:
# [PosixPath('/media/guilherme/ssd_m2_data/py_new_projects/fast_english/extract_data_video/data/video/sentences/Screen_Recording_20250501_114145_FunEasyLearn.mp4'),
#  PosixPath('/media/guilherme/ssd_m2_data/py_new_projects/fast_english/extract_data_video/data/video/sentences/Screen_Recording_20250501_114401_FunEasyLearn.mp4'),
#  PosixPath('/media/guilherme/ssd_m2_data/py_new_projects/fast_english/extract_data_video/data/video/sentences/Screen_Recording_20250501_115152_FunEasyLearn.mp4'),
#  PosixPath('/media/guilherme/ssd_m2_data/py_new_projects/fast_english/extract_data_video/data/video/sentences/Screen_Recording_20250501_115446_FunEasyLearn.mp4'),
#  PosixPath('/media/guilherme/ssd_m2_data/py_new_projects/fast_english/extract_data_video/data/video/sentences/Screen_Recording_20250501_115742_FunEasyLearn.mp4'),
#  PosixPath('/media/guilherme/ssd_m2_data/py_new_projects/fast_english/extract_data_video/data/video/sentences/Screen_Recording_20250501_120254_FunEasyLearn.mp4'),
# ...

# %%
len(videos), len(list_testos)
# Out:
# (120, 120)

# %%
4+10+5+5+8+7+12+14+10+5+8+9+6+6+6+6+7+12+7+7+7+6+11+8+7+5
# Out:
# 198
