# %%
import os
# %load_ext autoreload
# %autoreload 2
os.chdir("..")
os.chdir("..")
os.chdir("..")

# %%
import os
import tkinter as tk
from tkinter import messagebox
from pathlib import Path
import pandas as pd
from PIL import Image, ImageTk
import json
import pygame
import random
from datetime import datetime
from deep_translator import GoogleTranslator
from random import randint


from app.utils.data_loader import DataLoader
from app.utils.game_timer import GameTimer
from app.utils.save_data import save_game_data

# Inicializa o mixer do pygame
pygame.mixer.init()

TITLE_FONT = ("Arial", 20)
LABEL_FONT = ("Arial", 14)
SMALL_FONT = ("Arial", 12)

# DATA_PATH = Path("extract_data_video/data/extracted_data/words/data_organize")
DATA_PATH = Path("database/vocabulary/words/data_organize")
SUBCATEGORY_NAME = "em_loja"


class HangmanGame(tk.Frame):
    MAX_ATTEMPTS = 6

    def __init__(self, parent=None, **kwargs):
        super().__init__(parent, **kwargs)
        self.parent = parent
        self.loader = DataLoader(base_path=DATA_PATH)
        self.list_data_words:list[dict] = self.loader.get_all_words(subcategory_name=SUBCATEGORY_NAME)
        random.shuffle(self.list_data_words)

        self.timer = GameTimer(self)

        self.clicks_on_guess = 0

        self.last_word = None

        self.id_game = self.gerar_hash_id()
        self.reset_game()
        self.setup_ui()

    def gerar_hash_id(self):
        agora = datetime.now().strftime("%Y%m%d%H%M%S%f")  # AnoMesDiaHoraMinSegMicroseg
        return hex(abs(hash(agora)))[2:]  # Converte para hexadecimal e remove '0x'

    def reset_game(self):
        if not self.list_data_words:
            messagebox.showinfo("Fim", "Não há mais palavras disponíveis.")
            self.parent.quit()
            return

        self.dict_info_words = self.list_data_words.pop(random.randint(0, len(self.list_data_words)-1))

        self.word_answer = self.dict_info_words.get("text_eng", None)
        
        self.word_question = self.dict_info_words.get("text_pt_br", None) 

        self.guessed_word = self.hide_text(self.word_answer) 
        self.remaining_attempts = self.MAX_ATTEMPTS
        self.guessed_letters = set()

        self.timer.play()

    def hide_text(self, text: str) -> str:
        # return [" " if c == " " else "_" for c in text]
        return ['_' if c.isalpha() else c for c in text]

    def show_label_words(self):
        font=("Arial", 12)
        fg="black"
        self.palavras_restantes_label = tk.Label(self, text=f"Palavras restantes: {len(self.list_data_words)}", font=font, fg=fg)
        self.palavras_restantes_label.place(relx=0, rely=0.0, anchor="nw")

    def setup_ui(self):

        self.show_label_words()

        self.word_label = tk.Label(self, text=" ".join(self.guessed_word), font=TITLE_FONT)
        self.word_label.pack(pady=10)

        self.attempts_label = tk.Label(self, text="", font=LABEL_FONT)
        self.attempts_label.pack()

        self.guessed_label = tk.Label(self, text="", font=SMALL_FONT)
        self.guessed_label.pack()

        self.image_label = tk.Label(self)
        self.image_label.pack(pady=10)

        self.hint_label = tk.Label(self, text="", font=LABEL_FONT)
        self.hint_label.pack()

        self.input_frame = tk.Frame(self)
        self.input_frame.pack(pady=10)

        tk.Label(self.input_frame, text="Letra:", font=SMALL_FONT).pack(side="left")
        self.letter_entry = tk.Entry(self.input_frame, width=5, font=LABEL_FONT)
        self.letter_entry.pack(side="left")

        self.guess_button = tk.Button(self.input_frame, text="Adivinhar", command=self.check_guess)
        self.guess_button.pack(side="left", padx=5)

        self.update_ui()

    def update_ui(self):
        
        self.palavras_restantes_label.config(text=f"Palavras restantes: {len(self.list_data_words)}")

        self.word_label.config(text=" ".join(self.guessed_word))
        self.attempts_label.config(text=f"Tentativas restantes: {self.remaining_attempts}")
        self.guessed_label.config(text=f"Letras tentadas: {', '.join(sorted(self.guessed_letters))}")
        self.hint_label.config(text=f"Dica: {self.word_question}")

        # if not img_path.exists():
        #     print(f"[ERRO] Caminho da imagem não encontrado: {img_path}")

        # if not hasattr(self.image_label, 'current_image_path') or self.image_label.current_image_path != img_path:

        image_figure = self.dict_info_words.get("image_figure", None)

        if image_figure:
            img_path = image_figure
            img = Image.open(img_path).resize((200, 200))
            photo = ImageTk.PhotoImage(img)

            self.image_label.config(image=photo)
            self.image_label.image = photo  # <- MANTÉM REFERÊNCIA
        else:
            self.image_label.config(image='')
            self.image_label.image = None

    def check_guess(self):
        self.clicks_on_guess += 1

        guess = self.letter_entry.get().strip().lower()
        self.letter_entry.delete(0, tk.END)

        if not guess.isalpha():
            messagebox.showwarning("Letra inválida", "Digite apenas letras.")
            return

        for letter in guess:
            if letter in self.guessed_letters:
                continue

            self.guessed_letters.add(letter)

            if letter in self.word_answer:
                self.reveal_letters(letter)
            else:
                self.remaining_attempts -= 1

            if self.check_game_end():
                return

        self.update_ui()

    def reveal_letters(self, letter):
        for idx, char in enumerate(self.word_answer):
            if char == letter:
                self.guessed_word[idx] = letter

    def check_game_end(self) -> bool:
        if "_" not in self.guessed_word:
            self.save_score(True)
            messagebox.showinfo("Você venceu!", f"A palavra era: {self.word_answer}")
            self.restart_game()
            return True

        if self.remaining_attempts <= 0:
            self.save_score(False)

            # Coloca a palavra de volta na lista
            self.list_data_words.append(self.dict_info_words)
            
            messagebox.showerror("Fim de jogo", f"A palavra era: {self.word_answer}")
            self.restart_game()
            return True

        return False

    def restart_game(self):
        self.last_word = self.dict_info_words.copy()
        self.reset_game()
        self.update_ui()

    def save_score(self, won: bool):
        attempts_used = self.MAX_ATTEMPTS - self.remaining_attempts
        difficulty = attempts_used / self.MAX_ATTEMPTS

        correct_guessed_letters=[letter for letter in self.guessed_word if letter.isalnum()]
        incorrect_guessed_letters = list(set(self.guessed_letters).difference(set(self.guessed_word)))

        # finaliza_tempo
        # end_time = time.time()
        time_taken = self.timer.elapsed_time

        clicks_on_guess = self.clicks_on_guess

        path_word = self.dict_info_words.get("path", None)
        category = path_word.parts[-3]
        sub_category = path_word.parts[-2]
        # adjetivos/sobre_as_pessoas/unable

        if not any([category == loader_category.name for loader_category in self.loader.get_categories()]):
            print("Categoria Não Existe")

        self.timer.reset_timer()
        self.clicks_on_guess = 0

        # assert total_attempts >= used_attempts, "Tentativas usadas não podem ser maiores que o total permitido."

        datetime_now = datetime.now().isoformat(timespec="seconds")
        

        game_data = {
            "id_game": self.id_game,
            "datetime": datetime_now,
            "word": self.word_answer,
            "category":category,
            "sub_category":sub_category,
            "hint": self.word_question,
            "won": won,
            "difficulty": difficulty,
            "total_attempts": self.MAX_ATTEMPTS,
            "used_attempts": attempts_used,
            "clicks_on_guess": clicks_on_guess,
            "correct_guessed_letters": correct_guessed_letters,
            "incorrect_guessed_letters": incorrect_guessed_letters,
            # "correct_guesses": correct_guesses,
            # "incorrect_guesses": incorrect_guesses,
            "time_taken": time_taken,
            "game_name": "hangman",
        }

        save_game_data(game_data)
        # self.save_score()

    def translate_sentence(self, sentence, source_lang="en", target_lang="pt"):
        try:
            translator = GoogleTranslator(source=source_lang, target=target_lang)
            return translator.translate(sentence)
        except Exception as e:
            print(f"Translation error: {e}")
            return "Translation unavailable"

if __name__ == "__main__":
    try:
        root = tk.Tk()
        root.title("Jogo da Forca com Imagens")
        game = HangmanGame(root)
        game.pack(expand=True, fill="both")
        root.geometry("600x600")
        root.mainloop()
    except Exception as e:
        print(f"Error {e}")
    
    finally:
        root.destroy()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# Cell In[55], line 268
#     265     print(f"Error {e}")
#     267 finally:
# --> 268     root.destroy()
#
# File /usr/lib/python3.12/tkinter/__init__.py:2387, in Tk.destroy(self)
#    2384 """Destroy this and all descendants widgets. This will
#    2385 end the application of this Tcl interpreter."""
#    2386 for c in list(self.children.values()): c.destroy()
# -> 2387 self.tk.call('destroy', self._w)
#    2388 Misc.destroy(self)
#    2389 global _default_root
#
# TclError: can't invoke "destroy" command: application has been destroyed

# %%
from app.utils.data_loader import DataLoader
from pathlib import Path
import os

kind = "phrases"
DATA_PATH = "database/extract_data_video/data/extracted_data/{kind}/data_organize"
SUBCATEGORY_NAME = "em_loja"

os.listdir(DATA_PATH.format(kind=kind))
loader = DataLoader(base_path=DATA_PATH.format(kind=kind))
loader.get_categories(kind_return = "dict").keys()
# Out:
# dict_keys(['viagem', 'compras', 'restaurante_e_bar', 'encontros', 'avião', 'saúde', 'hotel', 'tempo_e_clima', 'comida', 'frases_básicas', 'emergências', 'serviços', 'educação', 'meios_de_comunicação', 'empregos', 'outro_transporte', 'conversa_geral', 'carro', 'fazer_amigos', 'tempo_de_lazer'])

# %%
estrutura = {}
estrutura["cate"] = "teste"


estrutura
# Out:
# {'cate': 'teste'}

# %%
estrutura = {}
list_kinds = ["words", "phrases"]
for kind in list_kinds:
    loader = DataLoader(base_path=DATA_PATH.format(kind=kind))
    estrutura[kind] = {}
    for categoria in loader.get_categories():
        estrutura[kind][categoria.name] = {}
        for subcat in loader.get_subcategories(categoria):
            estrutura[kind][categoria.name][subcat.name] = []
            for word_path in loader.get_word_paths(subcat):
                estrutura[kind][categoria.name][subcat.name].append(word_path.name)

# %%
estrutura["words"]
# Out:
# {'pessoas': {'identidade': ['status',
#    'privacy',
#    'passport',
#    'age',
#    'birth_certificate',
#    'missus',
#    'name',
#    'habit',
#    'citizenship',
#    'nationality',
#    'autograph',
#    'pseudonym',
#    'personality',
#    'human',
#    'reputation',
#    'miss',
#    'last_name',
#    'motherland',
#    'person',
#    'fingerprint',
#    'signature',
#    'mister',
#    'nickname'],
#   'idade_e_eventos_da_vida': ['long-lived',
#    'to_be_born',
#    'young',
#    'ceremony',
#    'to_age',
#    'birthday',
#    'honeymoon',
#    'death',
#    'fireworks',
#    'to_die',
#    'gift',
#    'baby',
#    'to_celebrate',
#    'wedding',
#    'festival',
#    'child',
#    'middle-aged',
#    'engagement',
#    'old',
#    'teenager',
#    'occasion',
#    'parade',
#    'life',
#    'to_congratulate',
#    'to_marry',
#    'invitation',
#    'divorce',
#    'anniversary',
#    'tradition',
#    'mature',
#    'surprise',
#    'to_retire',
#    'adult'],
#   'familia': ['hereditary',
#    'to_adopt',
#    'triplets',
#    'sister',
#    'brother',
#    'daughter',
#    'related',
#    'nephew',
#    'mother',
#    'grandmother',
#    'grandson',
#    'son-in-law',
#    'wife',
#    'aunt',
#    'niece',
#    'brother-in-law',
#    'son',
#    'childless',
#    'adoptive_parents',
#    'father',
#    'paternal',
#    'ancestry',
#    'parents',
#    'grandfather',
#    'great-granddaught_er',
#    'husband',
#    'great-grandmother',
#    'great-grandson',
#    'foster_parents',
#    'granddaughter',
#    'generation',
#    'mother-in-law',
#    'relatives',
#    'cousin',
#    'daughter-in-law',
#    'grandparents',
#    'twins',
#    'uncle',
#    'sister-in-law',
#    'great-grandfather',
#    'maternal',
#    'adoption',
#    'father-in-law'],
#   'amor_e_amizade': ['gang',
#    'couple',
#    'to_meet',
#    'friend',
#    'unmarried',
#    'to_court',
#    'acquaintance',
#    'relationship',
#    'bride',
#    'single',
#    'boyfriend',
#    'stranger',
#    'to_fall_in_love',
#    'to_introduce',
#    'guy',
#    'marriage',
#    'bridesmaid',
#    'igag',
#    'married',
#    'intimacy',
#    'bridegroom',
#    'romantic',
#    'girl',
#    'fiancé',
#    'to_flirt',
#    'proposal',
#    'man',
#    'girlfriend',
#    'colleague',
#    'fiancée',
#    'divorced',
#    'boy',
#    'groomsman',
#    'romance',
#    'woman']},
#  'plantas': {'arvores': ['mahogany',
#    'willow',
#    'eucalyptus',
#    'log',
#    'alder',
#    'sequoia',
#    'pine',
#    'oak',
#    'beech',
#    'spruce',
#    'acorn',
#    'tree',
#    'linden',
#    'pinecone',
#    'sapling',
#    'elm',
#    'fir',
#    'birch',
#    'yew',
#    'maple',
#    'magnolia',
#    'aspen',
#    'poplar',
#    'stick',
#    'acacia',
#    'chestnut_tree',
#    'branch',
#    'leaf',
#    'cedar',
#    'cypress'],
#   'arbustos': ['rosemary',
#    'raspberry',
#    'rhododendron',
#    'cassava',
#    'strawberry',
#    'holly',
#    'shrub',
#    'blackberry',
#    'lilac',
#    'bush',
#    'privet',
#    'cranberry',
#    'myrtle',
#    'blueberry',
#    'hydrangea'],
#   'agricultura': ['tractor',
#    'irrigation',
#    'plantation',
#    'to_feed',
#    'barn',
#    'plow',
#    'mud',
#    'windmill',
#    'hay',
#    'trap',
#    'to_fertilize',
#    'agriculturist',
#    'to_cultivate',
#    'to_hoe',
#    'to_ripen',
#    'to_reap',
#    'to_harrow',
#    'scarecrow',
#    'herbicide',
#    'seedling',
#    'harvest',
#    'sprinkler',
#    'vineyard',
#    'farm',
#    'to_rake',
#    'to_garden',
#    'gardener',
#    'gardening',
#    'infertile',
#    'spade',
#    'scythe',
#    'rake',
#    'orchard',
#    'soil',
#    'to_sow',
#    'to_water',
#    'to_plow',
#    'crop',
#    'to_gather',
#    'agriculture',
#    'field',
#    'herbarium',
#    'fertilizer',
#    'to_sweep',
#    'to_flower',
#    'to_mow',
#    'greenhouse',
#    'shovel',
#    'fertile',
#    'breeder',
#    'to_plant',
#    'to_shovel',
#    'to_irrigate'],
#   'flores': ['lavender',
#    'chrysanthemum',
#    'blossom',
#    'anemone',
#    'daffodil',
#    'primrose',
#    'peony',
#    'begonia',
#    'daisy',
#    'dahlia',
#    'rose',
#    'camellia',
#    'gerbera',
#    'lily',
#    'azalea',
#    'hyacinth',
#    'freesia',
#    'iris',
#    'orchid',
#    'tulip',
#    'carnation',
#    'violet',
#    'poppy',
#    'cyclamen',
#    'bouquet',
#    'buttercup',
#    'sunflower',
#    'lotus',
#    'gladiolus',
#    'dandelion',
#    'forget-me-not',
#    'snowdrop',
#    'marigold',
#    'pansy',
#    'flower'],
#   'arvores_de_fruto': ['almond_tree',
#    'pomegranate_tree',
#    'avocado_tree',
#    'tamarind_tree',
#    'olive_tree',
#    'quince_tree',
#    'apricot_tree',
#    'pear_tree',
#    'plum',
#    'lemon_tree',
#    'lime_tree',
#    'cacao',
#    'guava_tree',
#    'mango_tree',
#    'grapefruit_tree',
#    'hazelnut_tree',
#    'cherry_tree',
#    'pistachio_tree',
#    'cashew_tree',
#    'peach_tree',
#    'persimmon_tree',
#    'orange_tree',
#    'apple_tree',
#    'macadamia_nut_tree'],
#   'sobre_as_plantas': ['bud',
#    'trunk',
#    'growth',
#    'to_wither',
#    'to_replant',
#    'flora',
#    'thorn',
#    'stem',
#    'twig',
#    'species',
#    'pollen',
#    'nectar',
#    'sprout',
#    'vegetation',
#    'bark',
#    'root',
#    'petal'],
#   'outras_plantas': ['kelp',
#    'chickweed',
#    'jasmine',
#    'rapeseed',
#    'tobacco',
#    'plant',
#    'briar',
#    'alfalfa',
#    'papyrus',
#    'ginseng',
#    'bamboo',
#    'sundew',
#    'arnica',
#    'thatch',
#    'aloe',
#    'grass',
#    'cotton',
#    'mistletoe',
#    'seaweed',
#    'chamomile',
#    'reed',
#    'hop',
#    'nettle',
#    'clover',
#    'shoot',
#    'thistle',
#    'fern',
#    'fuchsia',
#    'periwinkle',
#    'geranium',
#    'rushes',
#    'tansy',
#    'cactus',
#    'foxglove',
#    'buckthorn',
#    'hyssop',
#    'honeysuckle',
#    'ivy',
#    'rue',
#    'moss',
#    'fungus']},
#  'compras': {'papelaria': ['pen',
#    'stapler',
#    'chalk',
#    'staple',
#    'cardboard',
#    'coloured_pencil',
#    'cartridge',
#    'datebook',
#    'stationery',
#    'highlighter',
#    'pencil_sharpener',
#    'paper_clip',
#    'thumbtack',
#    'correction_fluid',
#    'ruler',
#    'toner',
#    'crayon',
#    'sheet',
#    'marker',
#    'scissors',
#    'glue',
#    'folder',
#    'notebook',
#    'eraser',
#    'watercolor',
#    'paper',
#    'notepad',
#    'pencil'],
#   'loja_de_ferragens': ['tool',
#    'saw',
#    'hammer',
#    'nail',
#    'valve',
#    'nut',
#    'wedge',
#    'bulb',
#    'ax',
#    'bolt',
#    'pincers',
#    'clamp',
#    'jigsaw',
#    'sledgehammer',
#    'screw',
#    'wrench',
#    'drill',
#    'lock',
#    'screwdriver',
#    'pump',
#    'spike',
#    'handle',
#    'toolbox',
#    'hardware',
#    'faucet'],
#   'livraria': ['atlas',
#    'audiobook',
#    'dictionary',
#    'exercise_book',
#    'encyclopedia',
#    'textbook',
#    'map',
#    'comic_book',
#    'greeting_card',
#    'souvenir',
#    'postcard',
#    'magazine',
#    'newspaper'],
#   'loja_de_eletrodomesticos': ['projector',
#    'plug',
#    'scanner',
#    'freezer',
#    'microphone',
#    'adapter',
#    'fan',
#    'washing_machine',
#    'cable',
#    'speaker',
#    'fax',
#    'calculator',
#    'microwave_oven',
#    'dishwasher',
#    'range',
#    'wire',
#    'iron',
#    'camera',
#    'outlet',
#    'headphones',
#    'video_camera',
#    'appliance',
#    'switch',
#    'battery',
#    'flashlight',
#    'blender',
#    'vacuum_cleaner',
#    'charger',
#    'clock',
#    'alarm_clock',
#    'satellite_dish',
#    'mixer',
#    'oven',
#    'laptop',
#    'copier',
#    'printer',
#    'refrigerator',
#    'shredder',
#    'webcam'],
#   'produtos_para_o_lar': ['broom',
#    'dustpan',
#    'plastic_bag',
#    'brush',
#    'sponge',
#    'trash_bag',
#    'air_freshener',
#    'pail',
#    'washing_powder',
#    'furniture_polish',
#    'ladder',
#    'barrel',
#    'rag',
#    'peg',
#    'match',
#    'apron',
#    'box',
#    'lighter',
#    'fabric_softener',
#    'mop',
#    'bleach',
#    'basket',
#    'detergent',
#    'dishwashing_liquid',
#    'garbage_can',
#    'household_products'],
#   'loja_de_utensilios_de_cozinha': ['dish',
#    'timer',
#    'skewer',
#    'corkscrew',
#    'mug',
#    'bottle',
#    'lid',
#    'funnel',
#    'utensils',
#    'grater',
#    'cork',
#    'cookie_sheet',
#    'glass',
#    'coaster',
#    'vessel',
#    'kettle',
#    'platter',
#    'can',
#    'kitchenware',
#    'saucer',
#    'cake_tin',
#    'broiler',
#    'skillet',
#    'tongs',
#    'jar',
#    'bowl',
#    'colander',
#    'plate',
#    'steamer',
#    'fork',
#    'pitcher',
#    'teapot',
#    'knife',
#    'whisk',
#    'casserole_dish',
#    'opener',
#    'teaspoon',
#    'toothpick',
#    'fish_slice',
#    'ladle',
#    'foil',
#    'rolling_pin',
#    'spoon'],
#   'loja_de_cosméticos': ['blush',
#    'lipstick',
#    'eyeshadow',
#    'cologne',
#    'cosmetics',
#    'cotton_pad',
#    'lip_gloss',
#    'nail_polish_remover',
#    'eyeliner',
#    'lotion',
#    'make-up',
#    'perfume',
#    'mascara',
#    'cream',
#    'concealer',
#    'foundation',
#    'lip_liner',
#    'makeup_remover',
#    'eyebrow_pencil',
#    'hairspray',
#    'powder',
#    'nail_polish',
#    'deodorant',
#    'wet_wipes'],
#   'em_loja': ['consumer',
#    'scanner',
#    'line',
#    'to_shop',
#    'cost',
#    'store_window',
#    'department',
#    'to_sell',
#    'stand',
#    'checkout',
#    'sales_slip',
#    'dressing_room',
#    'to_spend',
#    'aisle',
#    'goods',
#    'counter',
#    'to_buy',
#    'shopping_list',
#    'scale',
#    'shopping',
#    'cart',
#    'price_tag',
#    'discount'],
#   'loja_de_artigos_para_criança': ['doll',
#    'balloon',
#    'sled',
#    'top',
#    'rattle',
#    'toy',
#    'stuffed_toy',
#    'slingshot',
#    'dollhouse',
#    'teddy_bear',
#    'playpen',
#    'diaper',
#    'pinwheel',
#    'yo-yo',
#    'boomerang',
#    'bonnet',
#    'potty',
#    'pacifier',
#    'kite',
#    'bib',
#    'stroller',
#    'puppet',
#    'roly-poly'],
#   'loja_de_produtos_de_banho': ['shampoo',
#    'razor_blade',
#    'tweezers',
#    'shaving_foam',
#    'toilet_paper',
#    'floss',
#    'conditioner',
#    'hygiene',
#    'razor',
#    'toothpaste',
#    'balsam',
#    'cotton_swab',
#    'soap',
#    'toothbrush',
#    'shower_gel',
#    'mouthwash'],
#   'compras_online': ['customer_service',
#    'offer',
#    'assortment',
#    'delivery',
#    'price',
#    'return',
#    'buyer',
#    'refund',
#    'order',
#    'account',
#    'to_track',
#    'item',
#    'sale',
#    'tracking',
#    'to_purchase'],
#   'tipos_de_lojas': ['storekeeper',
#    'boutique',
#    'bookstore',
#    'flea_market',
#    'supermarket',
#    'shopping_mall',
#    "butcher's",
#    "fishmonger's",
#    'market',
#    'store',
#    'bakeshop',
#    'flower_shop',
#    'stall',
#    "greengrocer's",
#    'hardware_store',
#    'antique_shop',
#    'second-hand_shop',
#    'workshop',
#    "jeweller's",
#    'toy_store',
#    'grocery_store',
#    'kiosk',
#    'furniture_store',
#    'pawnshop',
#    'perfumery']},
#  'comunicações': {'internet': ['server',
#    'wireless',
#    'feed',
#    'to_download',
#    'to_surf',
#    'e-mail_address',
#    'notification',
#    'terabyte',
#    'network',
#    'profile',
#    'password',
#    'online',
#    'router',
#    'browser',
#    'social_network',
#    'link',
#    'comment',
#    'offline',
#    'website',
#    'attachment',
#    'chat',
#    'web',
#    'subscriber',
#    'gigabyte',
#    'login',
#    'internet',
#    'modem',
#    'spam',
#    'smiley',
#    'inbox',
#    'data',
#    'user',
#    'megabyte',
#    'to_upload',
#    'to_forward',
#    'portal',
#    'byte',
#    'bit',
#    'to_update',
#    'e-mail'],
#   'correio': ['mailbox',
#    'mail',
#    'to_send',
#    'to_dispatch',
#    'to_receive',
#    'airmail',
#    'post_office',
#    'recipient',
#    'envelope',
#    'letter',
#    'sender',
#    'to_deliver',
#    'package',
#    'address',
#    'mailman',
#    'addressee',
#    'to_address'],
#   'jornalismo': ['journalism',
#    'information',
#    'mass-media',
#    'publication',
#    'interviewer',
#    'article',
#    'to_interview',
#    'headline',
#    'sources',
#    'reporter',
#    'to_advertise',
#    'poster'],
#   'computadores': ['operation',
#    'programming',
#    'to_access',
#    'multimedia',
#    'memory_stick',
#    'file',
#    'informatics',
#    'to_click',
#    'virtual',
#    'toolbar',
#    'to_delete',
#    'processor',
#    'digital',
#    'to_restart',
#    'computer',
#    'system',
#    'software',
#    'monitor',
#    'to_install',
#    'subscription',
#    'robot',
#    'click',
#    'tablet',
#    'image',
#    'hacker',
#    'radiation',
#    'interactive',
#    'user-friendly',
#    'keyboard',
#    'application',
#    'interface',
#    'to_uninstall',
#    'mouse',
#    'font',
#    'to_scroll',
#    'technology',
#    'program',
#    'desktop'],
#   'telefones': ['to_call',
#    'display',
#    'contacts',
#    'connection',
#    'to_vibrate',
#    'phone',
#    'to_contact',
#    'to_dial',
#    'message',
#    'voice_message',
#    'call',
#    'ringtone',
#    'to_charge'],
#   'tv_e_rádio': ['to_broadcast',
#    'dj',
#    'channel',
#    'viewer',
#    'advertisement',
#    'tv-show',
#    'to_turn_off',
#    'episode',
#    'news',
#    'radio_station',
#    'listener',
#    'recording',
#    'presenter',
#    'remote_control',
#    'radio',
#    'video',
#    'show',
#    'television',
#    'program',
#    'live',
#    'to_turn_on']},
#  'trabalho': {'empregos_1': ['housekeeper',
#    'pharmacist',
#    'florist',
#    'poet',
#    'model',
#    'teacher',
#    'secretary',
#    'technician',
#    'architect',
#    'veterinarian',
#    'baker',
#    'doctor',
#    'confectioner',
#    'judge',
#    'translator',
#    'job',
#    'actress',
#    'driver',
#    'programmer',
#    'lecturer',
#    'artist',
#    'worker',
#    'butcher',
#    'clown',
#    'accountant',
#    'sculptor',
#    'fishmonger',
#    'sommelier',
#    'policeman',
#    'writer',
#    'salesman',
#    'engineer',
#    'farmer',
#    'profession',
#    'cook',
#    'bartender',
#    'barber',
#    'cashier',
#    'designer',
#    'potter',
#    'tailor',
#    'dancer',
#    'expert',
#    'attorney',
#    'nurse',
#    'pilot',
#    'musician',
#    'hairdresser',
#    'sailor',
#    'singer',
#    'journalist',
#    'chef',
#    'firefighter',
#    'waiter'],
#   'bancos': ['credit_card',
#    'tax',
#    'payment',
#    'exchange',
#    'transaction',
#    'bank',
#    'dollar',
#    'euro',
#    'financial',
#    'credit',
#    'duty',
#    'currency',
#    'bank_transfer',
#    'to_invest',
#    'fund',
#    'to_sponsor',
#    'fee',
#    'financing',
#    'pin_number',
#    'investment',
#    'to_finance',
#    'capital',
#    'economic',
#    'bill',
#    'check',
#    'bank_account',
#    'debt',
#    'coin',
#    'form',
#    'to_pay',
#    'money',
#    'balance',
#    'yen',
#    'cash'],
#   'empregos_2': ['blacksmith',
#    'tutor',
#    'lifeguard',
#    'assistant',
#    'diplomat',
#    'carpenter',
#    'biographer',
#    'aviator',
#    'bookseller',
#    'travel_agent',
#    'broker',
#    'sheepherder',
#    'advisor',
#    'craftsman',
#    'administrator',
#    'publisher',
#    'part-time',
#    'plumber',
#    'full-time',
#    'cowboy',
#    'receptionist',
#    'analyst',
#    'agent',
#    'observer',
#    'builder',
#    'occupation',
#    'spy',
#    'doorman',
#    'usher',
#    'entrepreneur',
#    'cleaner',
#    'editor',
#    'beekeeper',
#    'magician',
#    'flight_attendant',
#    'philosopher',
#    'archivist',
#    'antiquarian',
#    'librarian',
#    'clerk',
#    'ghostwriter',
#    'paparazzo',
#    'bodyguard',
#    'stunt_double',
#    'producer',
#    'miller',
#    'locksmith',
#    'deputy',
#    'bookmaker',
#    'critic',
#    'security_guard'],
#   'negócio': ['consultant',
#    'plan',
#    'organization',
#    'logo',
#    'commerce',
#    'client',
#    'cooperation',
#    'service',
#    'sponsor',
#    'monopoly',
#    'founder',
#    'representative',
#    'development',
#    'budget',
#    'factory',
#    'company',
#    'marketing',
#    'committee',
#    'administration',
#    'associate',
#    'investor',
#    'export',
#    'to_contract',
#    'profit',
#    'mediator',
#    'industry',
#    'economy',
#    'spokesman',
#    'business',
#    'to_negotiate',
#    'to_cost',
#    'corporation',
#    'brand',
#    'agreement',
#    'owner',
#    'firm',
#    'partnership',
#    'franchise',
#    'import',
#    'association',
#    'enterprise',
#    'logistics',
#    'partner'],
#   'local_de_trabalho': ['employment',
#    'career',
#    'to_work',
#    'license',
#    'leader',
#    'salary',
#    'to_sign',
#    'to_scan',
#    'busy',
#    'income',
#    'position',
#    'employer',
#    'teamwork',
#    'document',
#    'to_hire',
#    'to_earn',
#    'résumé',
#    'contract',
#    'applicant',
#    'boss',
#    'duty',
#    'job_interview',
#    'paperwork',
#    'management',
#    'agency',
#    'work',
#    'project',
#    'meeting',
#    'agenda',
#    'pension',
#    'office_building',
#    'to_stipulate',
#    'employee',
#    'to_copy',
#    'payday',
#    'shift',
#    'workplace',
#    'office',
#    'staff',
#    'promotion',
#    'meeting_room',
#    'raise']},
#  'adjetivos': {'descrições_2': ['endless',
#    'excessive',
#    'ready',
#    'insufficient',
#    'social',
#    'southern',
#    'unavailable',
#    'destructive',
#    'efficient',
#    'crowded',
#    'northern',
#    'final',
#    'extraterrestrial',
#    'sufficient',
#    'numerous',
#    'typical',
#    'eastern',
#    'obvious',
#    'loud',
#    'technological',
#    'abundant',
#    'western',
#    'confidential',
#    'imaginary',
#    'central',
#    'partial',
#    'strategic',
#    'secret',
#    'nuclear',
#    'urgent',
#    'commercial',
#    'public',
#    'equal',
#    'available',
#    'random',
#    'global',
#    'worldwide',
#    'constant',
#    'alternative'],
#   'descrição_de_objetos': ['portable',
#    'flexible',
#    'qualitative',
#    'automatic',
#    'broken',
#    'golden',
#    'empty',
#    'fireproof',
#    'electric',
#    'standard',
#    'rusty',
#    'slow',
#    'sparkling',
#    'furry',
#    'open',
#    'translucent',
#    'wooden',
#    'moist',
#    'recyclable',
#    'waterproof',
#    'transparent',
#    'elastic',
#    'innovative',
#    'durable',
#    'full',
#    'wet',
#    'new',
#    'sticky',
#    'heavy',
#    'silver',
#    'authentic',
#    'light',
#    'precious',
#    'glossy',
#    'metallic',
#    'old',
#    'inflexible',
#    'priceless',
#    'cheap',
#    'closed',
#    'electronic',
#    'expensive',
#    'fast',
#    'sophisticated',
#    'valuable',
#    'shiny',
#    'fluffy',
#    'ideal',
#    'hard',
#    'soft',
#    'fragile'],
#   'pares_2': ['improbable',
#    'valid',
#    'physical',
#    'sharp',
#    'incomplete',
#    'exact',
#    'invalid',
#    'vacant',
#    'mental',
#    'accessible',
#    'inexact',
#    'blunt',
#    'national',
#    'probable',
#    'stable',
#    'general',
#    'independent',
#    'superior',
#    'harmful',
#    'formal',
#    'informal',
#    'solid',
#    'unstable',
#    'specific',
#    'useful',
#    'liquid',
#    'useless',
#    'human',
#    'united',
#    'inaccessible',
#    'separate',
#    'international',
#    'harmless',
#    'dependent',
#    'wanted',
#    'inferior',
#    'unwanted',
#    'occupied',
#    'complete',
#    'non-human'],
#   'descição_de_arte': ['progressive',
#    'brief',
#    'vague',
#    'diverse',
#    'amazing',
#    'notable',
#    'comic',
#    'cultural',
#    'symbolic',
#    'eccentric',
#    'dubious',
#    'overrated',
#    'complex',
#    'historic',
#    'convincing',
#    'illogical',
#    'classical',
#    'meaningless',
#    'constructive',
#    'recent',
#    'satirical',
#    'exceptional',
#    'admirable',
#    'artistic',
#    'distinguished',
#    'trivial',
#    'futuristic',
#    'antique',
#    'unforgettable',
#    'original',
#    'shocking',
#    'tragic',
#    'impressive',
#    'extraordinary',
#    'logical',
#    'paradoxical',
#    'nplic',
#    'promising',
#    'underrated',
#    'splendid',
#    'aberrant',
#    'provocative',
#    'confusing',
#    'realistic',
#    'expressive',
#    'intuitive'],
#   'pares_1': ['lucky',
#    'minimal',
#    'deep',
#    'old-fashioned',
#    'prepared',
#    'effective',
#    'fair',
#    'front',
#    'visible',
#    'shallow',
#    'direct',
#    'unlucky',
#    'far',
#    'natural',
#    'safe',
#    'absent',
#    'unclear',
#    'clear',
#    'modern',
#    'unusual',
#    'artificial',
#    'real',
#    'impossible',
#    'ineffective',
#    'true',
#    'possible',
#    'unused',
#    'close',
#    'invisible',
#    'unreal',
#    'indirect',
#    'dangerous',
#    'identical',
#    'used',
#    'unfair',
#    'present',
#    'different',
#    'unprepared',
#    'back',
#    'false',
#    'usual',
#    'maximal'],
#   'descrições_1': ['triple',
#    'dense',
#    'various',
#    'powerful',
#    'local',
#    'dynamic',
#    'fixed',
#    'proportionate',
#    'relative',
#    'individual',
#    'special',
#    'immediate',
#    'ethnic',
#    'mino',
#    'known',
#    'other',
#    'multicultural',
#    'analogous',
#    'mixed',
#    'technical',
#    'main',
#    'regional',
#    'disproportionate',
#    'external',
#    'intense',
#    'middle',
#    'majo',
#    'double',
#    'foreign',
#    'compact',
#    'static',
#    'extreme',
#    'infinite',
#    'magnetic',
#    'traditional',
#    'distant',
#    'only',
#    'luminous',
#    'extra',
#    'total',
#    'additional'],
#   'descrições_3': ['threatening',
#    'adjacent',
#    'opposite',
#    'forgivable',
#    'integrated',
#    'vast',
#    'optimal',
#    'consecutive',
#    'subordinate',
#    'tiring',
#    'hypothetical',
#    'irreversible',
#    'arbitrary',
#    'routine',
#    'reversible',
#    'troublesome',
#    'essential',
#    'inexistent',
#    'moderate',
#    'repeated',
#    'detailed',
#    'universal',
#    'home-made',
#    'prestigious',
#    'unforgivable',
#    'tidy',
#    'worthy',
#    'comparative',
#    'forgotten',
#    'existent',
#    'voluntary',
#    'depressing',
#    'vital',
#    'hidden',
#    'contradictory'],
#   'sobre_as_pessoas': ['unpopular',
#    'dead',
#    'myopic',
#    'ironic',
#    'well-known',
#    'objective',
#    'unqualified',
#    'alive',
#    'lame',
#    'literate',
#    'crazy',
#    'subjective',
#    'talented',
#    'rich',
#    'illiterate',
#    'successful',
#    'strong',
#    'rational',
#    'qualified',
#    'unknown',
#    'anonymous',
#    'mute',
#    'deaf-mute',
#    'blind',
#    'deaf',
#    'able',
#    'intellectual',
#    'popular',
#    'irrational',
#    'spontaneous',
#    'weak',
#    'free',
#    'pregnant',
#    'unable',
#    'naked',
#    'famous']},
#  'corpo': {'membros_do_corpo': ['toe',
#    'leg',
#    'fist',
#    'wrist',
#    'chest',
#    'arm',
#    'belly',
#    'knuckles',
#    'forearm',
#    'hand',
#    'nail',
#    'joint',
#    'elbow',
#    'knee',
#    'body',
#    'shin',
#    'thigh',
#    'neck',
#    'instep',
#    'foot',
#    'palm',
#    'finger',
#    'waist',
#    'ankle',
#    'cuticle',
#    'shoulder',
#    'armpit',
#    'back',
#    'calf',
#    'heel',
#    'sole'],
#   'orgãos_internos': ['gland',
#    'to_ferment',
#    'throat',
#    'artery',
#    'hormone',
#    'orgal',
#    'larynx',
#    'kidneys',
#    'anatomy',
#    'appendix',
#    'liver',
#    'stomach',
#    'blood',
#    'heart',
#    'vocal_cords',
#    'respiration',
#    'metabolism',
#    'saliva',
#    'pancreas',
#    'intestine',
#    'diaphragm',
#    'lungs',
#    'thyroid_gland',
#    'spleen',
#    'adenoids',
#    'large_intestine',
#    'esophagus',
#    'digestion',
#    'tonsils',
#    'tear',
#    'neuron',
#    'pulse',
#    'to_digest',
#    'windpipe',
#    'internal',
#    'epiglottis',
#    'bile',
#    'glottis',
#    'small_intestine',
#    'snot',
#    'pharynx',
#    "adam's_apple",
#    'bladder'],
#   'esqueleto_e_musculos': ['pore',
#    'marrow',
#    'bone',
#    'vertebra',
#    'cheekbones',
#    'biceps',
#    'maxilla',
#    'mandible',
#    'tissue',
#    'backbone',
#    'rib',
#    'musculature',
#    'jaw',
#    'tendon',
#    'achilles_tendon',
#    'ligament',
#    'muscle',
#    'skull',
#    'membrane',
#    'skin',
#    'triceps',
#    'cartilage',
#    'tailbone',
#    'muscular',
#    'skeleton',
#    'vein',
#    'capillary',
#    'nerve'],
#   'cabeça_e_rosto': ['lips',
#    'sigh',
#    'mouth',
#    'freckles',
#    'smile',
#    'sense',
#    'frown',
#    'hearing',
#    'face',
#    'eye',
#    'nostrils',
#    'sight',
#    'forehead',
#    'nose',
#    'smell',
#    'hair',
#    'eyelid',
#    'brain',
#    'beard',
#    'eyebrow',
#    'eyelashes',
#    'yawn',
#    'tongue',
#    'cheek',
#    'taste',
#    'head',
#    'mustache',
#    'ear',
#    'chin'],
#   'ações': ['to_whistle',
#    'to_kiss',
#    'to_sit',
#    'to_write',
#    'to_put',
#    'to_yawn',
#    'to_hiccup',
#    'to_snore',
#    'to_eat',
#    'to_drink',
#    'to_taste',
#    'to_jump',
#    'to_cough',
#    'to_sip',
#    'to_move',
#    'to_listen',
#    'to_hear',
#    'to_bring',
#    'to_laugh',
#    'to_wake_up',
#    'to_lick',
#    'to_speak',
#    'to_smell',
#    'to_chew',
#    'to_exhale',
#    'to_giggle',
#    'to_fall_asleep',
#    'to_sigh',
#    'to_see',
#    'to_read',
#    'to_give',
#    'to_fall',
#    'to_spit',
#    'to_cry',
#    'to_wash',
#    'to_touch',
#    'to_inhale',
#    'to_whisper',
#    'to_smile',
#    'to_suck',
#    'to_take',
#    'to_look',
#    'action',
#    'to_hug',
#    'to_walk',
#    'to_swallow',
#    'to_watch',
#    'to_stand',
#    'to_stand_up',
#    'to_breathe',
#    'to_blow',
#    'to_sleep']},
#  'ambiente': {'rochas_e_pedras_preciosas': ['opal',
#    'rock',
#    'sapphire',
#    'pearl',
#    'agate',
#    'gem',
#    'marble',
#    'turquoise',
#    'diamond',
#    'malachite',
#    'amber',
#    'aquamarine',
#    'sandstone',
#    'fluorite',
#    'pebbles',
#    'granite',
#    'ruby',
#    'lava',
#    'moonstone',
#    'boulder',
#    'emerald',
#    'stone',
#    'obsidian',
#    'ivory',
#    'alabaster',
#    'topaz',
#    'amethyst'],
#   'tempo': ['to_rain',
#    'breeze',
#    'rainy',
#    'sunny',
#    'cool',
#    'temperature',
#    'drizzle',
#    'hailstone',
#    'cold',
#    'windy',
#    'alr',
#    'frosty',
#    'damp',
#    'slippery',
#    'warm',
#    'precipitation',
#    'snowflake',
#    'weather_forecast',
#    'rain',
#    'drought',
#    'icy',
#    'frost',
#    'hot',
#    'to_snow',
#    'humidity',
#    'cloudy',
#    'weather',
#    'degree',
#    'stormy',
#    'raindrop',
#    'icicle',
#    'wind',
#    'foggy',
#    'cloud',
#    'snow'],
#   'poluição': ['pollution',
#    'smog',
#    'to_recycle',
#    'landfill',
#    'trash',
#    'ecology',
#    'global_warming',
#    'recycling',
#    'greenhouse_effect',
#    'plastic',
#    'purification',
#    'pollutants',
#    'environment',
#    'nature',
#    'wastewater',
#    'ecosystem',
#    'dirty'],
#   'corpo_de_água': ['pond',
#    'whirlpool',
#    'ocean',
#    'underground',
#    'riverbed',
#    'canal',
#    'bay',
#    'lake',
#    'reservoir',
#    'iceberg',
#    'river',
#    'lagoon',
#    'glacier',
#    'waterway',
#    'brook',
#    'puddle',
#    'waterfall',
#    'flow',
#    'spring',
#    'strait',
#    'watershed',
#    'groundwater',
#    'stream',
#    'sea'],
#   'fenómenos_naturais': ['phenomenon',
#    'snowstorm',
#    'fog',
#    'calamity',
#    'tornado',
#    'rainbow',
#    'cyclone',
#    'flood',
#    'whirlwind',
#    'disaster',
#    'eruption',
#    'arthquak',
#    'avalanche',
#    'landslide',
#    'sleet',
#    'hail',
#    'thunder',
#    'disastrous',
#    'hurricane',
#    'lightning',
#    'catastrophic',
#    'storm',
#    'dew',
#    'tsunami',
#    'sandstorm',
#    'catastrophe'],
#   'minerais_e_matais': ['gold',
#    'zinc',
#    'crystal',
#    'asbestos',
#    'metal',
#    'alloy',
#    'glass',
#    'iron',
#    'rust',
#    'bronze',
#    'silver',
#    'gypsum',
#    'nugget',
#    'coal',
#    'aluminum',
#    'mineral',
#    'clay',
#    'brass',
#    'tin',
#    'nickel',
#    'platinum',
#    'steel',
#    'graphite',
#    'porcelain',
#    'quartz'],
#   'paisagem': ['coral_reef',
#    'cliff',
#    'woodland',
#    'mountain',
#    'picturesque',
#    'rainforest',
#    'valley',
#    'forestry',
#    'prairie',
#    'turf',
#    'tundra',
#    'coast',
#    'desert',
#    'oakwood',
#    'wilderness',
#    'glade',
#    'oasis',
#    'landmass',
#    'savannah',
#    'canyon',
#    'jungle',
#    'landscape',
#    'reef',
#    'hill',
#    'volcano',
#    'seashore',
#    'taiga',
#    'meadow',
#    'plateau',
#    'forest',
#    'land',
#    'steppe',
#    'dune',
#    'plain',
#    'cave']},
#  'descrição_de_pessoas': {'caracteriscicas_4': ['merciless',
#    'sluggish',
#    'frank',
#    'smug',
#    'submissive',
#    'defenseless',
#    'choosy',
#    'idle',
#    'indiscreet',
#    'vicious',
#    'severe',
#    'impertinent',
#    'sensitive',
#    'oblivious',
#    'pitiless',
#    'inactive',
#    'rebellious',
#    'obnoxious',
#    'sarcastic',
#    'haughty',
#    'cold-blooded',
#    'vile'],
#   'sentimentos': ['boredom',
#    'loneliness',
#    'stress',
#    'curiosity',
#    'joy',
#    'mood',
#    'tension',
#    'compassion',
#    'respect',
#    'disrespect',
#    'peace',
#    'motivation',
#    'sympathy',
#    'satisfaction',
#    'passion',
#    'harmony',
#    'hatred',
#    'regret',
#    'sense_of_humor',
#    'anger',
#    'despair',
#    'emotion',
#    'irritation',
#    'shame',
#    'unhappiness',
#    'admiration',
#    'hope',
#    'aggression',
#    'happiness',
#    'feeling',
#    'euphoria',
#    'indifference',
#    'panic',
#    'love',
#    'greed',
#    'pride',
#    'pleasure',
#    'self-confidence',
#    'relief',
#    'sadness',
#    'doubt',
#    'care',
#    'fear'],
#   'caracteristicas_fisicas': ['appearance',
#    'gorgeous',
#    'complexion',
#    'adorable',
#    'agile',
#    'sloppy',
#    'pretty',
#    'graceful',
#    'attractive',
#    'ugly',
#    'beautiful',
#    'tall',
#    'skinny',
#    'athletic',
#    'tanned',
#    'short',
#    'voluptuous',
#    'pallid',
#    'slender',
#    'nice',
#    'posture',
#    'mole',
#    'build',
#    'handsome',
#    'lovely',
#    'bald',
#    'burly',
#    'overweight',
#    'figure',
#    'corpulent',
#    'obese',
#    'unattractive',
#    'charming',
#    'breathtaking',
#    'neat',
#    'vigorous',
#    'smooth',
#    'chubby',
#    'aspect',
#    'cute',
#    'hairy',
#    'charismatic'],
#   'valores_e_vícios': ['racism',
#    'courage',
#    'power',
#    'kindness',
#    'envy',
#    'equality',
#    'truth',
#    'purity',
#    'friendship',
#    'arrogance',
#    'wisdom',
#    'patriotism',
#    'value',
#    'disloyalty',
#    'virtue',
#    'revenge',
#    'loyalty',
#    'responsibility',
#    'vice',
#    'jealousy',
#    'vanity',
#    'patience',
#    'laziness',
#    'honesty',
#    'lie',
#    'impatience',
#    'dishonesty',
#    'devotion',
#    'discrimination',
#    'guilt',
#    'weakness',
#    'honor'],
#   'opiniões_das_pessoas': ['unexpected',
#    'wonderful',
#    'awful',
#    'strange',
#    'acceptable',
#    'unbelievable',
#    'inconvenient',
#    'good',
#    'personal',
#    'terrible',
#    'scary',
#    'mysterious',
#    'unfamiliar',
#    'surprising',
#    'fine',
#    'perfect',
#    'unique',
#    'easy',
#    'absurd',
#    'interesting',
#    'unimportant',
#    'expected',
#    'vulgar',
#    'boring',
#    'bad',
#    'super',
#    'convenient',
#    'offensive',
#    'unpleasant',
#    'miraculous',
#    'wrong',
#    'mediocre',
#    'fantastic',
#    'neutral',
#    'difficult',
#    'simple',
#    'believable',
#    'unacceptable',
#    'great',
#    'frightening',
#    'opinion',
#    'right',
#    'risky',
#    'bizarre',
#    'adequate',
#    'inadequate',
#    'fun',
#    'pleasant',
#    'familiar',
#    'complicated',
#    'important',
#    'excellent',
#    'favorite',
#    'imperfect'],
#   'estados_físicas': ['energetic',
#    'hungry',
#    'thirsty',
#    'sober',
#    'awake',
#    'tired',
#    'sweaty',
#    'exhausted',
#    'asleep',
#    'dizzy'],
#   'caracteristicas_3': ['organized',
#    'merciful',
#    'assertive',
#    'straightforwarc',
#    'loving',
#    'witty',
#    'avid',
#    'diplomatic',
#    'respectable',
#    'sensible',
#    'extroverted',
#    'introverted',
#    'cooperative',
#    'humble',
#    'devoted',
#    'conscious',
#    'idealistic',
#    'competent',
#    'professional'],
#   'caracteristicas_2': ['stupid',
#    'arrogant',
#    'critical',
#    'envious',
#    'stubborn',
#    'anxious',
#    'shameless',
#    'careless',
#    'unfriendly',
#    'timio',
#    'childish',
#    'lazy',
#    'forgetful',
#    'impolite',
#    'rude',
#    'naughty',
#    'suspicious',
#    'indifferent',
#    'irresponsible',
#    'negative',
#    'wicked',
#    'shy',
#    'cynical',
#    'helpless',
#    'insecure',
#    'unsuccessful',
#    'passive',
#    'disorganized',
#    'aggressive',
#    'dishonest',
#    'sly',
#    'foolish',
#    'naive',
#    'mean',
#    'cruel',
#    'incompetent',
#    'selfish',
#    'disobedient',
#    'unreliable',
#    'rigid',
#    'mad',
#    'clumsy',
#    'greedy',
#    'disrespectful',
#    'impatient',
#    'pessimistic'],
#   'caracteristicas_1': ['strict',
#    'friendly',
#    'polite',
#    'attentive',
#    'funny',
#    'brave',
#    'optimistic',
#    'talkative',
#    'ingenious',
#    'active',
#    'reserved',
#    'kind',
#    'modest',
#    'respectful',
#    'capable',
#    'hard-working',
#    'playful',
#    'loyal',
#    'thoughtful',
#    'patient',
#    'curious',
#    'obedient',
#    'passionate',
#    'sociable',
#    'reliable',
#    'educated',
#    'sincere',
#    'characteristic',
#    'wise',
#    'self-confident',
#    'faithful',
#    'honest',
#    'hospitable',
#    'creative',
#    'serious',
#    'positive',
#    'benevolent',
#    'adventurous',
#    'responsible',
#    'dedicated',
#    'careful',
#    'intelligent',
#    'smart',
#    'cheerful',
#    'generous',
#    'lively'],
#   'estados_emocionais': ['irritated',
#    'upset',
#    'concerned',
#    'eager',
#    'determined',
#    'satisfied',
#    'annoyed',
#    'shocked',
#    'jealous',
#    'excited',
#    'thankful',
#    'hopeless',
#    'proud',
#    'scared',
#    'hopeful',
#    'happy',
#    'motivated',
#    'joyful',
#    'impressed',
#    'angry',
#    'sure',
#    'worried',
#    'disappointed',
#    'dissatisfied',
#    'emotional',
#    'lost',
#    'calm',
#    'depressed',
#    'trigu',
#    'furious',
#    'relaxed',
#    'obsessed',
#    'pleased',
#    'lonely',
#    'unhappy',
#    'nervous',
#    'sad',
#    'interested',
#    'afraid',
#    'enthusiastic',
#    'confused',
#    'surprised',
#    'bored',
#    'miserable',
#    'fearful',
#    'desperate',
#    'doubtful']},
#  'cidade': {'regiões': ['principality',
#    'village',
#    'hometown',
#    'country',
#    'province',
#    'countryside',
#    'metropolis',
#    'republic',
#    'city',
#    'urban',
#    'suburb',
#    'colony',
#    'empire',
#    'kingdom',
#    'district',
#    'town',
#    'rural']},
#  'advérbios': {'advérbios_de_grau': ['equally',
#    'also',
#    'sufficiently',
#    'extremely',
#    'less',
#    'very',
#    'quite',
#    'more',
#    'pretty',
#    'as',
#    'slightly',
#    'excessively',
#    'too',
#    'completely',
#    'least',
#    'enough',
#    'insufficiently',
#    'almost',
#    'supremely',
#    'rather',
#    'hardly',
#    'relatively',
#    'most'],
#   'advérbios_de_modo_3': ['proudly',
#    'exclusively',
#    'politically',
#    'kindly',
#    'fairly',
#    'calmly',
#    'anonymously',
#    'visibly',
#    'conveniently',
#    'individually',
#    'efficiently',
#    'preferably',
#    'totally',
#    'attentively',
#    'potentially',
#    'cruelly',
#    'legally',
#    'successfully',
#    'frankly',
#    'effectively',
#    'naturally',
#    'hastily',
#    'essentially',
#    'surprisingly',
#    'strongly',
#    'typically',
#    'wisely',
#    'consciously',
#    'excellently',
#    'strategically',
#    'illegally',
#    'enthusiastically',
#    'mutually',
#    'sincerely',
#    'boldly'],
#   'palavras_interrogativas_e_ligação': ['perhaps',
#    'however',
#    'especially',
#    'how',
#    'moreover',
#    'vice_versa',
#    'anyhow',
#    'unless',
#    'when',
#    'otherwise',
#    'what',
#    'why',
#    'although',
#    'even',
#    'nevertheless',
#    'besides',
#    'where',
#    'therefore'],
#   'advérbios_de_modo_2': ['truthfully',
#    'considerably',
#    'officially',
#    'accurately',
#    'similarly',
#    'physically',
#    'scientifically',
#    'falsely',
#    'intentionally',
#    'mechanically',
#    'publicly',
#    'aloud',
#    'silently',
#    'differently',
#    'lazily',
#    'honestly',
#    'partially',
#    'mentally',
#    'independently',
#    'traditionally',
#    'simply',
#    'happily',
#    'financially',
#    'automatically',
#    'clearly',
#    'historically',
#    'voluntarily',
#    'impatiently',
#    'beautifully',
#    'firmly',
#    'patiently'],
#   'de_lugar': ['backward',
#    'there',
#    'nearby',
#    'left',
#    'forward',
#    'far',
#    'someplace',
#    'elsewhere',
#    'home',
#    'everyplace',
#    'here',
#    'right',
#    'closely'],
#   'de_tempo_e_frequência': ['forever',
#    'sometimes',
#    'yesterday',
#    'daily',
#    'after',
#    'always',
#    'now',
#    'today',
#    'tomorrow',
#    'once',
#    'nowadays',
#    'then',
#    'regularly',
#    'recently',
#    'just',
#    'again',
#    'annually',
#    'meanwhile',
#    'weekly',
#    'never',
#    'soon',
#    'tonight',
#    'before',
#    'later',
#    'occasionally',
#    'still',
#    'overnight',
#    'twice',
#    'already',
#    'often',
#    'since',
#    'rarely',
#    'usually',
#    'ever',
#    'monthly',
#    'thrice'],
#   'advérbios_de_modo_1': ['well',
#    'clockwise',
#    'unfortunately',
#    'directly',
#    'really',
#    'apart',
#    'together',
#    'badly',
#    'perfectly',
#    'nervously',
#    'easily',
#    'generally',
#    'carefully',
#    'quickly',
#    'fortunately',
#    'necessarily',
#    'somehow',
#    'artificially',
#    'mainly',
#    'instead',
#    'nearly',
#    'gracefully',
#    'manually',
#    'finally',
#    'vertically',
#    'seriously',
#    'horizontally',
#    'secretly',
#    'exceptionally',
#    'slowly',
#    'suddenly']},
#  'esportes': {'sobre_esportes': ['stadium',
#    'to_compete',
#    'mascot',
#    'winner',
#    'fan',
#    'finish',
#    'olympic',
#    'tournament',
#    'to_race',
#    'final',
#    'emblem',
#    'league',
#    'loser',
#    'scoreboard',
#    'champion',
#    'to_award',
#    'trophy',
#    'victory',
#    'team',
#    'turn',
#    'referee',
#    'cheerleader',
#    'medal',
#    'finish_line',
#    'race',
#    'start',
#    'to_pass',
#    'to_ride',
#    'timeout',
#    'coach',
#    'to_practice',
#    'to_catch',
#    'olympics',
#    'prize',
#    'sports',
#    'to_score',
#    'semifinal',
#    'practice',
#    'championship',
#    'overtime',
#    'contestant',
#    'npeti',
#    'tie',
#    'to_penalise',
#    'quarter-final'],
#   'ginásio': ['jogging',
#    'fitness',
#    'workout',
#    'aerobics',
#    'running',
#    'to_train',
#    'to_cycle',
#    'to_box',
#    'gym',
#    'to_pull_up',
#    'pilates',
#    'sit-up',
#    'push-up',
#    'to_exercise',
#    'to_squat',
#    'swimming',
#    'to_flex',
#    'weight_training',
#    'jump',
#    'exercise',
#    'lunge'],
#   'esportes_de_verão': ['basketball',
#    'bodybuilding',
#    'kickboxing',
#    'golf',
#    'archery',
#    'water_polo',
#    'boxing',
#    'motocross',
#    'fencing',
#    'gymnastics',
#    'sprint',
#    'windsurfing',
#    'artistic_swimming',
#    'cricket',
#    'cycling',
#    'waterskiing',
#    'scuba_diving',
#    'tennis',
#    'soccer',
#    'track_and_field',
#    'rafting',
#    'badminton',
#    'marathon',
#    'lacrosse',
#    'rally',
#    'billiards',
#    'squash',
#    'rock_climbing',
#    'table_tennis',
#    'horseback_riding',
#    'handball',
#    'netball',
#    'softball',
#    'volleyball',
#    'snooker',
#    'triathlon',
#    'baseball',
#    'wrestling',
#    'rugby'],
#   'esportes_de_inverno': ['alpine_skiing',
#    'hockey',
#    'nountaineerin',
#    'luge',
#    'speed_skating',
#    'skiing',
#    'skating',
#    'slalom',
#    'biathlon',
#    'bobsleigh',
#    'figure_skating',
#    'curling',
#    'ice_climbing',
#    'oss-couni_skiing',
#    'ski_jumping',
#    'snowboarding'],
#   'esportistas': ['rider',
#    'runner',
#    'golfer',
#    'cyclist',
#    'hockey_player',
#    'basketball_player',
#    'skier',
#    'tennis_player',
#    'sportsman',
#    'player',
#    'boxer',
#    'swimmer',
#    'football_player',
#    'jockey',
#    'athlete',
#    'volleyballer'],
#   'equipamento_esportivo': ['racket',
#    'birdie',
#    'roller_skates',
#    'parachute',
#    'skis',
#    'whistle',
#    'boxing_gloves',
#    'skateboard',
#    'dumb-bell',
#    'punching_bag',
#    'surfboard',
#    'oar',
#    'equipment',
#    'cue',
#    'snowboard',
#    'hot-air_balloon',
#    'jump_rope',
#    'chronometer',
#    'ball',
#    'gumshield',
#    'helmet']},
#  'transportes': {'transportes_aquaticos': ['dock',
#    'to_sail',
#    'aboard',
#    'shipyard',
#    'lifeboat',
#    'hold',
#    'to_disembark',
#    'seaman',
#    'to_embark',
#    'to_sink',
#    'steamship',
#    'tanker',
#    'freighter',
#    'cruiser',
#    'lighthouse',
#    'yacht',
#    'sailboat',
#    'kayak',
#    'nautical',
#    'boat',
#    'motorboat',
#    'sail',
#    'catamaran',
#    'ferry',
#    'battleship',
#    'flagship',
#    'hovercraft',
#    'to_float',
#    'canoe',
#    'gunboat',
#    'pier',
#    'deck',
#    'schooner',
#    'cargo',
#    'anchor',
#    'cruise_liner',
#    'rowboat',
#    'icebreaker',
#    'trimaran',
#    'barge',
#    'port',
#    'submarine',
#    'ship',
#    'gondola'],
#   'peças_de_carro': ['sunroof',
#    'vehicle_audio',
#    'starter',
#    'back_seat',
#    'odometer',
#    'hazard_lights',
#    'wheel',
#    'gearshift',
#    'lights_switch',
#    'speedometer',
#    'bumper',
#    'spare_tire',
#    'seat_belt',
#    "driver's_seat",
#    'pedal',
#    'dashboard',
#    'steering_wheel',
#    'airbag',
#    'tire',
#    'motor',
#    'gas',
#    'flat_tire',
#    'headrest',
#    'brake',
#    'gear',
#    'child_seat',
#    'gearbox',
#    'hubcap',
#    'to_honk',
#    'hood'],
#   'transportes_aéreos': ['economy_class',
#    'passport_control',
#    'to_check_in',
#    'propeller',
#    'airport',
#    'airliner',
#    'to_take_off',
#    'to_board',
#    'to_land',
#    'seaplane',
#    'departure',
#    'ticket_office',
#    'boarding_pass',
#    'baggage_claim',
#    'wing',
#    'aircraft',
#    'fuselage',
#    'waiting_room',
#    'joystick',
#    'arrival',
#    'carry-on_baggage',
#    'plane',
#    'private_jet',
#    'radar',
#    'fighter_plane',
#    'helicopter',
#    'crew',
#    'flight',
#    'layover',
#    'business_class',
#    'cockpit',
#    'airline',
#    'co-pilot',
#    'landing',
#    'to_fly'],
#   'estradas': ['artery',
#    'traffic_circle',
#    'traffic',
#    'parking_meter',
#    'intersection',
#    'one-way',
#    'pass',
#    'bus_station',
#    'stoplights',
#    'viaduct',
#    'crosswalk',
#    'subway',
#    'traffic_sign',
#    'road',
#    'roadwork',
#    'ditch',
#    'station',
#    'lane',
#    'bypass',
#    'expressway',
#    'traffic_jam'],
#   'transportes_rodoviários': ['transportation',
#    'automobile',
#    'sport_car',
#    'fare',
#    'passenger',
#    'station_wagon',
#    'trailer',
#    'limousine',
#    'gas_station',
#    'van',
#    'to_transport',
#    'sedan',
#    'to_drive',
#    'vehicle',
#    'moped',
#    'motor_scooter',
#    'convertible',
#    'truck',
#    'trackless_trolley',
#    'garage',
#    'minivan',
#    'bicycle',
#    'bus',
#    'double-decker',
#    'to_stop',
#    'crossover',
#    'minibus',
#    'cab',
#    'hatchback',
#    'to_accelerate',
#    'car_wash',
#    'bulldozer',
#    'car',
#    'to_brake',
#    'motorcycle',
#    'carriage']},
#  'cidades': {'ruas': ['passageway',
#    'boulevard',
#    'street_light',
#    'avenue',
#    'curb',
#    'area',
#    'place',
#    'parking',
#    'street',
#    'to_park',
#    'sidewalk',
#    'location',
#    'pedestrian_zone',
#    'way',
#    'shortcut',
#    'alley',
#    'downtown'],
#   'restaurante_e_bar': ['snack_bar',
#    'reserved',
#    'nightclub',
#    'to_serve',
#    'tray',
#    'smoking_room',
#    'wine_list',
#    'steakhouse',
#    'to_order',
#    'pizza_parlor',
#    'menu',
#    'bar_counter',
#    'café',
#    'restaurant',
#    'tavern',
#    'bar',
#    'reservation',
#    'check',
#    'buffet'],
#   'edifícios': ['tunnel',
#    'dungeon',
#    'gargoyle',
#    'woodworking',
#    'dome',
#    'lumber',
#    'pedestal',
#    'concrete',
#    'bricklayer',
#    'barrier',
#    'to_renovate',
#    'architecture',
#    'aqueduct',
#    'brick',
#    'downspout',
#    'escalator',
#    'to_build',
#    'blueprint',
#    'to_collapse',
#    'hard_hat',
#    'spire',
#    'arcade',
#    'to_rebuild',
#    'skyscraper',
#    'to_found',
#    'tube',
#    'column',
#    'wood',
#    'cement',
#    'labyrinth',
#    'to_demolish',
#    'beam',
#    'foreman',
#    'block',
#    'dam',
#    'building',
#    'pylon',
#    'cornice',
#    'debris',
#    'venetian_blind',
#    'repair',
#    'tile',
#    'overhaul',
#    'reconstruction',
#    'construction',
#    'construction_site'],
#   'hotel': ['motel',
#    'twin_room',
#    'reception',
#    'room_number',
#    'guesthouse',
#    'accommodations',
#    'resort',
#    'bed_and_breakfast',
#    'double_room',
#    'visitor',
#    'registration',
#    'maid_service',
#    'hotel',
#    'room_key',
#    'room_service',
#    'hostel',
#    'all-inclusive',
#    'reservation',
#    'guest',
#    'single_room',
#    'foyer'],
#   'atrações_turisticas': ['arch',
#    'national_park',
#    'remains',
#    'bridge',
#    'gallery',
#    'tower',
#    'iistoric_buildin',
#    'pyramid',
#    'fortress',
#    'park',
#    'museum',
#    'entrance_fee',
#    'touristic_attractions',
#    'exhibit',
#    'city_hall',
#    'circus',
#    'monument',
#    'statue',
#    'theme_park',
#    'ruins',
#    'fountain',
#    'safari_park',
#    'planetarium']},
#  'moda': {'acessórios': ['mittens',
#    'satchel',
#    'handkerchief',
#    'veil',
#    'headband',
#    'shawl',
#    'backpack',
#    'beret',
#    'suspenders',
#    'chain',
#    'billfold',
#    'hat',
#    'headscarf',
#    'bow_tie',
#    'purse',
#    'watch',
#    'scarf',
#    'necklace',
#    'duffel_bag',
#    'belt',
#    'accessories',
#    'saddlebag',
#    'sack',
#    'suitcase',
#    'hair_tie',
#    'beanie',
#    'shoulder_bag',
#    'cufflinks',
#    'gloves',
#    'pendant',
#    'umbrella',
#    'briefcase',
#    'bracelet',
#    'ring',
#    'earmuffs',
#    'sunglasses',
#    'tie',
#    'jewelry',
#    'earrings',
#    'bag'],
#   'alfaiataria': ['silk',
#    'hanger',
#    'flannel',
#    'to_iron',
#    'strap',
#    'to_widen',
#    'buttonhole',
#    'bow',
#    'thimble',
#    'pocket',
#    'lapel',
#    'textile',
#    'pin',
#    'ribbon',
#    'to_mend',
#    'leather',
#    'zipper',
#    'to_fold',
#    'to_shorten',
#    'safety_pin',
#    'stitch',
#    'seam',
#    'thread',
#    'button',
#    'nylon',
#    'to_lengthen',
#    'cotton',
#    'cashmere',
#    'design',
#    'tape_measure',
#    'linen',
#    'fabric',
#    'sleeve',
#    'hem',
#    'needle',
#    'velvet',
#    'to_knit',
#    'pincushion',
#    'to_sew',
#    'collar',
#    "tailor's",
#    'to_alter',
#    'hood'],
#   'roupas': ['bra',
#    'underpants',
#    'sweater',
#    'sweatshirt',
#    'suit',
#    'bathrobe',
#    'blazer',
#    'jeans',
#    'overalls',
#    'shirt',
#    't-shirt',
#    'stockings',
#    'nightdress',
#    'dress',
#    'to_dress',
#    'tracksuit',
#    'uniform',
#    'clothes',
#    'shorts',
#    'coat',
#    'skirt',
#    'clothing',
#    'pants',
#    'elegant',
#    'pantyhose',
#    'miniskirt',
#    'socks',
#    'blouse',
#    'cape',
#    'style',
#    'pajamas',
#    'to_undress',
#    'to_wear',
#    'underwear',
#    'cardigan_sweater',
#    'fashion',
#    'loose',
#    'jacket',
#    'slip',
#    'turtleneck',
#    'panties',
#    'tunic',
#    'costume',
#    'corset'],
#   'salão_de_beleza': ['ponytail',
#    'nail_file',
#    'wig',
#    'hairdryer',
#    'nail_scissors',
#    'bun',
#    'pedicure',
#    'to_braid',
#    'curl',
#    'bangs',
#    'part',
#    'braids',
#    'hairstyle',
#    'braid',
#    'bob',
#    'to_straighten',
#    'afro',
#    'pigtails',
#    'manicure',
#    'to_comb',
#    'look',
#    'perm',
#    'hairbrush',
#    'comb',
#    'beauty_shop',
#    'to_brush',
#    'nail_clippers',
#    'to_curl',
#    'esthetic'],
#   'calçado': ['high_heels',
#    'slippers',
#    'platform_shoes',
#    'shoes',
#    'sandals',
#    'sneakers',
#    'thongs',
#    'footwear',
#    'espadrilles',
#    'snowshoes',
#    'boots',
#    'clogs',
#    'shoestrings',
#    'rubber_boots',
#    'moccasins',
#    'barefoot',
#    'heel',
#    'sole']},
#  'nomes': {'pessoas': ['caveman',
#    'community',
#    'crowd',
#    'compatriot',
#    'diva',
#    'idol',
#    'countryman',
#    'minor',
#    'member',
#    'society',
#    'resident',
#    'outsider',
#    'celebrity',
#    'fool',
#    'rival',
#    'genius',
#    'dreamer',
#    'people',
#    'refugee',
#    'coward',
#    'orphan',
#    'group',
#    'foreigner',
#    'millionaire',
#    'locals',
#    'superstar',
#    'liar',
#    'patriot',
#    'opponent',
#    'tribe',
#    'humanity',
#    'immigrant',
#    'intellectual',
#    'gypsy',
#    'guru',
#    'knight',
#    'public',
#    'pedant',
#    'ilizat',
#    'taxpayer',
#    'nation',
#    'vegetarian',
#    'citizen',
#    'minority',
#    'billionaire',
#    'favorite'],
#   'consciência': ['disobedience',
#    'conclusion',
#    'choice',
#    'soul',
#    'mind',
#    'effort',
#    'attention',
#    'shock',
#    'decision',
#    'logic',
#    'memory',
#    'depression',
#    'obedience',
#    'fantasy',
#    'manner',
#    'sociology',
#    'belief',
#    'analysis',
#    'philosophy',
#    'idea',
#    'desire',
#    'behavior',
#    'psychology',
#    'attitude'],
#   'substantivos_abstratos_2': ['hurry',
#    'importance',
#    'contribution',
#    'interest',
#    'objective',
#    'standard',
#    'creation',
#    'use',
#    'union',
#    'priority',
#    'variant',
#    'principle',
#    'reality',
#    'routine',
#    'achievement',
#    'destruction',
#    'competence',
#    'demonstration',
#    'tendency',
#    'trouble',
#    'method',
#    'structure',
#    'combination',
#    'risk',
#    'discipline',
#    'comfort',
#    'ban',
#    'comparison',
#    'ideal'],
#   'comunicação': ['speech',
#    'compromise',
#    'conflict',
#    'gossip',
#    'warning',
#    'guess',
#    'insult',
#    'scream',
#    'scandal',
#    'remark',
#    'whisper',
#    'debate',
#    'permission',
#    'gesture',
#    'shout',
#    'observation',
#    'piece_of_advice',
#    'communication',
#    'laughter',
#    'promise',
#    'apology',
#    'suggestion',
#    'argument',
#    'quarrel',
#    'greeting',
#    'rumor',
#    'conversation',
#    'discussion',
#    'joke',
#    'favor'],
#   'substantivos_concretos_1': ['kiss',
#    'flagpole',
#    'side',
#    'silence',
#    'warmth',
#    'bubbles',
#    'list',
#    'smoke',
#    'noise',
#    'layer',
#    'beginning',
#    'fire',
#    'flag',
#    'hole',
#    'embers',
#    'ash',
#    'ending',
#    'level',
#    'middle',
#    'treasure',
#    'light',
#    'stain',
#    'rubber',
#    'tar',
#    'darkness',
#    'foam',
#    'dirt',
#    'spark',
#    'hug',
#    'dust',
#    'object',
#    'shadow',
#    'echo',
#    'sunlight',
#    'bottom'],
#   'substantivos_abstratos_1': ['process',
#    'need',
#    'protest',
#    'independence',
#    'problem',
#    'effect',
#    'dream',
#    'politics',
#    'election',
#    'result',
#    'parliament',
#    'advantage',
#    'disadvantage',
#    'embassy',
#    'ministry',
#    'necessity',
#    'aim',
#    'situation',
#    'example',
#    'destiny',
#    'progress',
#    'chance',
#    'constitution',
#    'skill',
#    'increase',
#    'decrease',
#    'change',
#    'secret',
#    'imagination',
#    'reason',
#    'pause',
#    'success',
#    'answer',
#    'beauty',
#    'glory',
#    'fame',
#    'alliance',
#    'revolution',
#    'solution',
#    'difference',
#    'sleep']},
#  'educação': {'linguística': ['definition',
#    'word',
#    'pronunciation',
#    'intonation',
#    'syllable',
#    'lowercase',
#    'alphabet',
#    'hieroglyph',
#    'language',
#    'vocabulary',
#    'phonetics',
#    'spelling',
#    'linguistics',
#    'question',
#    'grammar',
#    'accent',
#    'sentence',
#    'tone',
#    'consonant',
#    'letter',
#    'uppercase',
#    'synonym',
#    'term',
#    'antonym',
#    'stylistics',
#    'vowel',
#    'dialect',
#    'plural',
#    'translation',
#    'singular',
#    'phrase'],
#   'escola': ['test',
#    'canteen',
#    'homework',
#    'to_check',
# ...
#    'pie',
#    'cuisine',
#    'risotto',
#    'kebab',
#    'jello',
#    'salad',
#    'gingerbread',
#    'waffle',
#    'cheeseburger',
#    'mashed_potatoes',
#    'fried_egg',
#    'spaghetti',
#    'hot_dog',
#    'cake',
#    'broth',
#    'lasagna',
#    'syrup',
#    'pancakes',
#    'french_fries',
#    'pickles',
#    'crêpe',
#    'pizza',
#    'wedding_cake',
#    'hamburger',
#    'popcorn',
#    'muesli',
#    'sush',
#    'pasta',
#    'shawarma',
#    'mousse',
#    'chips',
#    'cheesecake',
#    'meatball'],
#   'grãos_nozes_e_sementes': ['anise',
#    'barley',
#    'filbert',
#    'cocoa_beans',
#    'coffee_beans',
#    'nut',
#    'almond',
#    'poppy_seeds',
#    'cumin',
#    'cob',
#    'oats',
#    'sunflower_seeds',
#    'pistachio',
#    'pod',
#    'sesame',
#    'flaxseed',
#    'rice',
#    'grains',
#    'flour',
#    'beans',
#    'seed',
#    'corn',
#    'peanut',
#    'soybean',
#    'coconut',
#    'walnut',
#    'wheat'],
#   'vegetais': ['truffle',
#    'olive',
#    'marrow',
#    'vegetable',
#    'cauliflower',
#    'champignon',
#    'potato',
#    'cherry_tomato',
#    'rutabaga',
#    'lettuce',
#    'string_beans',
#    'asparagus',
#    'cabbage',
#    'celery',
#    'leek',
#    'onion',
#    'bell_pepper',
#    'radish',
#    'turnip',
#    'brussels_sprout',
#    'fennel',
#    'eggplant',
#    'yam',
#    'chili_pepper',
#    'broccoli',
#    'zucchini',
#    'mushroom',
#    'beet',
#    'cucumber',
#    'garlic',
#    'carrot',
#    'artichoke',
#    'pumpkin',
#    'tomato',
#    'spinach',
#    'shallot',
#    'pea',
#    'chanterelle'],
#   'refeições': ['to_treat',
#    'fasting',
#    'diet',
#    'main_course',
#    'to_nibble',
#    'breakfast',
#    'food',
#    'meal',
#    'aperitif',
#    'brunch',
#    'to_fast',
#    'takeout',
#    'dinner',
#    'feast',
#    'lunch',
#    'snack',
#    'fast_food',
#    'dessert',
#    'side_dish',
#    'appetizer',
#    'picnic',
#    'barbecue'],
#   'bebidas_não_alcoólicas': ['ice-cold',
#    'unpotable',
#    'herbal_tea',
#    'mineral_water',
#    'smoothie',
#    'water',
#    'green_tea',
#    'hot_chocolate',
#    'to_quench',
#    'ice',
#    'espresso',
#    'potable',
#    'coffee',
#    'cocoa',
#    'cappuccino',
#    'mocha',
#    'juice',
#    'soda',
#    'still_water',
#    'tea',
#    'iced_coffee',
#    'lemonade',
#    'non-alcoholic',
#    'drink',
#    'teabag',
#    'latte'],
#   'condimentos': ['parsley',
#    'herbs',
#    'cilantro',
#    'wasabi',
#    'bay',
#    'mayonnaise',
#    'condiments',
#    'vanilla',
#    'y_sal',
#    'thyme',
#    'cinnamon',
#    'pesto',
#    'mint',
#    'olive_oil',
#    'mustard',
#    'vinegar',
#    'balsamic_vinegar',
#    'gravy',
#    'ginger',
#    'fenugreek',
#    'spices',
#    'oil',
#    'ketchup',
#    'dill',
#    'black_pepper',
#    'oregano',
#    'chili',
#    'peppermint',
#    'to_season',
#    'palm_oil',
#    'sauce',
#    'basil',
#    'paprika',
#    'salt',
#    'maple_syrup',
#    'caraway',
#    'sugar'],
#   'descrição_da_comida': ['sweet',
#    'greasy',
#    'delicious',
#    'healthful',
#    'baked',
#    'tough',
#    'cooked',
#    'salty',
#    'carbohydrate',
#    'bitter',
#    'glucose',
#    'stale',
#    'dry',
#    'aftertaste',
#    'cookery',
#    'fatty',
#    'fried',
#    'disgusting',
#    'aromatic',
#    'caffeine',
#    'sour',
#    'smoked',
#    'tasteless',
#    'gourmet',
#    'smell',
#    'appetite',
#    'poisonous',
#    'raw',
#    'fresh',
#    'tender',
#    'spicy',
#    'rotten',
#    'juicy',
#    'fat-free',
#    'delicacy'],
#   'frutas': ['orange',
#    'citron',
#    'lemon',
#    'fruit',
#    'peach',
#    'fig',
#    'exotic',
#    'grape',
#    'papaya',
#    'citrus',
#    'tropical_fruit',
#    'raspberry',
#    'berry',
#    'plum',
#    'passion_fruit',
#    'mango',
#    'lime',
#    'banana',
#    'date',
#    'watermelon',
#    'apricot',
#    'strawberry',
#    'raisin',
#    'avocado',
#    'durian',
#    'wi_fri',
#    'mandarin',
#    'unripe',
#    'pomegranate',
#    'prune',
#    'cherry',
#    'grapefruit',
#    'guava',
#    'blackberry',
#    'pear',
#    'apple',
#    'persimmon',
#    'feijo',
#    'pineapple',
#    'cantaloupe',
#    'ripe',
#    'cranberry',
#    'melon',
#    'blueberry']},
#  'outras_partes_do_discurso': {'expressão_de_quantidades': ['all',
#    'quarter',
#    'piece',
#    'pair',
#    'few',
#    'each',
#    'these',
#    'sip',
#    'portion',
#    'those',
#    'slice',
#    'many',
#    'set',
#    'crumbs',
#    'half',
#    'both',
#    'drop',
#    'this',
#    'neither',
#    'no',
#    'either',
#    'that'],
#   'preposições': ['under',
#    'from',
#    'inside',
#    'until',
#    'than',
#    'down',
#    'above',
#    'outside',
#    'at',
#    'near',
#    'after',
#    'across',
#    'along',
#    'on',
#    'up',
#    'in_front_of',
#    'for',
#    'about',
#    'during',
#    'without',
#    'like',
#    'through',
#    'with',
#    'amid',
#    'of',
#    'around',
#    'between',
#    'below',
#    'before',
#    'to',
#    'among',
#    'toward',
#    'behind',
#    'in'],
#   'pontuação': ['punctuation',
#    'ellipsis',
#    'apostrophe',
#    'colon',
#    'exclamation_point',
#    'ampersand',
#    'dot',
#    'semicolon',
#    'hyphen',
#    'asterisk',
#    'comma',
#    'question_mark',
#    'dash',
#    'parentheses'],
#   'conjunções': ['or', 'once', 'but', 'because', 'so_that', 'while'],
#   'pronomes': ['they',
#    'he',
#    'ourselves',
#    'such',
#    'her',
#    'me',
#    'certain',
#    'same',
#    'mine',
#    'something',
#    'its',
#    'his',
#    'who',
#    'us',
#    'ours',
#    'which',
#    'it',
#    'everybody',
#    'everything',
#    'myself',
#    'them',
#    'somebody',
#    'she',
#    'themselves',
#    'yours',
#    'itself',
#    'nothing',
#    'him',
#    'you',
#    'yourself',
#    'nobody',
#    'another',
#    'hers',
#    'herself',
#    'whom',
#    'whoever',
#    'yourselves',
#    'himself',
#    'theirs']},
#  'cultura': {'instrumentos_musicais': ['gong',
#    'bell',
#    'organ',
#    'harmonica',
#    'bugle',
#    'to_tune',
#    'clarinet',
#    'bow',
#    'piano',
#    'cymbal',
#    'musical_instrument',
#    'drum_kit',
#    'bongos',
#    'french_horn',
#    'mouthpiece',
#    'trumpet',
#    'electric_guitar',
#    'harp',
#    'flute',
#    'piccolo',
#    'glockenspiel',
#    'saxophone',
#    'cello',
#    'tambourine',
#    'bass_clarinet',
#    'violin',
#    'viola',
#    'maracas',
#    'oboe',
#    'kettledrum',
#    'accordion',
#    'trombone',
#    'drum',
#    'guitar',
#    'lyre',
#    'string_instrument',
#    'xylophone',
#    'bassoon',
#    'drumsticks'],
#   'fotografia': ['colorful',
#    'to_pose',
#    'film',
#    'photographer',
#    'studio',
#    'photogenic',
#    'watermark',
#    'resolution',
#    'photograph',
#    'to_photograph',
#    'negative',
#    'black-and-white',
#    'photography',
#    'tripod',
#    'case',
#    'flash',
#    'red-eye',
#    'photo_album',
#    'photo_frame',
#    'selfie',
#    'viewfinder',
#    'pixel',
#    'darkroom'],
#   'mitos_e_lendas': ['mystery',
#    'giant',
#    'elf',
#    'unicorn',
#    'centaur',
#    'mermaid',
#    'mirage',
#    'phoenix',
#    'legend',
#    'zombie',
#    'alien',
#    'mythology',
#    'monster',
#    'dwarf',
#    'werewolf',
#    'dragon',
#    'myth',
#    'hobbit',
#    'minotaur',
#    'cyclops',
#    'vampire',
#    'genie',
#    'goblin',
#    'fairy',
#    'ogre',
#    'troll'],
#   'sobrenatural': ['spell',
#    'occultism',
#    'witch',
#    'alchemy',
#    'magic',
#    'astrology',
#    'immortal',
#    'pentagram',
#    'mystical',
#    'curse',
#    'ghost',
#    'miracle',
#    'talisman',
#    'angel',
#    'superstition',
#    'zodiac',
#    'potion',
#    'supernatural',
#    'demon',
#    'horoscope',
#    'wizard',
#    'prophecy',
#    'immortality'],
#   'livros': ['villain',
#    'index',
#    'intrigue',
#    'dialog',
#    'context',
#    'supplement',
#    'appendix',
#    'saying',
#    'character',
#    'topic',
#    'proverb',
#    'motif',
#    'monolog',
#    'to_narrate',
#    'page',
#    'to_summarize',
#    'hero',
#    'cover',
#    'title',
#    'bibliography',
#    'book',
#    'paragraph',
#    'preface',
#    'description',
#    'chapter',
#    'introduction',
#    'to_quote',
#    'plot',
#    'quotation',
#    'contents',
#    'edition'],
#   'literatura': ['narrator',
#    'autobiography',
#    'ballad',
#    'culture',
#    'story',
#    'author',
#    'verse',
#    'reader',
#    'poem',
#    'non-fiction',
#    'epic_poem',
#    'literary_genre',
#    'fiction',
#    'prose',
#    'novel',
#    'literature',
#    'saga',
#    'composition',
#    'epistolary_novel',
#    'dramaturgy',
#    'poetry',
#    'biography',
#    'manuscript',
#    'fairy_tale',
#    'text',
#    'tragedy',
#    'memoir',
#    'draft',
#    'tale',
#    'stanza',
#    'reading'],
#   'música': ['heavy_metal',
#    'playlist',
#    'rhythm',
#    'classical_music',
#    'folk_music',
#    'music',
#    'melody',
#    'chorus',
#    'band',
#    'ethnomusic',
#    'timbre',
#    'choir',
#    'rap',
#    'virtuoso',
#    'jazz',
#    'trance',
#    'operetta',
#    'voice',
#    'acoustic',
#    'solo',
#    'reggae',
#    'quartet',
#    'note',
#    'singing',
#    'song',
#    'accompaniment',
#    'chord',
#    'orchestra',
#    'lullaby',
#    'to_sing',
#    'composer',
#    'lyrics',
#    'karaoke',
#    'pop',
#    'techno',
#    'opera',
#    'ensemble',
#    'discography',
#    'sheet_music',
#    'octave',
#    'duet',
#    'musical',
#    'sound',
#    'volume',
#    'songwriter',
#    'blues'],
#   'artes_plásticas': ['acrylic_paint',
#    'arabesque',
#    'stencil',
#    'mural',
#    'sketch',
#    'mosaic',
#    'contrast',
#    'bust',
#    'to_color',
#    'to_draw',
#    'paint',
#    'perspective',
#    'engraving',
#    'self-portrait',
#    'sculpture',
#    'origami',
#    'technique',
#    'oil_paint',
#    'palette',
#    'easel',
#    'paintbrush',
#    'talent',
#    'silhouette',
#    'outline',
#    'canvas',
#    'picture',
#    'masterpiece',
#    'artwork',
#    'stripe',
#    'collage',
#    'portrait',
#    'fresco',
#    'art',
#    'graffiti',
#    'background']},
#  'tempo_de_lazer': {'passatempos': ['activity',
#    'calligraphy',
#    'hobby',
#    'meditation',
#    'spa',
#    'entertainment',
#    'leisure_time',
#    'craft',
#    'beginner',
#    'bowling',
#    'bungee_jumping',
#    'rest',
#    'yoga',
#    'amateur',
#    'skydiving',
#    'lottery',
#    'carving',
#    'knitting',
#    'patchwork',
#    'weaving',
#    'surfing',
#    'collection',
#    'to_entertain',
#    'recreation',
#    'pottery',
#    'fun',
#    'stamp_collecting',
#    'roller_skating',
#    'professional'],
#   'parque_de_diversões': ['roller_coaster',
#    'teeter-totter',
#    'snowman',
#    'merry-go-round',
#    'wading_pool',
#    'jungle_gym',
#    'swing',
#    'sandbox',
#    'slide',
#    'playground'],
#   'cinama': ['filmmaker',
#    'cast',
#    'melodrama',
#    'director',
#    'direction',
#    'comedy',
#    'superhero',
#    'science_fiction_film',
#    'screen',
#    'western',
#    'documentary',
#    'footage',
#    'production',
#    'cutting',
#    'movie_theater',
#    'horror_film',
#    'movie',
#    'thriller',
#    'cartoon',
#    'anime',
#    'blockbuster'],
#   'jogos': ['backgammon',
#    'peekaboo',
#    'king',
#    'foosball',
#    'to_play',
#    'rook',
#    'puzzle',
#    'crossword',
#    'tic-tac-toe',
#    'bullseye',
#    'bishop',
#    'dominoes',
#    'queen',
#    'chess',
#    'game',
#    'dartboard',
#    'knight',
#    'roulette',
#    'bingo',
#    'pawn',
#    'leapfrog',
#    'hopscotch',
#    'board_game',
#    'video_game',
#    'darts',
#    'checkers'],
#   'viagens': ['adventure',
#    'traveler',
#    'baggage',
#    'holiday_brochure',
#    'voyage',
#    'itinerary',
#    'guided_tour',
#    'tourist_office',
#    'tourist',
#    'tourism',
#    'trip',
#    'route',
#    'to_travel',
#    'travel_agency',
#    'visit',
#    'visa',
#    'tour_bus',
#    'hike',
#    'excursion',
#    'tour',
#    'vacation',
#    'ecotourism',
#    'walk',
#    'expedition',
#    'cruise',
#    'car_rental'],
#   'teatro': ['repertoire',
#    'theater_program',
#    'role',
#    'audience',
#    'backdrop',
#    'dance',
#    'seat',
#    'to_applaud',
#    'premiere',
#    'auditorium',
#    'vestibule',
#    'to_perform',
#    'ticket',
#    'theater',
#    'arena',
#    'event',
#    'orchestra_pit',
#    'stage',
#    'to_rehearse',
#    'binoculars',
#    'performance',
#    'play',
#    'intermission',
#    'coatroom',
#    'applause',
#    'ballroom',
#    'show',
#    'spotlight',
#    'rehearsal',
#    'ballet',
#    'concert',
#    'row',
#    'mask'],
#   'campismo': ['sleeping_bag',
#    'insect_repellent',
#    'firestarter',
#    'tent_peg',
#    'outdoors',
#    'charcoal',
#    'camp',
#    'air_mattress',
#    'recreational_vehicle',
#    'flame',
#    'campfire',
#    '7rikin«',
#    'to_light_a_fire',
#    'to_pitch_a_tent',
#    'tent',
#    'camping'],
#   'na_praia': ['shade',
#    'life_vest',
#    'to_sunbathe',
#    'seaside',
#    'wave',
#    'beach',
#    'tide',
#    'sand',
#    'tan',
#    'sandy',
#    'rocky',
#    'sandcastle',
#    'to_dive',
#    'rubber_ring',
#    'buoy',
#    'sunshine',
#    'beach_umbrella'],
#   'pesca': ['waders',
#    'bait',
#    'to_fish',
#    'tackle_box',
#    'fishing_reel',
#    'fisherman',
#    'fishing_pole',
#    'creel',
#    'fishing',
#    'fishing_permit']},
#  'saude': {'problemas_de_saude': ['coma',
#    'contagious',
#    'blindness',
#    'stroke',
#    'hay_fever',
#    'cancer',
#    'ulcer',
#    'deafness',
#    'mumps',
#    'epidemic',
#    'disabled',
#    'albinism',
#    'bulimia',
#    'herpes',
#    'asthma',
#    'dehydration',
#    'alcoholism',
#    'hemorrhage',
#    'pneumonia',
#    'insanity',
#    'acne',
#    'schizophrenia',
#    'kidney_stone',
#    'medical_condition',
#    'germs',
#    'paranoia',
#    'poisoning',
#    'rthrit',
#    'heart_attack',
#    'cold',
#    'diabetes',
#    'measles',
#    'hernia',
#    'tuberculosis',
#    'psoriasis',
#    'rheumatism',
#    'infection',
#    'chickenpox',
#    'virus',
#    'jaundice',
#    'mutism',
#    'epilepsy',
#    'sunstroke',
#    'anemia',
#    'hangover',
#    'flu',
#    'hepatitis',
#    'rubella',
#    'disease',
#    'appendicitis',
#    'paralysis',
#    'insomnia',
#    'allergy',
#    'anorexia',
#    'autism'],
#   'especialistas': ['dermatologist',
#    'pediatrician',
#    'radiologist',
#    'specialist',
#    'psychiatrist',
#    'urologist',
#    'healer',
#    'toxicologist',
#    'dietitian',
#    'pathologist',
#    'physiotherapist',
#    'surgeon',
#    'physician',
#    'neurologist',
#    'midwife',
#    'obstetrician',
#    'anesthesiologist',
#    'chiropractor',
#    'neurosurgeon',
#    'oncologist',
#    'cardiologist',
#    'nephrologist',
#    'psychologist',
#    'ophthalmologist'],
#   'sintomas': ['dandruff',
#    'rash',
#    'hysteria',
#    'hallucination',
#    'migraine',
#    'syndrome',
#    'heartburn',
#    'aracl',
#    'colic',
#    'cough',
#    'diarrhea',
#    'headache',
#    'to_sneeze',
#    'dizziness',
#    'shiver',
#    'fever',
#    'stomach_ache',
#    'hiccup',
#    'sore_throat',
#    'nausea',
#    'spasm',
#    'nightmare',
#    'chronic',
#    'symptom',
#    'to_vomit',
#    'pain',
#    'perspiration',
#    'seizure',
#    'inflammation'],
#   'consultorio_dentista': ['molar',
#    'dental',
#    'canine',
#    'caries',
#    'tooth',
#    'dental_implant',
#    'cavity',
#    'gum',
#    'dentures',
#    'filling',
#    'enamel',
#    'incisor',
#    'toothache',
#    'root',
#    'premolar',
#    'dentist',
#    'braces'],
#   'otica': ['farsightedness',
#    'contact_lenses',
#    'eye_test',
#    'diopter',
#    'eyeglasses',
#    'lens',
#    'optometrist',
#    'nearsightedness'],
#   'farmacia': ['antibiotic',
#    'pipette',
#    'ointment',
#    'neck_brace',
#    'side_effect',
#    'pharmaceutical',
#    'pharmacy',
#    'odin',
#    'to_prescribe',
#    'capsule',
#    'sleeping_pill',
#    'pill',
#    'medicine',
#    'thermometer',
#    'expiry_date',
#    'insulin',
#    'antiseptic',
#    'dose',
#    'prescription',
#    'vitamin',
#    'painkiller',
#    'mixture',
#    'earplugs',
#    'tonometer',
#    'first_aid_box',
#    'inhaler'],
#   'lesões': ['bandage',
#    'wounded',
#    'splinter',
#    'sting',
#    'electric_shock',
#    'lesion',
#    'trauma',
#    'injury',
#    'blister',
#    'swelling',
#    'concussion',
#    'to_hurt',
#    'bruise',
#    'sprain',
#    'chafe',
#    'burn',
#    'hangnail',
#    'scratch',
#    'bite',
#    'fracture',
#    'bump',
#    'nosebleed'],
#   'tratamento': ['to_treat',
#    'clinic',
#    'blood_test',
#    'pacemaker',
#    'operating_room',
#    'health',
#    'surgery',
#    'prosthesis',
#    'jectic',
#    'syringe',
#    'check-up',
#    'hospital',
#    'to_heal',
#    'to_sterilize',
#    'to_infect',
#    'intensive_care_unit',
#    'aid',
#    'warc',
#    'emergency_room',
#    'to_hospitalize',
#    'diagnosis',
#    'psychotherapy',
#    'patient',
#    'to_recover',
#    'stethoscope',
#    'lancet',
#    'unhealthy',
#    'donor',
#    'to_inject',
#    'assistance',
#    'consultation',
#    'stretcher',
#    'maternity_ward',
#    'crutches',
#    'to_diagnose',
#    'wheelchair',
#    'catheter',
#    'to_contaminate',
#    'health_insurance',
#    'sick',
#    'procedure',
#    'plaster_cast',
#    'prophylaxis',
#    'prognosis',
#    'therapy',
#    'plastic_surgery',
#    'complaint',
#    'vaccine',
#    'to_disinfect',
#    'massage',
#    'remedy',
#    'medical_history',
#    'vaccination',
#    'treatment',
#    'recovery',
#    'painful',
#    'healthy',
#    'x-ray']}}

# %%
{"words": {
        "Casa": {
            "Partes": ["porta", "janela", "telhado"],
            "Cômodos": ["sala", "quarto", "cozinha"]
        },}

# %%
import tkinter as tk

class WordBaseApp(tk.Frame):
    def __init__(self, parent=None, **kwargs):
        super().__init__(parent, **kwargs)
        self.parent = parent

        self.data_path = "database/extract_data_video/data/extracted_data/{kind}/data_organize"
        self.current_type = "words"
        # self.data = {
        #     "words": {
        #         "Casa": {
        #             "Partes": ["porta", "janela", "telhado"],
        #             "Cômodos": ["sala", "quarto", "cozinha"]
        #         },
        #         "Trabalho": {
        #             "Profissões": ["engenheiro", "professor"]
        #         }
        #     },
        #     "phrases": {
        #         "Saudações": {
        #             "Informal": ["Oi!", "E aí?"],
        #             "Formal": ["Bom dia", "Como vai?"]
        #         }
        #     }
        # }

        self.data = self.create_estructure()

        self.build_ui()

    def create_estructure(self):
        estrutura = {}
        list_kinds = ["words", "phrases"]
        for kind in list_kinds:
            loader = DataLoader(base_path=DATA_PATH.format(kind=kind))
            estrutura[kind] = {}
            for categoria in loader.get_categories():
                estrutura[kind][categoria.name] = {}
                for subcat in loader.get_subcategories(categoria):
                    estrutura[kind][categoria.name][subcat.name] = []
                    for word_path in loader.get_word_paths(subcat):
                        estrutura[kind][categoria.name][subcat.name].append(word_path.name)
        return estrutura
    

    def build_ui(self):
        # Limpa tudo
        for widget in self.winfo_children():
            widget.destroy()

        # Topo: Botões de tipo
        top_frame = tk.Frame(self)
        top_frame.pack(pady=10)

        words_btn = tk.Button(top_frame, text="Palavras", command=lambda: self.switch_type("words"))
        words_btn.pack(side="left", padx=5)

        phrases_btn = tk.Button(top_frame, text="Frases", command=lambda: self.switch_type("phrases"))
        phrases_btn.pack(side="left", padx=5)

        # Área de conteúdo
        self.content_frame = tk.Frame(self)
        self.content_frame.pack(fill="both", expand=True, pady=10)

        self.draw_categories()

    def switch_type(self, type_name):
        self.current_type = type_name
        self.draw_categories()

    def draw_categories(self):
        for widget in self.content_frame.winfo_children():
            widget.destroy()

        categories = self.data.get(self.current_type, {})

        print(self.current_type)
        print("-----")
        print(categories.items())

        os.listdir(self.data_path.format(kind=self.current_type))
        loader = DataLoader(base_path=DATA_PATH.format(kind=kind))
        loader.get_categories(kind_return = "dict").keys()
        

        for category, subcats in categories.items():
            cat_frame = tk.Frame(self.content_frame)
            cat_frame.pack(fill="x", padx=10, pady=5)

            is_expanded = tk.BooleanVar(value=False)

            def toggle(sub_frame=subcats, var=is_expanded, master=cat_frame, cat_name=category):
                if var.get():
                    for widget in master.winfo_children()[1:]:
                        widget.destroy()
                    var.set(False)
                else:
                    for sub, items in sub_frame.items():
                        
                        sub_btn = tk.Button(
                            master,
                            text=f"   {sub}",
                            anchor="w",
                            command=lambda sub=sub, items=items: self.show_word_list(category=cat_name, subcategory=sub, words=items)
                        )
                        sub_btn.pack(fill="x")
                    var.set(True)

            btn = tk.Button(cat_frame, text=category, anchor="w", command=toggle)
            btn.pack(fill="x")

    def show_word_list(self, category, subcategory, words):
        # Limpa conteúdo

        print(f"sub:{category}, items:{subcategory}")
        
        for widget in self.winfo_children():
            widget.destroy()

        # Botão voltar
        back_btn = tk.Button(self, text="Voltar", command=self.build_ui)
        back_btn.pack(pady=10)


        # Título
        title = tk.Label(self, text=f"{self.current_type.title()} - {category} > {subcategory}", font=("Arial", 16))
        title.pack(pady=5)

        # Lista de palavras
        list_frame = tk.Frame(self)
        list_frame.pack(fill="both", expand=True, pady=10)

        for word in words:
            word_label = tk.Label(list_frame, text=word, anchor="w")
            word_label.pack(fill="x", padx=20, pady=2)



if __name__ == "__main__":
    root = tk.Tk()
    root.title("Base de Palavras e Frases")
    root.geometry("600x600")
    app = WordBaseApp(root)
    app.pack(fill="both", expand=True)  # <- Mostra o app na janela
    root.mainloop()
# Out:
# words
# -----
# dict_items([('pessoas', {'identidade': ['status', 'privacy', 'passport', 'age', 'birth_certificate', 'missus', 'name', 'habit', 'citizenship', 'nationality', 'autograph', 'pseudonym', 'personality', 'human', 'reputation', 'miss', 'last_name', 'motherland', 'person', 'fingerprint', 'signature', 'mister', 'nickname'], 'idade_e_eventos_da_vida': ['long-lived', 'to_be_born', 'young', 'ceremony', 'to_age', 'birthday', 'honeymoon', 'death', 'fireworks', 'to_die', 'gift', 'baby', 'to_celebrate', 'wedding', 'festival', 'child', 'middle-aged', 'engagement', 'old', 'teenager', 'occasion', 'parade', 'life', 'to_congratulate', 'to_marry', 'invitation', 'divorce', 'anniversary', 'tradition', 'mature', 'surprise', 'to_retire', 'adult'], 'familia': ['hereditary', 'to_adopt', 'triplets', 'sister', 'brother', 'daughter', 'related', 'nephew', 'mother', 'grandmother', 'grandson', 'son-in-law', 'wife', 'aunt', 'niece', 'brother-in-law', 'son', 'childless', 'adoptive_parents', 'father', 'paternal', 'ancestry', 'parents', 'grandfather', 'great-granddaught_er', 'husband', 'great-grandmother', 'great-grandson', 'foster_parents', 'granddaughter', 'generation', 'mother-in-law', 'relatives', 'cousin', 'daughter-in-law', 'grandparents', 'twins', 'uncle', 'sister-in-law', 'great-grandfather', 'maternal', 'adoption', 'father-in-law'], 'amor_e_amizade': ['gang', 'couple', 'to_meet', 'friend', 'unmarried', 'to_court', 'acquaintance', 'relationship', 'bride', 'single', 'boyfriend', 'stranger', 'to_fall_in_love', 'to_introduce', 'guy', 'marriage', 'bridesmaid', 'igag', 'married', 'intimacy', 'bridegroom', 'romantic', 'girl', 'fiancé', 'to_flirt', 'proposal', 'man', 'girlfriend', 'colleague', 'fiancée', 'divorced', 'boy', 'groomsman', 'romance', 'woman']}), ('plantas', {'arvores': ['mahogany', 'willow', 'eucalyptus', 'log', 'alder', 'sequoia', 'pine', 'oak', 'beech', 'spruce', 'acorn', 'tree', 'linden', 'pinecone', 'sapling', 'elm', 'fir', 'birch', 'yew', 'maple', 'magnolia', 'aspen', 'poplar', 'stick', 'acacia', 'chestnut_tree', 'branch', 'leaf', 'cedar', 'cypress'], 'arbustos': ['rosemary', 'raspberry', 'rhododendron', 'cassava', 'strawberry', 'holly', 'shrub', 'blackberry', 'lilac', 'bush', 'privet', 'cranberry', 'myrtle', 'blueberry', 'hydrangea'], 'agricultura': ['tractor', 'irrigation', 'plantation', 'to_feed', 'barn', 'plow', 'mud', 'windmill', 'hay', 'trap', 'to_fertilize', 'agriculturist', 'to_cultivate', 'to_hoe', 'to_ripen', 'to_reap', 'to_harrow', 'scarecrow', 'herbicide', 'seedling', 'harvest', 'sprinkler', 'vineyard', 'farm', 'to_rake', 'to_garden', 'gardener', 'gardening', 'infertile', 'spade', 'scythe', 'rake', 'orchard', 'soil', 'to_sow', 'to_water', 'to_plow', 'crop', 'to_gather', 'agriculture', 'field', 'herbarium', 'fertilizer', 'to_sweep', 'to_flower', 'to_mow', 'greenhouse', 'shovel', 'fertile', 'breeder', 'to_plant', 'to_shovel', 'to_irrigate'], 'flores': ['lavender', 'chrysanthemum', 'blossom', 'anemone', 'daffodil', 'primrose', 'peony', 'begonia', 'daisy', 'dahlia', 'rose', 'camellia', 'gerbera', 'lily', 'azalea', 'hyacinth', 'freesia', 'iris', 'orchid', 'tulip', 'carnation', 'violet', 'poppy', 'cyclamen', 'bouquet', 'buttercup', 'sunflower', 'lotus', 'gladiolus', 'dandelion', 'forget-me-not', 'snowdrop', 'marigold', 'pansy', 'flower'], 'arvores_de_fruto': ['almond_tree', 'pomegranate_tree', 'avocado_tree', 'tamarind_tree', 'olive_tree', 'quince_tree', 'apricot_tree', 'pear_tree', 'plum', 'lemon_tree', 'lime_tree', 'cacao', 'guava_tree', 'mango_tree', 'grapefruit_tree', 'hazelnut_tree', 'cherry_tree', 'pistachio_tree', 'cashew_tree', 'peach_tree', 'persimmon_tree', 'orange_tree', 'apple_tree', 'macadamia_nut_tree'], 'sobre_as_plantas': ['bud', 'trunk', 'growth', 'to_wither', 'to_replant', 'flora', 'thorn', 'stem', 'twig', 'species', 'pollen', 'nectar', 'sprout', 'vegetation', 'bark', 'root', 'petal'], 'outras_plantas': ['kelp', 'chickweed', 'jasmine', 'rapeseed', 'tobacco', 'plant', 'briar', 'alfalfa', 'papyrus', 'ginseng', 'bamboo', 's ...
# words
# -----
# dict_items([('pessoas', {'identidade': ['status', 'privacy', 'passport', 'age', 'birth_certificate', 'missus', 'name', 'habit', 'citizenship', 'nationality', 'autograph', 'pseudonym', 'personality', 'human', 'reputation', 'miss', 'last_name', 'motherland', 'person', 'fingerprint', 'signature', 'mister', 'nickname'], 'idade_e_eventos_da_vida': ['long-lived', 'to_be_born', 'young', 'ceremony', 'to_age', 'birthday', 'honeymoon', 'death', 'fireworks', 'to_die', 'gift', 'baby', 'to_celebrate', 'wedding', 'festival', 'child', 'middle-aged', 'engagement', 'old', 'teenager', 'occasion', 'parade', 'life', 'to_congratulate', 'to_marry', 'invitation', 'divorce', 'anniversary', 'tradition', 'mature', 'surprise', 'to_retire', 'adult'], 'familia': ['hereditary', 'to_adopt', 'triplets', 'sister', 'brother', 'daughter', 'related', 'nephew', 'mother', 'grandmother', 'grandson', 'son-in-law', 'wife', 'aunt', 'niece', 'brother-in-law', 'son', 'childless', 'adoptive_parents', 'father', 'paternal', 'ancestry', 'parents', 'grandfather', 'great-granddaught_er', 'husband', 'great-grandmother', 'great-grandson', 'foster_parents', 'granddaughter', 'generation', 'mother-in-law', 'relatives', 'cousin', 'daughter-in-law', 'grandparents', 'twins', 'uncle', 'sister-in-law', 'great-grandfather', 'maternal', 'adoption', 'father-in-law'], 'amor_e_amizade': ['gang', 'couple', 'to_meet', 'friend', 'unmarried', 'to_court', 'acquaintance', 'relationship', 'bride', 'single', 'boyfriend', 'stranger', 'to_fall_in_love', 'to_introduce', 'guy', 'marriage', 'bridesmaid', 'igag', 'married', 'intimacy', 'bridegroom', 'romantic', 'girl', 'fiancé', 'to_flirt', 'proposal', 'man', 'girlfriend', 'colleague', 'fiancée', 'divorced', 'boy', 'groomsman', 'romance', 'woman']}), ('plantas', {'arvores': ['mahogany', 'willow', 'eucalyptus', 'log', 'alder', 'sequoia', 'pine', 'oak', 'beech', 'spruce', 'acorn', 'tree', 'linden', 'pinecone', 'sapling', 'elm', 'fir', 'birch', 'yew', 'maple', 'magnolia', 'aspen', 'poplar', 'stick', 'acacia', 'chestnut_tree', 'branch', 'leaf', 'cedar', 'cypress'], 'arbustos': ['rosemary', 'raspberry', 'rhododendron', 'cassava', 'strawberry', 'holly', 'shrub', 'blackberry', 'lilac', 'bush', 'privet', 'cranberry', 'myrtle', 'blueberry', 'hydrangea'], 'agricultura': ['tractor', 'irrigation', 'plantation', 'to_feed', 'barn', 'plow', 'mud', 'windmill', 'hay', 'trap', 'to_fertilize', 'agriculturist', 'to_cultivate', 'to_hoe', 'to_ripen', 'to_reap', 'to_harrow', 'scarecrow', 'herbicide', 'seedling', 'harvest', 'sprinkler', 'vineyard', 'farm', 'to_rake', 'to_garden', 'gardener', 'gardening', 'infertile', 'spade', 'scythe', 'rake', 'orchard', 'soil', 'to_sow', 'to_water', 'to_plow', 'crop', 'to_gather', 'agriculture', 'field', 'herbarium', 'fertilizer', 'to_sweep', 'to_flower', 'to_mow', 'greenhouse', 'shovel', 'fertile', 'breeder', 'to_plant', 'to_shovel', 'to_irrigate'], 'flores': ['lavender', 'chrysanthemum', 'blossom', 'anemone', 'daffodil', 'primrose', 'peony', 'begonia', 'daisy', 'dahlia', 'rose', 'camellia', 'gerbera', 'lily', 'azalea', 'hyacinth', 'freesia', 'iris', 'orchid', 'tulip', 'carnation', 'violet', 'poppy', 'cyclamen', 'bouquet', 'buttercup', 'sunflower', 'lotus', 'gladiolus', 'dandelion', 'forget-me-not', 'snowdrop', 'marigold', 'pansy', 'flower'], 'arvores_de_fruto': ['almond_tree', 'pomegranate_tree', 'avocado_tree', 'tamarind_tree', 'olive_tree', 'quince_tree', 'apricot_tree', 'pear_tree', 'plum', 'lemon_tree', 'lime_tree', 'cacao', 'guava_tree', 'mango_tree', 'grapefruit_tree', 'hazelnut_tree', 'cherry_tree', 'pistachio_tree', 'cashew_tree', 'peach_tree', 'persimmon_tree', 'orange_tree', 'apple_tree', 'macadamia_nut_tree'], 'sobre_as_plantas': ['bud', 'trunk', 'growth', 'to_wither', 'to_replant', 'flora', 'thorn', 'stem', 'twig', 'species', 'pollen', 'nectar', 'sprout', 'vegetation', 'bark', 'root', 'petal'], 'outras_plantas': ['kelp', 'chickweed', 'jasmine', 'rapeseed', 'tobacco', 'plant', 'briar', 'alfalfa', 'papyrus', 'ginseng', 'bamboo', 's ...
# phrases
# -----
# dict_items([('viagem', {'no_posto_de_turismo': ["where's_the_cathedral", 'where_can_i_find_a_sandwich_store', 'what_are_the_main_points_of_interest', "i'd_like_to_stay_downtown", "where's_the_main_shopping_area", 'is_there_a_subway_station_nearby', 'is_there_a_bar_in_the_town', 'where_can_i_catch_the_shuttle_bus', 'how_do_we_get_to_the_theater', "where's_downtown", 'where_are_the_ruins', 'can_you_recommend_a_good_bar_near_here', "what's_the_best_way_of_getting_around_the_city", 'can_i_book_a_hotel_room_here', 'where_is_the_museum', "where's_the_airport", 'is_there_a_bus_into_town', "where's_the_nearest_restaurant", 'where_is_the_botanical_garden', 'please_give_me_a_map_of_the_city', "where's_the_market", 'do_you_have_any_brochures', 'i_would_like_to_see_the_old_town', 'can_you_recommend_any_good_campgrounds', 'where_is_the_visitor_center', 'where_are_the_buses', 'are_there_any_motels', 'do_you_know_the_number_to_call_a_cab', 'could_you_book_accommodations_for_me', 'we_need_someplace_to_stay', 'can_you_recommend_a_good_restaurant', 'where_is_the_best_place_to_go_fora_stroll', 'where_is_the_park', 'do_you_have_a_list_of_youth_hostels', 'is_there_a_theater_in_this_town', "where's_the_art_gallery", "we're_looking_for_accommodations", "i'm_a_foreigner", 'where_can_i_rent_a_car', 'how_many_stars_does_it_have', 'do_you_have_any_information_on_local_taxi_services', 'where_is_the_nearest_hotel', 'do_you_have_a_program_of_events', 'do_you_have_a_map', 'i_want_to_go_sightseeing'], 'dar_indicações': ['at_the_stoplights', 'continue_straight_ahead_for_about_a_kilometer', 'north', 'across_from_the_post_office', "it's_near_here", 'go_through_the_park', 'at_the_corner_of_the_boulevard', 'go_back', "it's_not_too_far", "you're_going_the_wrong_way", 'west', "it's_quite_far_from_here", 'right_here', "sorry,_i'm_not_from_around_here", 'i_can_show_you', 'use_the_pedestrian_underpass', "‘ou'd_better_tak_the_bus", "sorry,_i_don't_know_the_way", "it's_quite_close", 'east', 'left', 'go_down_there', 'straight_ahead', 'keep_going_for_another_two_hundred_meters', "it's_right_across_the_street", 'follow_the_signs_for_downtown', "it's_a_long_way_to_walk", "‘ou'd_better_tak_the_trolley", 'south', 'a_little_bit_further', 'it_will_take_you_quite_a_while_to_get_there', 'it_will_be_straight_ahead_of_you', "it's_near_the_supermarket", "it's_right_there,_in_front_of_you", 'continue_past_the_firehouse', 't_the_end_of_th_street', 'continue_straight_on_past_some_stoplights', 'at_the_intersection', 'right', 'behind_the_bank', 'o_straight_the_turn_left', 'it_will_be_on_your_left', 'next_to_the_bus_station', "it's_about_a_five-minute_walk", "sorry,_i_don't_know_the_town", 'around_the_corner', "it's_a_short_walk", 'another_half_kilometer'], 'excursões': ['do_you_have_a_brochure_describing_tours_and_excursions', 'could_you_print_the_photos_from_this_memory_card', 'when_will_the_photos_be_ready', "you_can't_miss_it", 'an_i_get_off_at_t_hotel', 'would_you_please_tell_me_what_museums_are_here', 'excuse_me,_could_you_take_a_photo_for_me', 'will_there_be_an_opportunity_to_take_some_photographs', 'are_there_any_tours', "i'd_like_to_pick_up_my_photos", 'do_you_need_a_guided_tour', "i'd_like_to_book_a_trip_to_berlin", "i'd_like_a_georgian_speaking_guide", 'are_there_any_cultural_events_on_at_the_moment', 'are_there_any_excursions', "could_you_tell_us_what's_on_at_the_concert_hall", 'is_there_a_city_tour', 'i_would_like_these_photographs_enlarged', 'what_kind_of_tour_would_you_prefer', 'i_think_some_of_these_photos_are_underexposed', 'can_you_take_pictures', 'where_can_i_sign_up_for_the_excursion', 'can_we_take_a_bicycle_tour', 'recommend_a_ightseeing_tou!', 'what_bus_tours_are_available', 'what_other_interesting_things_are_there_to_see', 'vhich_is_the_be_route', 'is_an_all-day_tour_available_here', 'what_time_do_we_leave', '[hat_time_does_start', 'can_i_join_the_tour_at_the_hotel', 'do_you_have_any_brochures_on_local_attractions', "when's_the_next_tour", 'can_l_have_a_guide', 'who ...
# words
# -----
# dict_items([('pessoas', {'identidade': ['status', 'privacy', 'passport', 'age', 'birth_certificate', 'missus', 'name', 'habit', 'citizenship', 'nationality', 'autograph', 'pseudonym', 'personality', 'human', 'reputation', 'miss', 'last_name', 'motherland', 'person', 'fingerprint', 'signature', 'mister', 'nickname'], 'idade_e_eventos_da_vida': ['long-lived', 'to_be_born', 'young', 'ceremony', 'to_age', 'birthday', 'honeymoon', 'death', 'fireworks', 'to_die', 'gift', 'baby', 'to_celebrate', 'wedding', 'festival', 'child', 'middle-aged', 'engagement', 'old', 'teenager', 'occasion', 'parade', 'life', 'to_congratulate', 'to_marry', 'invitation', 'divorce', 'anniversary', 'tradition', 'mature', 'surprise', 'to_retire', 'adult'], 'familia': ['hereditary', 'to_adopt', 'triplets', 'sister', 'brother', 'daughter', 'related', 'nephew', 'mother', 'grandmother', 'grandson', 'son-in-law', 'wife', 'aunt', 'niece', 'brother-in-law', 'son', 'childless', 'adoptive_parents', 'father', 'paternal', 'ancestry', 'parents', 'grandfather', 'great-granddaught_er', 'husband', 'great-grandmother', 'great-grandson', 'foster_parents', 'granddaughter', 'generation', 'mother-in-law', 'relatives', 'cousin', 'daughter-in-law', 'grandparents', 'twins', 'uncle', 'sister-in-law', 'great-grandfather', 'maternal', 'adoption', 'father-in-law'], 'amor_e_amizade': ['gang', 'couple', 'to_meet', 'friend', 'unmarried', 'to_court', 'acquaintance', 'relationship', 'bride', 'single', 'boyfriend', 'stranger', 'to_fall_in_love', 'to_introduce', 'guy', 'marriage', 'bridesmaid', 'igag', 'married', 'intimacy', 'bridegroom', 'romantic', 'girl', 'fiancé', 'to_flirt', 'proposal', 'man', 'girlfriend', 'colleague', 'fiancée', 'divorced', 'boy', 'groomsman', 'romance', 'woman']}), ('plantas', {'arvores': ['mahogany', 'willow', 'eucalyptus', 'log', 'alder', 'sequoia', 'pine', 'oak', 'beech', 'spruce', 'acorn', 'tree', 'linden', 'pinecone', 'sapling', 'elm', 'fir', 'birch', 'yew', 'maple', 'magnolia', 'aspen', 'poplar', 'stick', 'acacia', 'chestnut_tree', 'branch', 'leaf', 'cedar', 'cypress'], 'arbustos': ['rosemary', 'raspberry', 'rhododendron', 'cassava', 'strawberry', 'holly', 'shrub', 'blackberry', 'lilac', 'bush', 'privet', 'cranberry', 'myrtle', 'blueberry', 'hydrangea'], 'agricultura': ['tractor', 'irrigation', 'plantation', 'to_feed', 'barn', 'plow', 'mud', 'windmill', 'hay', 'trap', 'to_fertilize', 'agriculturist', 'to_cultivate', 'to_hoe', 'to_ripen', 'to_reap', 'to_harrow', 'scarecrow', 'herbicide', 'seedling', 'harvest', 'sprinkler', 'vineyard', 'farm', 'to_rake', 'to_garden', 'gardener', 'gardening', 'infertile', 'spade', 'scythe', 'rake', 'orchard', 'soil', 'to_sow', 'to_water', 'to_plow', 'crop', 'to_gather', 'agriculture', 'field', 'herbarium', 'fertilizer', 'to_sweep', 'to_flower', 'to_mow', 'greenhouse', 'shovel', 'fertile', 'breeder', 'to_plant', 'to_shovel', 'to_irrigate'], 'flores': ['lavender', 'chrysanthemum', 'blossom', 'anemone', 'daffodil', 'primrose', 'peony', 'begonia', 'daisy', 'dahlia', 'rose', 'camellia', 'gerbera', 'lily', 'azalea', 'hyacinth', 'freesia', 'iris', 'orchid', 'tulip', 'carnation', 'violet', 'poppy', 'cyclamen', 'bouquet', 'buttercup', 'sunflower', 'lotus', 'gladiolus', 'dandelion', 'forget-me-not', 'snowdrop', 'marigold', 'pansy', 'flower'], 'arvores_de_fruto': ['almond_tree', 'pomegranate_tree', 'avocado_tree', 'tamarind_tree', 'olive_tree', 'quince_tree', 'apricot_tree', 'pear_tree', 'plum', 'lemon_tree', 'lime_tree', 'cacao', 'guava_tree', 'mango_tree', 'grapefruit_tree', 'hazelnut_tree', 'cherry_tree', 'pistachio_tree', 'cashew_tree', 'peach_tree', 'persimmon_tree', 'orange_tree', 'apple_tree', 'macadamia_nut_tree'], 'sobre_as_plantas': ['bud', 'trunk', 'growth', 'to_wither', 'to_replant', 'flora', 'thorn', 'stem', 'twig', 'species', 'pollen', 'nectar', 'sprout', 'vegetation', 'bark', 'root', 'petal'], 'outras_plantas': ['kelp', 'chickweed', 'jasmine', 'rapeseed', 'tobacco', 'plant', 'briar', 'alfalfa', 'papyrus', 'ginseng', 'bamboo', 's ...
# sub:adjetivos, items:descrições_2

# %% [markdown]
# ## Futuras features
#
# - taxa de erros
# - ultimas palavras [acerto/erro] [audio]
# - palavras já vistas [gral de conhecimento]
# - completude por categoria, depois subcategoria [conhecidas/desconhecidas]
#
# - melhores formas de esconher as caregorias pra jogar
#
# - criar paineis de gráfico

# %%
import tkinter as tk

def ouvir_audio():
    print("Tocando áudio...")  # Aqui você chamaria a função real de áudio
    popup.destroy()

def mostrar_mensagem():
    global popup
    popup = tk.Toplevel(root)
    popup.title("Mensagem")
    popup.geometry("300x150")
    popup.grab_set()  # Faz a janela se comportar como modal

    label = tk.Label(popup, text="Você errou a palavra!")
    label.pack(pady=10)

    botao_ouvir = tk.Button(popup, text="🔊 Ouvir áudio", command=ouvir_audio)
    botao_ouvir.pack(pady=5)

    botao_ok = tk.Button(popup, text="OK", command=popup.destroy)
    botao_ok.pack(pady=5)

root = tk.Tk()
tk.Button(root, text="Mostrar mensagem", command=mostrar_mensagem).pack(pady=20)
root.mainloop()

# %%
import tkinter as tk
from tkinter import messagebox

# Funções dos botões
def marcar_errado():
    messagebox.showinfo("Ação", "Palavra marcada como errada.")

def editar_palavra():
    messagebox.showinfo("Ação", "Abrindo editor de atributos...")

def favoritar_palavra():
    messagebox.showinfo("Ação", "Palavra favoritada!")

# Criação da janela
root = tk.Tk()
root.title("Exemplo de Botões com Emojis")
root.geometry("300x150")

# Frame para os botões
frame = tk.Frame(root)
frame.pack(pady=20)

# Botões com emojis (pode ajustar os emojis se preferir)
btn_errado = tk.Button(frame, text="❌ | Errado", command=marcar_errado)
btn_editar = tk.Button(frame, text="✏️ Editar", command=editar_palavra)
btn_favoritar = tk.Button(frame, text="⭐ Favoritar", command=favoritar_palavra)

# Posicionamento
btn_errado.grid(row=0, column=0, padx=5)
btn_editar.grid(row=0, column=1, padx=5)
btn_favoritar.grid(row=0, column=2, padx=5)

# Loop principal
root.mainloop()

# %%
# Out:
# '01/05/2025, 07:19:08'

# %% [markdown]
# ---

# %%
import tkinter as tk

class App(tk.Tk):
    def __init__(self):
        super().__init__()

        self.title("Exemplo de Mudar de Tela")
        self.geometry("400x300")

        # Tela 1
        self.tela_inicial = tk.Frame(self)
        self.tela_inicial.pack(fill="both", expand=True)

        label = tk.Label(self.tela_inicial, text="Tela Inicial", font=("Arial", 18))
        label.pack(pady=20)

        botao_ir_para_tela2 = tk.Button(self.tela_inicial, text="Ir para Tela 2", command=self.mostrar_tela2)
        botao_ir_para_tela2.pack()

        # Tela 2
        self.tela2 = tk.Frame(self)

        label2 = tk.Label(self.tela2, text="Você está na Tela 2!", font=("Arial", 18))
        label2.pack(pady=20)

        botao_voltar = tk.Button(self.tela2, text="Voltar para Tela Inicial", command=self.mostrar_tela_inicial)
        botao_voltar.pack()

    def mostrar_tela2(self):
        self.tela_inicial.pack_forget()
        self.tela2.pack(fill="both", expand=True)

    def mostrar_tela_inicial(self):
        self.tela2.pack_forget()
        self.tela_inicial.pack(fill="both", expand=True)

if __name__ == "__main__":
    app = App()
    app.mainloop()

# %%
import pandas as pd
import os

# %%
os.chdir("..")

# %%
df = pd.read_csv("database/csv/words_oxford_levels.csv")

WORDS = df.sample(100)["Word"].tolist()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df = pd.read_csv("database/csv/words_oxford_levels.csv")
#       3 WORDS = df.sample(100)["Word"].tolist()
#
# File ~/.cache/pypoetry/virtualenvs/fast-english-s-Sv58CE-py3.12/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/.cache/pypoetry/virtualenvs/fast-english-s-Sv58CE-py3.12/lib/python3.12/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/.cache/pypoetry/virtualenvs/fast-english-s-Sv58CE-py3.12/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/.cache/pypoetry/virtualenvs/fast-english-s-Sv58CE-py3.12/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/.cache/pypoetry/virtualenvs/fast-english-s-Sv58CE-py3.12/lib/python3.12/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'database/csv/words_oxford_levels.csv'

# %%
from deep_translator import GoogleTranslator



WORDS = ['Red', 'Blue', 'Green', 'Pink', 'Black',
                        'Yellow', 'Orange', 'White', 'Purple', 'Brown']
