# %%
class ItemList:
    def __init__(self, data=0, next_item=None):
        self.data = data
        self.next = next_item

    def __repr__(self) -> str:
        return f"{self.data} → {self.next}"


class LinkedList:
    def __init__(self) -> None:
        self.head = None

    def __repr__(self):
        return f"{self.head}"

    def append(self, data):
        # Cria um objeto para armazenar um novo item da lista
        new_item = ItemList(data)

        # O head é apontado como proximo item
        new_item.next = self.head

        # O item atual se torna o head
        self.head = new_item
    
    def insert(self, index, data):
        "Insere em posição específica"""
        pass

    def delete(self, data):
        "Remove o nó com valor específico"""
        pass

    def search(self, data):
        "Retorna se o valor está na lista"""
        pass

    def reverse(self):
        "Inverte a lista"""
        pass

    def length(self):
        "Retorna o tamanho"""
        pass

    def revome(self, value):
        # Verifica se o item a ser vemovido é o head
        if self.head and self.head.data == value:
            self.head = self.head.next
        else:
            # Detem a posição do elemento
            before = None
            current = self.head

            # Navega pela lista para encontrar o elemento
            while current and current.data != value:
                before = current
                current = current.next

            # Remove o item se ele for encontrado
            if current:
                before.next = current.next

    def find(self, value):
        current = self.head

        # Navega pela lista para encontrar o elemento
        while current and current.data != value:
            current = current.next
        
        return current


linked_list = LinkedList()

linked_list.append("Teste1")
linked_list.append("Teste2")
linked_list.append("Teste3")
linked_list.append("Teste4")
linked_list.append("Teste4")
linked_list.append("Teste5")

# linked_list.revome("Teste2")

linked_list.find("Teste5")
# Out:
# Teste5 → Teste4 → Teste4 → Teste3 → Teste2 → Teste1 → None

# %%
linked_list.head
# Out:
# Teste4 => Teste3 => Teste2 => Teste1 => None
